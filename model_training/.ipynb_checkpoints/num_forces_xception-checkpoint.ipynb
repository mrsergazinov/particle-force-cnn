# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
from PIL.ImageOps import expand
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'val')
model_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                          'PhotoForceReconML', 'models', 'vgg19_num_forces.h5')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels are inferred from the subdirectory names.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# Define gaussian blur class
class GaussBlur:
    def __init__(self, radius):
        self.radius = radius
    def blur(self, image):
        return gaussian_filter(image, sigma = self.radius)

# %%
# Define datagen and gaussian blur classes
gaussblur = GaussBlur(1)
datagen = ImageDataGenerator(
    rescale = 1 / 255,
    preprocessing_function = gaussblur.blur)

# %%
# Create directory iterator for reading in the data
datagen_flow_ex = datagen.flow_from_directory(train_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         save_to_dir = os.path.join(os.getcwd(), 'image_data', 'train_augmented'),
                                         save_prefix = "train-",
                                         save_format = "jpg",
                                         follow_links = False,
                                         interpolation = "nearest")
datagen_flow_train = datagen.flow_from_directory(train_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
datagen_flow_val = datagen.flow_from_directory(val_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
# Out:
# Found 80000 images belonging to 5 classes.
# Found 80000 images belonging to 5 classes.
# Found 20000 images belonging to 5 classes.

# %%
# Save some batches of generated data to inspect the results of transformation
i = 0 
for batch in datagen_flow_ex:
    i += 1
    if i > 3:
        break  # otherwise the generator would loop indefinitely

# %% [markdown]
# #### XCEPTION Model building

# %% [markdown]
# Convolutional neural network is defined and compiled in this step.

# %%
# Load XCEPTION model to be the base model
base_model = applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(128, 128, 3),
    include_top=False)

# %%
# Freeze model weights
base_model.trainable = False
# Get output shape
base_model.output_shape
# Get model summary
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 63, 63, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 63, 63, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 63, 63, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# Determine number of classes
num_classes = len(os.listdir(os.path.join(os.getcwd(), 'image_data', 'train')))

# Define the model
inputs = Input(shape=(128, 128, 3))
x = base_model(inputs, training = False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# ...
# Total params: 22,964,781
# Trainable params: 2,103,301
# Non-trainable params: 20,861,480
# ...

# %% [markdown]
# #### XCEPTION Model Training

# %% [markdown]
# The model is trained using Adam optimizer. The loss is defined to be categorical crossentropy. Best model selection across training epochs is implemented with model checkpoint tracking the validation loss. Early stopping is set with patience of 5 epochs.

# %%
# Compile model: define loss, optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(epsilon = 0.1),
              loss='categorical_crossentropy', 
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose = 1, patience = 20)
mc = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 100

history = model.fit(datagen_flow_train,
                            epochs = epochs,
                            steps_per_epoch = len(datagen_flow_train),
                            validation_data = datagen_flow_val,
                            validation_steps = len(datagen_flow_val),
                            callbacks=[es, mc]
                           )
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.5797 - accuracy: 0.7667 - categorical_crossentropy: 0.5797
# Epoch 00001: val_loss improved from inf to 0.36164, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/xception_num_forces.h5
# 2500/2500 [==============================] - 223s 89ms/step - loss: 0.5797 - accuracy: 0.7667 - categorical_crossentropy: 0.5797 - val_loss: 0.3616 - val_accuracy: 0.8570 - val_categorical_crossentropy: 0.3616
# Epoch 2/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8839 - categorical_crossentropy: 0.3039
# Epoch 00002: val_loss improved from 0.36164 to 0.28628, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/xception_num_forces.h5
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# #### XCEPTION Model Fine-tuning

# %%
base_model.trainable = True
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# ...
# Total params: 22,964,781
# Trainable params: 22,910,253
# Non-trainable params: 54,528
# ...

# %%
# Compile model: define loss, optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-05, epsilon = 0.1),
              loss='categorical_crossentropy', 
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 100

history_tune = model.fit(datagen_flow_train,
                            epochs = epochs,
                            steps_per_epoch = len(datagen_flow_train),
                            validation_data = datagen_flow_val,
                            validation_steps = len(datagen_flow_val),
                            callbacks=[es, mc]
                           )
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9956 - categorical_crossentropy: 0.0172
# Epoch 00001: val_loss improved from inf to 0.14036, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/xception_num_forces.h5
# 2500/2500 [==============================] - 318s 127ms/step - loss: 0.0172 - accuracy: 0.9956 - categorical_crossentropy: 0.0172 - val_loss: 0.1404 - val_accuracy: 0.9593 - val_categorical_crossentropy: 0.1404
# Epoch 2/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9973 - categorical_crossentropy: 0.0112
# Epoch 00002: val_loss improved from 0.14036 to 0.13130, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/xception_num_forces.h5
# ...

# %%
plt.plot(history_tune.history['loss'])
plt.plot(history_tune.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history_tune.history['accuracy'])
plt.plot(history_tune.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
