# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import Sequence
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                                'python-git-workspace', 'PhotoForceReconML', 'image_data', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                                'python-git-workspace', 'PhotoForceReconML', 'image_data', 'val')
train_label_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'train')
val_label_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'val')
models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels should be loaded from a separate directory. Each label corresponds to two particles.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# Define sorter of image names in order by image number (default is alphanumric)
def sorter(item):
    # Since highest marks first, least error = most marks
    radius = float(item[1 : item.find('_')])
    num_img = int(item[item.find('g') + 1 : item.find('j') - 1])
    return (radius, num_img)

# %%
# Load the train and validation sets

X_train, X_val = {}, {}
y_train, y_val = {}, {}

for k in range(5):
    i = k + 2
    X_path_train = os.path.join(train_image_path, str(i))
    X_path_val = os.path.join(val_image_path, str(i))
    X_train[i] = [os.path.join(X_path_train, name) for name in sorted(os.listdir(X_path_train), key = sorter)]
    X_val[i] = [os.path.join(X_path_val, name) for name in sorted(os.listdir(X_path_val), key = sorter)]
    y_train[i] = np.load(os.path.join(train_label_path, str(i), 'angles_tang.npy'))
    y_val[i] = np.load(os.path.join(val_label_path, str(i), 'angles_tang.npy'))

# %%
# Define class for data generation
class DataGenerator(Sequence):
    'Generates data for Keras'
    def __init__(self, list_image_paths = None, labels = None,  
                 batch_size = 32, dim = None, n_channels = 3, rescale = 1, 
                 shuffle=True, save_dir = None, preprocessing_func = None):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_image_paths = list_image_paths
        self.n_channels = n_channels
        self.rescale = rescale
        self.shuffle = shuffle
        self.save_dir = save_dir
        self.preprocessing_func = preprocessing_func
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_image_paths) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indices = self.indices[index * self.batch_size : (index + 1) * self.batch_size]

        # Generate data
        X, y = self.__data_generation(indices)
        
        if self.save_dir is not None:
            for i in range(X.shape[0]):
                path = os.path.join(self.save_dir, 'img' + str(i) + '.jpg')
                plt.imsave(path, np.asarray(X[i, ]), vmin = 0, vmax = 1)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indices = np.arange(len(self.list_image_paths))
        if self.shuffle == True:
            np.random.shuffle(self.indices)

    def __data_generation(self, indices):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        
        # Initialisation
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        list_image_paths_batch = [self.list_image_paths[k] for k in indices]
        
        # Get labels
        y = np.array([self.labels[k, :] for k in indices])
        
        # Generate data
        for i, image_path in enumerate(list_image_paths_batch):
            # Load image and transform
            image = Image.open(os.path.join(image_path))
            if self.dim is not None:
                image = image.resize(self.dim, resample = Image.NEAREST)
            image = np.array(image)[:, :, :self.n_channels]
            image = image * self.rescale
            if self.preprocessing_func is not None:
                image = self.preprocessing_func(image)
            # Store sample
            X[i,] = image

        return X, y

# %%
# Define gaussian blur class
class GaussBlur:
    def __init__(self, radius):
        self.radius = radius
    def blur(self, image):
        return gaussian_filter(image, sigma = self.radius)

# %%
# Apply data generators
gaussblur = GaussBlur(1)
params = {'batch_size': 32, 
          'dim': (128, 128), 
          'n_channels': 3, 
          'rescale': 1 / 255, 
          'shuffle': True, 
          'save_dir': None,
          'preprocessing_func': gaussblur.blur
          }

training_generator = {}
validation_generator = {}

for k in range(5):
    i = k + 2
    training_generator[i] = DataGenerator(X_train[i], y_train[i], **params)
    validation_generator[i] = DataGenerator(X_val[i], y_val[i], **params)

# %% [markdown]
# #### InceptionResNetV2 Models Building

# %% [markdown]
# Convolutional neural networks is defined and compiled in this step.

# %%
base_model = {}

# Load InceptionResNetV2 model to be the base model
for k in range(5):
    i = k + 2
    base_model[i] = applications.InceptionResNetV2(
        weights='imagenet',  # Load weights pre-trained on ImageNet.
        input_shape=(128, 128, 3),
        include_top=False)
    base_model[i].trainable = False

# %%
# Define the model
model = {}
for k in range(5):
    i = k + 2
    inputs = Input(shape=(128, 128, 3))
    x = base_model[i](inputs, training = False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(i, activation='linear')(x)
    model[i] = Model(inputs, outputs)

# %%
for k in range(5):
    i = k + 2
    model[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 55,912,674
# Trainable params: 1,575,938
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1536)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 55,913,699
# Trainable params: 1,576,963
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 55,914,724
# Trainable params: 1,577,988
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1536)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 1,579,013
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1536)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 55,916,774
# Trainable params: 1,580,038
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %% [markdown]
# #### InceptionResNetV2 Model Training

# %% [markdown]
# The model is trained using Adam optimizer. The loss is defined to be mean absolute error. Best model selection across training epochs is implemented with model checkpoint tracking the validation loss. Early stopping is set with patience of 30 epochs.

# %%
for k in range(5):
    i = 2 + k
    model[i].compile(optimizer=tf.keras.optimizers.Adam(),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = dict()
for k in range(5):
    i = k + 2
    model_path = os.path.join(models_path, 'InceptionResNetV2_angles_tang_'+str(i)+'.h5')
    mc[i] = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
epochs = 200
history = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history[i] = model[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/200
# 500/500 [==============================] - ETA: 0s - loss: 0.3244 - mean_absolute_error: 0.3244
# Epoch 00001: val_loss improved from inf to 0.14448, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 44s 87ms/step - loss: 0.3244 - mean_absolute_error: 0.3244 - val_loss: 0.1445 - val_mean_absolute_error: 0.1445
# Epoch 2/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1557 - mean_absolute_error: 0.1557
# Epoch 00002: val_loss improved from 0.14448 to 0.13799, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1557 - mean_absolute_error: 0.1557 - val_loss: 0.1380 - val_mean_absolute_error: 0.1380
# Epoch 3/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1507 - mean_absolute_error: 0.1507
# Epoch 00003: val_loss did not improve from 0.13799
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1446 - val_mean_absolute_error: 0.1446
# Epoch 4/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 00004: val_loss did not improve from 0.13799
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1470 - mean_absolute_error: 0.1470 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 5/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 00005: val_loss improved from 0.13799 to 0.11650, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1419 - mean_absolute_error: 0.1419 - val_loss: 0.1165 - val_mean_absolute_error: 0.1165
# Epoch 6/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 00006: val_loss did not improve from 0.11650
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1223 - val_mean_absolute_error: 0.1223
# Epoch 7/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1342 - mean_absolute_error: 0.1342
# Epoch 00007: val_loss improved from 0.11650 to 0.08650, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.0865 - val_mean_absolute_error: 0.0865
# Epoch 8/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1325 - mean_absolute_error: 0.1325
# Epoch 00008: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1325 - mean_absolute_error: 0.1325 - val_loss: 0.1127 - val_mean_absolute_error: 0.1127
# Epoch 9/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1334 - mean_absolute_error: 0.1334
# Epoch 00009: val_loss did not improve from 0.08650
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - val_loss: 0.1208 - val_mean_absolute_error: 0.1208
# Epoch 10/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1297 - mean_absolute_error: 0.1297
# Epoch 00010: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.0977 - val_mean_absolute_error: 0.0977
# Epoch 11/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1278 - mean_absolute_error: 0.1278
# Epoch 00011: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1278 - mean_absolute_error: 0.1278 - val_loss: 0.1286 - val_mean_absolute_error: 0.1286
# Epoch 12/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1285 - mean_absolute_error: 0.1285
# Epoch 00012: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1285 - mean_absolute_error: 0.1285 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 13/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1272 - mean_absolute_error: 0.1272
# Epoch 00013: val_loss did not improve from 0.08650
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1272 - mean_absolute_error: 0.1272 - val_loss: 0.1067 - val_mean_absolute_error: 0.1067
# Epoch 14/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1257 - mean_absolute_error: 0.1257
# Epoch 00014: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 15/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1254 - mean_absolute_error: 0.1254
# Epoch 00015: val_loss did not improve from 0.08650
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1254 - mean_absolute_error: 0.1254 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963
# Epoch 16/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1231 - mean_absolute_error: 0.1231
# Epoch 00016: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1231 - mean_absolute_error: 0.1231 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 17/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1241 - mean_absolute_error: 0.1241
# Epoch 00017: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.1080 - val_mean_absolute_error: 0.1080
# Epoch 18/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1223 - mean_absolute_error: 0.1223
# Epoch 00018: val_loss did not improve from 0.08650
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1222 - mean_absolute_error: 0.1222 - val_loss: 0.1046 - val_mean_absolute_error: 0.1046
# Epoch 19/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1213 - mean_absolute_error: 0.1213
# Epoch 00019: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1213 - mean_absolute_error: 0.1213 - val_loss: 0.1027 - val_mean_absolute_error: 0.1027
# Epoch 20/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1235 - mean_absolute_error: 0.1235
# Epoch 00020: val_loss did not improve from 0.08650
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1235 - mean_absolute_error: 0.1235 - val_loss: 0.1049 - val_mean_absolute_error: 0.1049
# Epoch 21/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1200 - mean_absolute_error: 0.1200
# Epoch 00021: val_loss did not improve from 0.08650
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1200 - mean_absolute_error: 0.1200 - val_loss: 0.0879 - val_mean_absolute_error: 0.0879
# Epoch 22/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 00022: val_loss improved from 0.08650 to 0.08475, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - val_loss: 0.0847 - val_mean_absolute_error: 0.0847
# Epoch 23/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1218 - mean_absolute_error: 0.1218
# Epoch 00023: val_loss did not improve from 0.08475
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1218 - mean_absolute_error: 0.1218 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
# Epoch 24/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1189 - mean_absolute_error: 0.1189
# Epoch 00024: val_loss did not improve from 0.08475
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1189 - mean_absolute_error: 0.1189 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909
# Epoch 25/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1210 - mean_absolute_error: 0.1210
# Epoch 00025: val_loss did not improve from 0.08475
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1210 - mean_absolute_error: 0.1210 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 26/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1198 - mean_absolute_error: 0.1198
# Epoch 00026: val_loss did not improve from 0.08475
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1198 - mean_absolute_error: 0.1198 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 27/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1195 - mean_absolute_error: 0.1195
# Epoch 00027: val_loss improved from 0.08475 to 0.07778, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1195 - mean_absolute_error: 0.1195 - val_loss: 0.0778 - val_mean_absolute_error: 0.0778
# Epoch 28/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 00028: val_loss did not improve from 0.07778
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1199 - mean_absolute_error: 0.1199 - val_loss: 0.0913 - val_mean_absolute_error: 0.0913
# Epoch 29/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1186 - mean_absolute_error: 0.1186
# Epoch 00029: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1186 - mean_absolute_error: 0.1186 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830
# Epoch 30/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1179 - mean_absolute_error: 0.1179
# Epoch 00030: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1179 - mean_absolute_error: 0.1179 - val_loss: 0.0930 - val_mean_absolute_error: 0.0930
# Epoch 31/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1171 - mean_absolute_error: 0.1171
# Epoch 00031: val_loss did not improve from 0.07778
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1171 - mean_absolute_error: 0.1171 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 32/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1154 - mean_absolute_error: 0.1154
# Epoch 00032: val_loss did not improve from 0.07778
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - val_loss: 0.1137 - val_mean_absolute_error: 0.1137
# Epoch 33/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1190 - mean_absolute_error: 0.1190
# Epoch 00033: val_loss did not improve from 0.07778
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909
# Epoch 34/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1168 - mean_absolute_error: 0.1168
# Epoch 00034: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1168 - mean_absolute_error: 0.1168 - val_loss: 0.0925 - val_mean_absolute_error: 0.0925
# Epoch 35/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1159 - mean_absolute_error: 0.1159
# Epoch 00035: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1159 - mean_absolute_error: 0.1159 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939
# Epoch 36/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 00036: val_loss did not improve from 0.07778
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1162 - mean_absolute_error: 0.1162 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815
# Epoch 37/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1167 - mean_absolute_error: 0.1167
# Epoch 00037: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1167 - mean_absolute_error: 0.1167 - val_loss: 0.0843 - val_mean_absolute_error: 0.0843
# Epoch 38/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1164 - mean_absolute_error: 0.1164
# Epoch 00038: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1164 - mean_absolute_error: 0.1164 - val_loss: 0.0812 - val_mean_absolute_error: 0.0812
# Epoch 39/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1170 - mean_absolute_error: 0.1170
# Epoch 00039: val_loss did not improve from 0.07778
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 40/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1156 - mean_absolute_error: 0.1156
# Epoch 00040: val_loss improved from 0.07778 to 0.07132, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1156 - mean_absolute_error: 0.1156 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 41/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1156 - mean_absolute_error: 0.1156
# Epoch 00041: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1156 - mean_absolute_error: 0.1156 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 42/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1163 - mean_absolute_error: 0.1163
# Epoch 00042: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1163 - mean_absolute_error: 0.1163 - val_loss: 0.0819 - val_mean_absolute_error: 0.0819
# Epoch 43/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1158 - mean_absolute_error: 0.1158
# Epoch 00043: val_loss did not improve from 0.07132
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1158 - mean_absolute_error: 0.1158 - val_loss: 0.0878 - val_mean_absolute_error: 0.0878
# Epoch 44/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1147 - mean_absolute_error: 0.1147
# Epoch 00044: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 45/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1145 - mean_absolute_error: 0.1145
# Epoch 00045: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1145 - mean_absolute_error: 0.1145 - val_loss: 0.0807 - val_mean_absolute_error: 0.0807
# Epoch 46/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1157 - mean_absolute_error: 0.1157- ETA: 0s - loss: 0.1158 - mean_absolute_err
# Epoch 00046: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1158 - mean_absolute_error: 0.1158 - val_loss: 0.0768 - val_mean_absolute_error: 0.0768
# Epoch 47/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1160 - mean_absolute_error: 0.1160
# Epoch 00047: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1159 - mean_absolute_error: 0.1159 - val_loss: 0.0921 - val_mean_absolute_error: 0.0921
# Epoch 48/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1159 - mean_absolute_error: 0.1159
# Epoch 00048: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1159 - mean_absolute_error: 0.1159 - val_loss: 0.0852 - val_mean_absolute_error: 0.0852
# Epoch 49/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1137 - mean_absolute_error: 0.1137
# Epoch 00049: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1137 - mean_absolute_error: 0.1137 - val_loss: 0.0811 - val_mean_absolute_error: 0.0811
# Epoch 50/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1147 - mean_absolute_error: 0.1147
# Epoch 00050: val_loss did not improve from 0.07132
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.0801 - val_mean_absolute_error: 0.0801
# Epoch 51/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1147 - mean_absolute_error: 0.1147
# Epoch 00051: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.0904 - val_mean_absolute_error: 0.0904
# Epoch 52/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1144 - mean_absolute_error: 0.1144
# Epoch 00052: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919
# Epoch 53/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1148 - mean_absolute_error: 0.1148
# Epoch 00053: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1148 - mean_absolute_error: 0.1148 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 54/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1146 - mean_absolute_error: 0.1146
# Epoch 00054: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1146 - mean_absolute_error: 0.1146 - val_loss: 0.0879 - val_mean_absolute_error: 0.0879
# Epoch 55/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1133 - mean_absolute_error: 0.1133
# Epoch 00055: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1133 - mean_absolute_error: 0.1133 - val_loss: 0.0885 - val_mean_absolute_error: 0.0885
# Epoch 56/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1144 - mean_absolute_error: 0.1144
# Epoch 00056: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - val_loss: 0.0838 - val_mean_absolute_error: 0.0838
# Epoch 57/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1141 - mean_absolute_error: 0.1141
# Epoch 00057: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1141 - mean_absolute_error: 0.1141 - val_loss: 0.1015 - val_mean_absolute_error: 0.1015
# Epoch 58/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1137 - mean_absolute_error: 0.1137
# Epoch 00058: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1137 - mean_absolute_error: 0.1137 - val_loss: 0.0803 - val_mean_absolute_error: 0.0803
# Epoch 59/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1122 - mean_absolute_error: 0.1122
# Epoch 00059: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1122 - mean_absolute_error: 0.1122 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 60/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1138 - mean_absolute_error: 0.1138
# Epoch 00060: val_loss did not improve from 0.07132
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1138 - mean_absolute_error: 0.1138 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815
# Epoch 00060: early stopping
# Model for  3  angles
# Epoch 1/200
# 500/500 [==============================] - ETA: 0s - loss: 0.3343 - mean_absolute_error: 0.3343
# Epoch 00001: val_loss improved from inf to 0.22496, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 43s 85ms/step - loss: 0.3343 - mean_absolute_error: 0.3343 - val_loss: 0.2250 - val_mean_absolute_error: 0.2250
# Epoch 2/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2215 - mean_absolute_error: 0.2215
# Epoch 00002: val_loss did not improve from 0.22496
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2215 - mean_absolute_error: 0.2215 - val_loss: 0.2252 - val_mean_absolute_error: 0.2252
# Epoch 3/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2212 - mean_absolute_error: 0.2212
# Epoch 00003: val_loss improved from 0.22496 to 0.22303, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.2212 - mean_absolute_error: 0.2212 - val_loss: 0.2230 - val_mean_absolute_error: 0.2230
# Epoch 4/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2189 - mean_absolute_error: 0.2189
# Epoch 00004: val_loss improved from 0.22303 to 0.22184, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2189 - mean_absolute_error: 0.2189 - val_loss: 0.2218 - val_mean_absolute_error: 0.2218
# Epoch 5/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2146 - mean_absolute_error: 0.2146
# Epoch 00005: val_loss improved from 0.22184 to 0.20991, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2146 - mean_absolute_error: 0.2146 - val_loss: 0.2099 - val_mean_absolute_error: 0.2099
# Epoch 6/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2113 - mean_absolute_error: 0.2113
# Epoch 00006: val_loss did not improve from 0.20991
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2114 - mean_absolute_error: 0.2114 - val_loss: 0.2135 - val_mean_absolute_error: 0.2135
# Epoch 7/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2111 - mean_absolute_error: 0.2111
# Epoch 00007: val_loss improved from 0.20991 to 0.20766, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2111 - mean_absolute_error: 0.2111 - val_loss: 0.2077 - val_mean_absolute_error: 0.2077
# Epoch 8/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2103 - mean_absolute_error: 0.2103
# Epoch 00008: val_loss did not improve from 0.20766
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2103 - mean_absolute_error: 0.2103 - val_loss: 0.2077 - val_mean_absolute_error: 0.2077
# Epoch 9/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2092 - mean_absolute_error: 0.2092
# Epoch 00009: val_loss improved from 0.20766 to 0.20601, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2092 - mean_absolute_error: 0.2092 - val_loss: 0.2060 - val_mean_absolute_error: 0.2060
# Epoch 10/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2087 - mean_absolute_error: 0.2087
# Epoch 00010: val_loss did not improve from 0.20601
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2087 - mean_absolute_error: 0.2087 - val_loss: 0.2075 - val_mean_absolute_error: 0.2075
# Epoch 11/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2089 - mean_absolute_error: 0.2089
# Epoch 00011: val_loss improved from 0.20601 to 0.20455, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2089 - mean_absolute_error: 0.2089 - val_loss: 0.2046 - val_mean_absolute_error: 0.2046
# Epoch 12/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2078 - mean_absolute_error: 0.2078
# Epoch 00012: val_loss did not improve from 0.20455
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2078 - mean_absolute_error: 0.2078 - val_loss: 0.2095 - val_mean_absolute_error: 0.2095
# Epoch 13/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2072 - mean_absolute_error: 0.2072
# Epoch 00013: val_loss did not improve from 0.20455
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2072 - mean_absolute_error: 0.2072 - val_loss: 0.2053 - val_mean_absolute_error: 0.2053
# Epoch 14/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2076 - mean_absolute_error: 0.2076
# Epoch 00014: val_loss did not improve from 0.20455
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2076 - mean_absolute_error: 0.2076 - val_loss: 0.2049 - val_mean_absolute_error: 0.2049
# Epoch 15/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2074 - mean_absolute_error: 0.2074
# Epoch 00015: val_loss did not improve from 0.20455
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2074 - mean_absolute_error: 0.2074 - val_loss: 0.2061 - val_mean_absolute_error: 0.2061
# Epoch 16/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2067 - mean_absolute_error: 0.2067
# Epoch 00016: val_loss did not improve from 0.20455
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2067 - mean_absolute_error: 0.2067 - val_loss: 0.2050 - val_mean_absolute_error: 0.2050
# Epoch 17/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2065 - mean_absolute_error: 0.2065
# Epoch 00017: val_loss did not improve from 0.20455
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2065 - mean_absolute_error: 0.2065 - val_loss: 0.2100 - val_mean_absolute_error: 0.2100
# Epoch 18/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2068 - mean_absolute_error: 0.2068
# Epoch 00018: val_loss did not improve from 0.20455
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2068 - mean_absolute_error: 0.2068 - val_loss: 0.2050 - val_mean_absolute_error: 0.2050
# Epoch 19/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2061 - mean_absolute_error: 0.2061
# Epoch 00019: val_loss did not improve from 0.20455
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2061 - mean_absolute_error: 0.2061 - val_loss: 0.2046 - val_mean_absolute_error: 0.2046
# Epoch 20/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2050 - mean_absolute_error: 0.2050
# Epoch 00020: val_loss improved from 0.20455 to 0.20226, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2049 - mean_absolute_error: 0.2049 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 21/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2049 - mean_absolute_error: 0.2049
# Epoch 00021: val_loss did not improve from 0.20226
# 500/500 [==============================] - 40s 79ms/step - loss: 0.2049 - mean_absolute_error: 0.2049 - val_loss: 0.2031 - val_mean_absolute_error: 0.2031
# Epoch 22/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2031 - mean_absolute_error: 0.2031
# Epoch 00022: val_loss improved from 0.20226 to 0.19287, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2031 - mean_absolute_error: 0.2031 - val_loss: 0.1929 - val_mean_absolute_error: 0.1929
# Epoch 23/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2015 - mean_absolute_error: 0.2015
# Epoch 00023: val_loss did not improve from 0.19287
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2015 - mean_absolute_error: 0.2015 - val_loss: 0.1950 - val_mean_absolute_error: 0.1950
# Epoch 24/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1998 - mean_absolute_error: 0.1998
# Epoch 00024: val_loss did not improve from 0.19287
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1998 - mean_absolute_error: 0.1998 - val_loss: 0.1948 - val_mean_absolute_error: 0.1948
# Epoch 25/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1990 - mean_absolute_error: 0.1990
# Epoch 00025: val_loss did not improve from 0.19287
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1990 - mean_absolute_error: 0.1990 - val_loss: 0.2010 - val_mean_absolute_error: 0.2010
# Epoch 26/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1974 - mean_absolute_error: 0.1974
# Epoch 00026: val_loss did not improve from 0.19287
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1974 - mean_absolute_error: 0.1974 - val_loss: 0.1991 - val_mean_absolute_error: 0.1991
# Epoch 27/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1974 - mean_absolute_error: 0.1974
# Epoch 00027: val_loss did not improve from 0.19287
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1974 - mean_absolute_error: 0.1974 - val_loss: 0.2019 - val_mean_absolute_error: 0.2019
# Epoch 28/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1976 - mean_absolute_error: 0.1976
# Epoch 00028: val_loss did not improve from 0.19287
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1976 - mean_absolute_error: 0.1976 - val_loss: 0.1949 - val_mean_absolute_error: 0.1949
# Epoch 29/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1964 - mean_absolute_error: 0.1964
# Epoch 00029: val_loss improved from 0.19287 to 0.18886, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1963 - mean_absolute_error: 0.1963 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889
# Epoch 30/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1962 - mean_absolute_error: 0.1962
# Epoch 00030: val_loss improved from 0.18886 to 0.18767, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1962 - mean_absolute_error: 0.1962 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877
# Epoch 31/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1959 - mean_absolute_error: 0.1959
# Epoch 00031: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1959 - mean_absolute_error: 0.1959 - val_loss: 0.1976 - val_mean_absolute_error: 0.1976
# Epoch 32/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1961 - mean_absolute_error: 0.1961
# Epoch 00032: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1961 - mean_absolute_error: 0.1961 - val_loss: 0.1964 - val_mean_absolute_error: 0.1964
# Epoch 33/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1954 - mean_absolute_error: 0.1954
# Epoch 00033: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1955 - mean_absolute_error: 0.1955 - val_loss: 0.1881 - val_mean_absolute_error: 0.1881
# Epoch 34/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1946 - mean_absolute_error: 0.1946
# Epoch 00034: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1946 - mean_absolute_error: 0.1946 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889
# Epoch 35/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1943 - mean_absolute_error: 0.1943
# Epoch 00035: val_loss did not improve from 0.18767
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1943 - mean_absolute_error: 0.1943 - val_loss: 0.1905 - val_mean_absolute_error: 0.1905
# Epoch 36/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1931 - mean_absolute_error: 0.1931
# Epoch 00036: val_loss did not improve from 0.18767
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1931 - mean_absolute_error: 0.1931 - val_loss: 0.1881 - val_mean_absolute_error: 0.1881
# Epoch 37/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1939 - mean_absolute_error: 0.1939
# Epoch 00037: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1939 - mean_absolute_error: 0.1939 - val_loss: 0.1930 - val_mean_absolute_error: 0.1930
# Epoch 38/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1939 - mean_absolute_error: 0.1939
# Epoch 00038: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1939 - mean_absolute_error: 0.1939 - val_loss: 0.1945 - val_mean_absolute_error: 0.1945
# Epoch 39/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1932 - mean_absolute_error: 0.1932
# Epoch 00039: val_loss did not improve from 0.18767
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1932 - mean_absolute_error: 0.1932 - val_loss: 0.1942 - val_mean_absolute_error: 0.1942
# Epoch 40/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1930 - mean_absolute_error: 0.1930
# Epoch 00040: val_loss improved from 0.18767 to 0.18718, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1930 - mean_absolute_error: 0.1930 - val_loss: 0.1872 - val_mean_absolute_error: 0.1872
# Epoch 41/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1932 - mean_absolute_error: 0.1932
# Epoch 00041: val_loss did not improve from 0.18718
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1932 - mean_absolute_error: 0.1932 - val_loss: 0.1886 - val_mean_absolute_error: 0.1886
# Epoch 42/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1925 - mean_absolute_error: 0.1925
# Epoch 00042: val_loss did not improve from 0.18718
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1926 - mean_absolute_error: 0.1926 - val_loss: 0.1956 - val_mean_absolute_error: 0.1956
# Epoch 43/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1925 - mean_absolute_error: 0.1925
# Epoch 00043: val_loss did not improve from 0.18718
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1925 - mean_absolute_error: 0.1925 - val_loss: 0.1900 - val_mean_absolute_error: 0.1900
# Epoch 44/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1921 - mean_absolute_error: 0.1921
# Epoch 00044: val_loss improved from 0.18718 to 0.18704, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1921 - mean_absolute_error: 0.1921 - val_loss: 0.1870 - val_mean_absolute_error: 0.1870
# Epoch 45/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1908 - mean_absolute_error: 0.1908
# Epoch 00045: val_loss did not improve from 0.18704
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1908 - mean_absolute_error: 0.1908 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 46/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1903 - mean_absolute_error: 0.1903
# Epoch 00046: val_loss did not improve from 0.18704
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1903 - mean_absolute_error: 0.1903 - val_loss: 0.1942 - val_mean_absolute_error: 0.1942
# Epoch 47/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1898 - mean_absolute_error: 0.1898
# Epoch 00047: val_loss improved from 0.18704 to 0.18524, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1898 - mean_absolute_error: 0.1898 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852
# Epoch 48/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1893 - mean_absolute_error: 0.1893
# Epoch 00048: val_loss did not improve from 0.18524
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1893 - mean_absolute_error: 0.1893 - val_loss: 0.1864 - val_mean_absolute_error: 0.1864
# Epoch 49/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1897 - mean_absolute_error: 0.1897
# Epoch 00049: val_loss improved from 0.18524 to 0.18366, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1897 - mean_absolute_error: 0.1897 - val_loss: 0.1837 - val_mean_absolute_error: 0.1837
# Epoch 50/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1889 - mean_absolute_error: 0.1889
# Epoch 00050: val_loss did not improve from 0.18366
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1889 - mean_absolute_error: 0.1889 - val_loss: 0.1849 - val_mean_absolute_error: 0.1849
# Epoch 51/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1889 - mean_absolute_error: 0.1889
# Epoch 00051: val_loss did not improve from 0.18366
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1889 - mean_absolute_error: 0.1889 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877
# Epoch 52/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1895 - mean_absolute_error: 0.1895
# Epoch 00052: val_loss did not improve from 0.18366
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1895 - mean_absolute_error: 0.1895 - val_loss: 0.1873 - val_mean_absolute_error: 0.1873
# Epoch 53/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1883 - mean_absolute_error: 0.1883
# Epoch 00053: val_loss did not improve from 0.18366
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1884 - mean_absolute_error: 0.1884 - val_loss: 0.1873 - val_mean_absolute_error: 0.1873
# Epoch 54/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1889 - mean_absolute_error: 0.1889
# Epoch 00054: val_loss did not improve from 0.18366
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1889 - mean_absolute_error: 0.1889 - val_loss: 0.1837 - val_mean_absolute_error: 0.1837
# Epoch 55/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1887 - mean_absolute_error: 0.1887
# Epoch 00055: val_loss did not improve from 0.18366
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1887 - mean_absolute_error: 0.1887 - val_loss: 0.1866 - val_mean_absolute_error: 0.1866
# Epoch 56/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1879 - mean_absolute_error: 0.1879
# Epoch 00056: val_loss improved from 0.18366 to 0.18324, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1879 - mean_absolute_error: 0.1879 - val_loss: 0.1832 - val_mean_absolute_error: 0.1832
# Epoch 57/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1877 - mean_absolute_error: 0.1877
# Epoch 00057: val_loss improved from 0.18324 to 0.18014, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1877 - mean_absolute_error: 0.1877 - val_loss: 0.1801 - val_mean_absolute_error: 0.1801
# Epoch 58/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1868 - mean_absolute_error: 0.1868
# Epoch 00058: val_loss improved from 0.18014 to 0.18005, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1868 - mean_absolute_error: 0.1868 - val_loss: 0.1801 - val_mean_absolute_error: 0.1801
# Epoch 59/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.1873
# Epoch 00059: val_loss did not improve from 0.18005
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 0.1811 - val_mean_absolute_error: 0.1811
# Epoch 60/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1875 - mean_absolute_error: 0.1875
# Epoch 00060: val_loss did not improve from 0.18005
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1875 - mean_absolute_error: 0.1875 - val_loss: 0.1806 - val_mean_absolute_error: 0.1806
# Epoch 61/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1887 - mean_absolute_error: 0.1887
# Epoch 00061: val_loss improved from 0.18005 to 0.17804, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1887 - mean_absolute_error: 0.1887 - val_loss: 0.1780 - val_mean_absolute_error: 0.1780
# Epoch 62/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1861 - mean_absolute_error: 0.1861
# Epoch 00062: val_loss did not improve from 0.17804
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - val_loss: 0.1860 - val_mean_absolute_error: 0.1860
# Epoch 63/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1879 - mean_absolute_error: 0.1879
# Epoch 00063: val_loss did not improve from 0.17804
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1879 - mean_absolute_error: 0.1879 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850
# Epoch 64/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.1870
# Epoch 00064: val_loss improved from 0.17804 to 0.17552, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 65/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1866 - mean_absolute_error: 0.1866
# Epoch 00065: val_loss did not improve from 0.17552
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1866 - mean_absolute_error: 0.1866 - val_loss: 0.1821 - val_mean_absolute_error: 0.1821
# Epoch 66/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1859 - mean_absolute_error: 0.1859
# Epoch 00066: val_loss did not improve from 0.17552
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1859 - mean_absolute_error: 0.1859 - val_loss: 0.1836 - val_mean_absolute_error: 0.1836
# Epoch 67/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1860 - mean_absolute_error: 0.1860
# Epoch 00067: val_loss did not improve from 0.17552
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1860 - mean_absolute_error: 0.1860 - val_loss: 0.1827 - val_mean_absolute_error: 0.1827
# Epoch 68/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1858 - mean_absolute_error: 0.1858
# Epoch 00068: val_loss did not improve from 0.17552
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1858 - mean_absolute_error: 0.1858 - val_loss: 0.1837 - val_mean_absolute_error: 0.1837
# Epoch 69/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1845 - mean_absolute_error: 0.1845
# Epoch 00069: val_loss did not improve from 0.17552
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1845 - mean_absolute_error: 0.1845 - val_loss: 0.1806 - val_mean_absolute_error: 0.1806
# Epoch 70/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.1870
# Epoch 00070: val_loss improved from 0.17552 to 0.17157, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.1716 - val_mean_absolute_error: 0.1716
# Epoch 71/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1857 - mean_absolute_error: 0.1857
# Epoch 00071: val_loss did not improve from 0.17157
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1857 - mean_absolute_error: 0.1857 - val_loss: 0.1773 - val_mean_absolute_error: 0.1773
# Epoch 72/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1847 - mean_absolute_error: 0.1847
# Epoch 00072: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1847 - mean_absolute_error: 0.1847 - val_loss: 0.1840 - val_mean_absolute_error: 0.1840
# Epoch 73/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1846 - mean_absolute_error: 0.1846
# Epoch 00073: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1845 - mean_absolute_error: 0.1845 - val_loss: 0.1765 - val_mean_absolute_error: 0.1765
# Epoch 74/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1849 - mean_absolute_error: 0.1849
# Epoch 00074: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1849 - mean_absolute_error: 0.1849 - val_loss: 0.1820 - val_mean_absolute_error: 0.1820
# Epoch 75/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1846 - mean_absolute_error: 0.1846
# Epoch 00075: val_loss did not improve from 0.17157
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1846 - mean_absolute_error: 0.1846 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 76/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1854 - mean_absolute_error: 0.1854
# Epoch 00076: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1853 - mean_absolute_error: 0.1853 - val_loss: 0.1761 - val_mean_absolute_error: 0.1761
# Epoch 77/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1847 - mean_absolute_error: 0.1847
# Epoch 00077: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1847 - mean_absolute_error: 0.1847 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 78/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1840 - mean_absolute_error: 0.1840
# Epoch 00078: val_loss did not improve from 0.17157
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1840 - mean_absolute_error: 0.1840 - val_loss: 0.1779 - val_mean_absolute_error: 0.1779
# Epoch 79/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1846 - mean_absolute_error: 0.1846
# Epoch 00079: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1846 - mean_absolute_error: 0.1846 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 80/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.1840 - mean_absolute_error: 0.1840
# Epoch 00080: val_loss did not improve from 0.17157
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1840 - mean_absolute_error: 0.1840 - val_loss: 0.1787 - val_mean_absolute_error: 0.1787
# Epoch 81/200
# 500/500 [==============================] - ETA: 0s - loss: 0.1837 - mean_absolute_error: 0.1837
# Epoch 00081: val_loss did not improve from 0.17157
# ...
# Epoch 9/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00009: val_loss did not improve from 0.21897
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 10/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00010: val_loss did not improve from 0.21897
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 11/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00011: val_loss did not improve from 0.21897
# 500/500 [==============================] - 42s 85ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192
# Epoch 12/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00012: val_loss did not improve from 0.21897
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 13/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00013: val_loss did not improve from 0.21897
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190
# Epoch 14/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00014: val_loss did not improve from 0.21897
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2193 - val_mean_absolute_error: 0.2193
# Epoch 15/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00015: val_loss did not improve from 0.21897
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192
# Epoch 16/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00016: val_loss did not improve from 0.21897
# 500/500 [==============================] - 43s 85ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 17/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00017: val_loss did not improve from 0.21897
# 500/500 [==============================] - 43s 87ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192
# Epoch 18/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00018: val_loss did not improve from 0.21897
# 500/500 [==============================] - 44s 87ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 19/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00019: val_loss did not improve from 0.21897
# 500/500 [==============================] - 44s 89ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190
# Epoch 20/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00020: val_loss did not improve from 0.21897
# 500/500 [==============================] - 44s 88ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2192 - val_mean_absolute_error: 0.2192
# Epoch 21/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00021: val_loss did not improve from 0.21897
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 22/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2263 - mean_absolute_error: 0.2263
# Epoch 00022: val_loss did not improve from 0.21897
# 500/500 [==============================] - 45s 90ms/step - loss: 0.2263 - mean_absolute_error: 0.2263 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 00022: early stopping
# Model for  6  angles
# Epoch 1/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2810 - mean_absolute_error: 0.2810
# Epoch 00001: val_loss improved from inf to 0.22707, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_6.h5
# 500/500 [==============================] - 46s 93ms/step - loss: 0.2810 - mean_absolute_error: 0.2810 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 2/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00002: val_loss improved from 0.22707 to 0.22705, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_6.h5
# 500/500 [==============================] - 45s 90ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 3/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00003: val_loss did not improve from 0.22705
# 500/500 [==============================] - 44s 87ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 4/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00004: val_loss did not improve from 0.22705
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 5/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00005: val_loss did not improve from 0.22705
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 6/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00006: val_loss did not improve from 0.22705
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 7/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00007: val_loss did not improve from 0.22705
# 500/500 [==============================] - 42s 83ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 8/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00008: val_loss did not improve from 0.22705
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 9/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00009: val_loss did not improve from 0.22705
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 10/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00010: val_loss did not improve from 0.22705
# 500/500 [==============================] - 41s 83ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 11/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00011: val_loss did not improve from 0.22705
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 12/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00012: val_loss improved from 0.22705 to 0.22702, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_6.h5
# 500/500 [==============================] - 43s 87ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 13/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00013: val_loss did not improve from 0.22702
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 14/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00014: val_loss did not improve from 0.22702
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 15/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00015: val_loss improved from 0.22702 to 0.22694, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_6.h5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2269 - val_mean_absolute_error: 0.2269
# Epoch 16/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00016: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 17/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00017: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 18/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00018: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 19/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00019: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 20/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00020: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 21/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00021: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2269 - val_mean_absolute_error: 0.2269
# Epoch 22/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00022: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2273 - val_mean_absolute_error: 0.2273
# Epoch 23/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00023: val_loss did not improve from 0.22694
# 500/500 [==============================] - 42s 83ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2270 - val_mean_absolute_error: 0.2270
# Epoch 24/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00024: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 25/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00025: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 26/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00026: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 27/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00027: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 28/200
# 499/500 [============================>.] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00028: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 29/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00029: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 30/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00030: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 31/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00031: val_loss did not improve from 0.22694
# 500/500 [==============================] - 41s 82ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 32/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00032: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 33/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00033: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 34/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00034: val_loss did not improve from 0.22694
# 500/500 [==============================] - 39s 79ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 35/200
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 - mean_absolute_error: 0.2226
# Epoch 00035: val_loss did not improve from 0.22694
# 500/500 [==============================] - 40s 81ms/step - loss: 0.2226 - mean_absolute_error: 0.2226 - val_loss: 0.2272 - val_mean_absolute_error: 0.2272
# Epoch 00035: early stopping

# %% [markdown]
# #### InceptionResNetV2 Model Fine-tuning

# %%
for k in range(5):
    i = k + 2
    base_model[i].trainable = True
    model[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 55,912,674
# Trainable params: 55,852,130
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1536)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 55,913,699
# Trainable params: 55,853,155
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 55,914,724
# Trainable params: 55,854,180
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1536)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 55,855,205
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1536)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 55,916,774
# Trainable params: 55,856,230
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
for k in range(5):
    i = 2 + k
    model[i].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
epochs = 100
history_ft = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history_ft[i] = model[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 00001: val_loss improved from 0.07132 to 0.07043, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 77s 154ms/step - loss: 0.1069 - mean_absolute_error: 0.1069 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 2/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1036 - mean_absolute_error: 0.1036
# Epoch 00002: val_loss did not improve from 0.07043
# 500/500 [==============================] - 74s 147ms/step - loss: 0.1036 - mean_absolute_error: 0.1036 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 3/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1006 - mean_absolute_error: 0.1006
# Epoch 00003: val_loss improved from 0.07043 to 0.06598, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1006 - mean_absolute_error: 0.1006 - val_loss: 0.0660 - val_mean_absolute_error: 0.0660
# Epoch 4/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0998 - mean_absolute_error: 0.0998
# Epoch 00004: val_loss did not improve from 0.06598
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0998 - mean_absolute_error: 0.0998 - val_loss: 0.0682 - val_mean_absolute_error: 0.0682
# Epoch 5/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0983 - mean_absolute_error: 0.0983
# Epoch 00005: val_loss did not improve from 0.06598
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0983 - mean_absolute_error: 0.0983 - val_loss: 0.0670 - val_mean_absolute_error: 0.0670
# Epoch 6/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0980 - mean_absolute_error: 0.0980
# Epoch 00006: val_loss did not improve from 0.06598
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - val_loss: 0.0678 - val_mean_absolute_error: 0.0678
# Epoch 7/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0973 - mean_absolute_error: 0.0973
# Epoch 00007: val_loss did not improve from 0.06598
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0973 - mean_absolute_error: 0.0973 - val_loss: 0.0680 - val_mean_absolute_error: 0.0680
# Epoch 8/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0952 - mean_absolute_error: 0.0952
# Epoch 00008: val_loss improved from 0.06598 to 0.06300, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630
# Epoch 9/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0955 - mean_absolute_error: 0.0955
# Epoch 00009: val_loss did not improve from 0.06300
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634
# Epoch 10/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0937 - mean_absolute_error: 0.0937
# Epoch 00010: val_loss improved from 0.06300 to 0.06281, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628
# Epoch 11/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0925 - mean_absolute_error: 0.0925
# Epoch 00011: val_loss improved from 0.06281 to 0.05885, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0925 - mean_absolute_error: 0.0925 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589
# Epoch 12/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0898 - mean_absolute_error: 0.0898
# Epoch 00012: val_loss did not improve from 0.05885
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 13/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0892 - mean_absolute_error: 0.0892
# Epoch 00013: val_loss did not improve from 0.05885
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617
# Epoch 14/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0883 - mean_absolute_error: 0.0883
# Epoch 00014: val_loss improved from 0.05885 to 0.05629, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0883 - mean_absolute_error: 0.0883 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563
# Epoch 15/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0880 - mean_absolute_error: 0.0880
# Epoch 00015: val_loss improved from 0.05629 to 0.05471, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547
# Epoch 16/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0851 - mean_absolute_error: 0.0851
# Epoch 00016: val_loss did not improve from 0.05471
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0851 - mean_absolute_error: 0.0851 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586
# Epoch 17/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0836 - mean_absolute_error: 0.0836
# Epoch 00017: val_loss improved from 0.05471 to 0.05299, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0836 - mean_absolute_error: 0.0836 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530
# Epoch 18/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0834 - mean_absolute_error: 0.0834
# Epoch 00018: val_loss did not improve from 0.05299
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0834 - mean_absolute_error: 0.0834 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559
# Epoch 19/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0818 - mean_absolute_error: 0.0818
# Epoch 00019: val_loss improved from 0.05299 to 0.05186, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0818 - mean_absolute_error: 0.0818 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519
# Epoch 20/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0819 - mean_absolute_error: 0.0819
# Epoch 00020: val_loss improved from 0.05186 to 0.04877, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0819 - mean_absolute_error: 0.0819 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488
# Epoch 21/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0793 - mean_absolute_error: 0.0793
# Epoch 00021: val_loss improved from 0.04877 to 0.04788, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0793 - mean_absolute_error: 0.0793 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479
# Epoch 22/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0789 - mean_absolute_error: 0.0789
# Epoch 00022: val_loss did not improve from 0.04788
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0789 - mean_absolute_error: 0.0789 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529
# Epoch 23/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0775 - mean_absolute_error: 0.0775
# Epoch 00023: val_loss did not improve from 0.04788
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0775 - mean_absolute_error: 0.0775 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523
# Epoch 24/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0768 - mean_absolute_error: 0.0768
# Epoch 00024: val_loss improved from 0.04788 to 0.04761, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0768 - mean_absolute_error: 0.0768 - val_loss: 0.0476 - val_mean_absolute_error: 0.0476
# Epoch 25/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0751 - mean_absolute_error: 0.0751
# Epoch 00025: val_loss improved from 0.04761 to 0.04193, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0751 - mean_absolute_error: 0.0751 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 26/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0729 - mean_absolute_error: 0.0729
# Epoch 00026: val_loss did not improve from 0.04193
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.0435 - val_mean_absolute_error: 0.0435
# Epoch 27/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0707 - mean_absolute_error: 0.0707
# Epoch 00027: val_loss did not improve from 0.04193
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445
# Epoch 28/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0679 - mean_absolute_error: 0.0679
# Epoch 00028: val_loss improved from 0.04193 to 0.03892, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.0389 - val_mean_absolute_error: 0.0389
# Epoch 29/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0669 - mean_absolute_error: 0.0669
# Epoch 00029: val_loss improved from 0.03892 to 0.03627, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0669 - mean_absolute_error: 0.0669 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363
# Epoch 30/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0656 - mean_absolute_error: 0.0656
# Epoch 00030: val_loss improved from 0.03627 to 0.03403, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - val_loss: 0.0340 - val_mean_absolute_error: 0.0340
# Epoch 31/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0637 - mean_absolute_error: 0.0637
# Epoch 00031: val_loss improved from 0.03403 to 0.03137, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0637 - mean_absolute_error: 0.0637 - val_loss: 0.0314 - val_mean_absolute_error: 0.0314
# Epoch 32/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0612 - mean_absolute_error: 0.0612
# Epoch 00032: val_loss did not improve from 0.03137
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0334 - val_mean_absolute_error: 0.0334
# Epoch 33/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0599 - mean_absolute_error: 0.0599
# Epoch 00033: val_loss improved from 0.03137 to 0.03025, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0599 - mean_absolute_error: 0.0599 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303
# Epoch 34/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0586 - mean_absolute_error: 0.0586
# Epoch 00034: val_loss did not improve from 0.03025
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0586 - mean_absolute_error: 0.0586 - val_loss: 0.0305 - val_mean_absolute_error: 0.0305
# Epoch 35/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0567 - mean_absolute_error: 0.0567
# Epoch 00035: val_loss improved from 0.03025 to 0.02948, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0567 - mean_absolute_error: 0.0567 - val_loss: 0.0295 - val_mean_absolute_error: 0.0295
# Epoch 36/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0546 - mean_absolute_error: 0.0546
# Epoch 00036: val_loss did not improve from 0.02948
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0308 - val_mean_absolute_error: 0.0308
# Epoch 37/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0535 - mean_absolute_error: 0.0535
# Epoch 00037: val_loss did not improve from 0.02948
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0535 - mean_absolute_error: 0.0535 - val_loss: 0.0303 - val_mean_absolute_error: 0.0303
# Epoch 38/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0521 - mean_absolute_error: 0.0521
# Epoch 00038: val_loss improved from 0.02948 to 0.02730, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0521 - mean_absolute_error: 0.0521 - val_loss: 0.0273 - val_mean_absolute_error: 0.0273
# Epoch 39/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0506 - mean_absolute_error: 0.0506
# Epoch 00039: val_loss improved from 0.02730 to 0.02369, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0506 - mean_absolute_error: 0.0506 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237
# Epoch 40/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0496 - mean_absolute_error: 0.0496
# Epoch 00040: val_loss did not improve from 0.02369
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0496 - mean_absolute_error: 0.0496 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238
# Epoch 41/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0491 - mean_absolute_error: 0.0491
# Epoch 00041: val_loss did not improve from 0.02369
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242
# Epoch 42/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0479 - mean_absolute_error: 0.0479
# Epoch 00042: val_loss did not improve from 0.02369
# 500/500 [==============================] - 74s 148ms/step - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.0256 - val_mean_absolute_error: 0.0256
# Epoch 43/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0460 - mean_absolute_error: 0.0460
# Epoch 00043: val_loss improved from 0.02369 to 0.02208, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221
# Epoch 44/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0460 - mean_absolute_error: 0.0460
# Epoch 00044: val_loss improved from 0.02208 to 0.02166, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 45/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0446 - mean_absolute_error: 0.0446
# Epoch 00045: val_loss improved from 0.02166 to 0.02103, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 46/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0434 - mean_absolute_error: 0.0434
# Epoch 00046: val_loss did not improve from 0.02103
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 47/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0425 - mean_absolute_error: 0.0425
# Epoch 00047: val_loss did not improve from 0.02103
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0425 - mean_absolute_error: 0.0425 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 48/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0417 - mean_absolute_error: 0.0417
# Epoch 00048: val_loss improved from 0.02103 to 0.01960, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 76s 153ms/step - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 49/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0411 - mean_absolute_error: 0.0411
# Epoch 00049: val_loss did not improve from 0.01960
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0411 - mean_absolute_error: 0.0411 - val_loss: 0.0243 - val_mean_absolute_error: 0.0243
# Epoch 50/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0406 - mean_absolute_error: 0.0406
# Epoch 00050: val_loss did not improve from 0.01960
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 51/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0400 - mean_absolute_error: 0.0400
# Epoch 00051: val_loss improved from 0.01960 to 0.01832, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183
# Epoch 52/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0393 - mean_absolute_error: 0.0393
# Epoch 00052: val_loss improved from 0.01832 to 0.01823, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 53/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0384 - mean_absolute_error: 0.0384
# Epoch 00053: val_loss did not improve from 0.01823
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0384 - mean_absolute_error: 0.0384 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 54/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0375 - mean_absolute_error: 0.0375
# Epoch 00054: val_loss did not improve from 0.01823
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185
# Epoch 55/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0369 - mean_absolute_error: 0.0369
# Epoch 00055: val_loss improved from 0.01823 to 0.01751, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0175 - val_mean_absolute_error: 0.0175
# Epoch 56/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0367 - mean_absolute_error: 0.0367
# Epoch 00056: val_loss did not improve from 0.01751
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193
# Epoch 57/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0359 - mean_absolute_error: 0.0359
# Epoch 00057: val_loss did not improve from 0.01751
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 58/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0358 - mean_absolute_error: 0.0358
# Epoch 00058: val_loss improved from 0.01751 to 0.01673, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167
# Epoch 59/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0355 - mean_absolute_error: 0.0355
# Epoch 00059: val_loss did not improve from 0.01673
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0173 - val_mean_absolute_error: 0.0173
# Epoch 60/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0346 - mean_absolute_error: 0.0346
# Epoch 00060: val_loss did not improve from 0.01673
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187
# Epoch 61/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0342 - mean_absolute_error: 0.0342
# Epoch 00061: val_loss did not improve from 0.01673
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 62/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0336 - mean_absolute_error: 0.0336
# Epoch 00062: val_loss improved from 0.01673 to 0.01528, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153
# Epoch 63/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0329 - mean_absolute_error: 0.0329
# Epoch 00063: val_loss did not improve from 0.01528
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166
# Epoch 64/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0327 - mean_absolute_error: 0.0327
# Epoch 00064: val_loss did not improve from 0.01528
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0164 - val_mean_absolute_error: 0.0164
# Epoch 65/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0329 - mean_absolute_error: 0.0329
# Epoch 00065: val_loss did not improve from 0.01528
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156
# Epoch 66/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0318 - mean_absolute_error: 0.0318
# Epoch 00066: val_loss improved from 0.01528 to 0.01488, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0149 - val_mean_absolute_error: 0.0149
# Epoch 67/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0318 - mean_absolute_error: 0.0318
# Epoch 00067: val_loss did not improve from 0.01488
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0162 - val_mean_absolute_error: 0.0162
# Epoch 68/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0313 - mean_absolute_error: 0.0313
# Epoch 00068: val_loss improved from 0.01488 to 0.01439, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0313 - mean_absolute_error: 0.0313 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144
# Epoch 69/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0311 - mean_absolute_error: 0.0311
# Epoch 00069: val_loss improved from 0.01439 to 0.01407, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0141 - val_mean_absolute_error: 0.0141
# Epoch 70/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0306 - mean_absolute_error: 0.0306
# Epoch 00070: val_loss did not improve from 0.01407
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153
# Epoch 71/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0305 - mean_absolute_error: 0.0305
# Epoch 00071: val_loss did not improve from 0.01407
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144
# Epoch 72/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0299 - mean_absolute_error: 0.0299
# Epoch 00072: val_loss improved from 0.01407 to 0.01336, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0134 - val_mean_absolute_error: 0.0134
# Epoch 73/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0296 - mean_absolute_error: 0.0296
# Epoch 00073: val_loss did not improve from 0.01336
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0152 - val_mean_absolute_error: 0.0152
# Epoch 74/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0298 - mean_absolute_error: 0.0298
# Epoch 00074: val_loss improved from 0.01336 to 0.01330, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133
# Epoch 75/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0290 - mean_absolute_error: 0.0290
# Epoch 00075: val_loss did not improve from 0.01330
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156
# Epoch 76/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0290 - mean_absolute_error: 0.0290
# Epoch 00076: val_loss improved from 0.01330 to 0.01329, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133
# Epoch 77/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0286 - mean_absolute_error: 0.0286
# Epoch 00077: val_loss did not improve from 0.01329
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0137 - val_mean_absolute_error: 0.0137
# Epoch 78/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0281 - mean_absolute_error: 0.0281
# Epoch 00078: val_loss did not improve from 0.01329
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156
# Epoch 79/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0281 - mean_absolute_error: 0.0281
# Epoch 00079: val_loss improved from 0.01329 to 0.01327, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133
# Epoch 80/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0279 - mean_absolute_error: 0.0279
# Epoch 00080: val_loss improved from 0.01327 to 0.01273, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0127 - val_mean_absolute_error: 0.0127
# Epoch 81/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0275 - mean_absolute_error: 0.0275
# Epoch 00081: val_loss did not improve from 0.01273
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135
# Epoch 82/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0275 - mean_absolute_error: 0.0275
# Epoch 00082: val_loss improved from 0.01273 to 0.01255, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126
# Epoch 83/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0270 - mean_absolute_error: 0.0270
# Epoch 00083: val_loss did not improve from 0.01255
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132
# Epoch 84/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0267 - mean_absolute_error: 0.0267
# Epoch 00084: val_loss did not improve from 0.01255
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0167 - val_mean_absolute_error: 0.0167
# Epoch 85/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0267 - mean_absolute_error: 0.0267
# Epoch 00085: val_loss did not improve from 0.01255
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0128 - val_mean_absolute_error: 0.0128
# Epoch 86/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0266 - mean_absolute_error: 0.0266
# Epoch 00086: val_loss improved from 0.01255 to 0.01212, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 149ms/step - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121
# Epoch 87/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0260 - mean_absolute_error: 0.0260
# Epoch 00087: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0164 - val_mean_absolute_error: 0.0164
# Epoch 88/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0263 - mean_absolute_error: 0.0263
# Epoch 00088: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0133 - val_mean_absolute_error: 0.0133
# Epoch 89/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0258 - mean_absolute_error: 0.0258
# Epoch 00089: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0131 - val_mean_absolute_error: 0.0131
# Epoch 90/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0253 - mean_absolute_error: 0.0253
# Epoch 00090: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126
# Epoch 91/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0254 - mean_absolute_error: 0.0254
# Epoch 00091: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0154 - val_mean_absolute_error: 0.0154
# Epoch 92/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0252 - mean_absolute_error: 0.0252
# Epoch 00092: val_loss did not improve from 0.01212
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122
# Epoch 93/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0249 - mean_absolute_error: 0.0249
# Epoch 00093: val_loss did not improve from 0.01212
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0154 - val_mean_absolute_error: 0.0154
# Epoch 94/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0249 - mean_absolute_error: 0.0249
# Epoch 00094: val_loss did not improve from 0.01212
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0144 - val_mean_absolute_error: 0.0144
# Epoch 95/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0243 - mean_absolute_error: 0.0243
# Epoch 00095: val_loss improved from 0.01212 to 0.01182, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0243 - mean_absolute_error: 0.0243 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118
# Epoch 96/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0241 - mean_absolute_error: 0.0241
# Epoch 00096: val_loss did not improve from 0.01182
# 500/500 [==============================] - 73s 146ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120
# Epoch 97/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0242 - mean_absolute_error: 0.0242
# Epoch 00097: val_loss improved from 0.01182 to 0.01178, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0242 - mean_absolute_error: 0.0242 - val_loss: 0.0118 - val_mean_absolute_error: 0.0118
# Epoch 98/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0240 - mean_absolute_error: 0.0240
# Epoch 00098: val_loss improved from 0.01178 to 0.01151, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_2.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - val_loss: 0.0115 - val_mean_absolute_error: 0.0115
# Epoch 99/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0240 - mean_absolute_error: 0.0240
# Epoch 00099: val_loss did not improve from 0.01151
# 500/500 [==============================] - 73s 147ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - val_loss: 0.0123 - val_mean_absolute_error: 0.0123
# Epoch 100/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0238 - mean_absolute_error: 0.0238
# Epoch 00100: val_loss did not improve from 0.01151
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0238 - mean_absolute_error: 0.0238 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126
# Model for  3  angles
# Epoch 1/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1801 - mean_absolute_error: 0.1801
# Epoch 00001: val_loss did not improve from 0.17157
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1801 - mean_absolute_error: 0.1801 - val_loss: 0.1734 - val_mean_absolute_error: 0.1734
# Epoch 2/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1764 - mean_absolute_error: 0.1764
# Epoch 00002: val_loss did not improve from 0.17157
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1764 - mean_absolute_error: 0.1764 - val_loss: 0.1744 - val_mean_absolute_error: 0.1744
# Epoch 3/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1752 - mean_absolute_error: 0.1752
# Epoch 00003: val_loss improved from 0.17157 to 0.17043, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 151ms/step - loss: 0.1752 - mean_absolute_error: 0.1752 - val_loss: 0.1704 - val_mean_absolute_error: 0.1704
# Epoch 4/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1726 - mean_absolute_error: 0.1726
# Epoch 00004: val_loss improved from 0.17043 to 0.16956, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1726 - mean_absolute_error: 0.1726 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
# Epoch 5/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1704 - mean_absolute_error: 0.1704
# Epoch 00005: val_loss improved from 0.16956 to 0.16791, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1704 - mean_absolute_error: 0.1704 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 6/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1698 - mean_absolute_error: 0.1698
# Epoch 00006: val_loss did not improve from 0.16791
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
# Epoch 7/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1684 - mean_absolute_error: 0.1684
# Epoch 00007: val_loss did not improve from 0.16791
# 500/500 [==============================] - 73s 146ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 8/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1661 - mean_absolute_error: 0.1661
# Epoch 00008: val_loss improved from 0.16791 to 0.16540, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 9/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1662 - mean_absolute_error: 0.1662
# Epoch 00009: val_loss did not improve from 0.16540
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1658 - val_mean_absolute_error: 0.1658
# Epoch 10/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1643 - mean_absolute_error: 0.1643
# Epoch 00010: val_loss improved from 0.16540 to 0.16251, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1625 - val_mean_absolute_error: 0.1625
# Epoch 11/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1631 - mean_absolute_error: 0.1631
# Epoch 00011: val_loss did not improve from 0.16251
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1631 - mean_absolute_error: 0.1631 - val_loss: 0.1629 - val_mean_absolute_error: 0.1629
# Epoch 12/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1629 - mean_absolute_error: 0.1629
# Epoch 00012: val_loss did not improve from 0.16251
# 500/500 [==============================] - 74s 147ms/step - loss: 0.1629 - mean_absolute_error: 0.1629 - val_loss: 0.1628 - val_mean_absolute_error: 0.1628
# Epoch 13/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1609 - mean_absolute_error: 0.1609
# Epoch 00013: val_loss improved from 0.16251 to 0.15979, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1609 - mean_absolute_error: 0.1609 - val_loss: 0.1598 - val_mean_absolute_error: 0.1598
# Epoch 14/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1604 - mean_absolute_error: 0.1604
# Epoch 00014: val_loss improved from 0.15979 to 0.15950, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1604 - mean_absolute_error: 0.1604 - val_loss: 0.1595 - val_mean_absolute_error: 0.1595
# Epoch 15/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1592 - mean_absolute_error: 0.1592
# Epoch 00015: val_loss improved from 0.15950 to 0.15871, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1592 - mean_absolute_error: 0.1592 - val_loss: 0.1587 - val_mean_absolute_error: 0.1587
# Epoch 16/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1593 - mean_absolute_error: 0.1593
# Epoch 00016: val_loss improved from 0.15871 to 0.15643, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1593 - mean_absolute_error: 0.1593 - val_loss: 0.1564 - val_mean_absolute_error: 0.1564
# Epoch 17/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1582 - mean_absolute_error: 0.1582
# Epoch 00017: val_loss improved from 0.15643 to 0.15625, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1582 - mean_absolute_error: 0.1582 - val_loss: 0.1563 - val_mean_absolute_error: 0.1563
# Epoch 18/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1571 - mean_absolute_error: 0.1571
# Epoch 00018: val_loss did not improve from 0.15625
# 500/500 [==============================] - 74s 147ms/step - loss: 0.1571 - mean_absolute_error: 0.1571 - val_loss: 0.1567 - val_mean_absolute_error: 0.1567
# Epoch 19/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1555 - mean_absolute_error: 0.1555
# Epoch 00019: val_loss improved from 0.15625 to 0.15407, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1555 - mean_absolute_error: 0.1555 - val_loss: 0.1541 - val_mean_absolute_error: 0.1541
# Epoch 20/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1558 - mean_absolute_error: 0.1558
# Epoch 00020: val_loss did not improve from 0.15407
# 500/500 [==============================] - 74s 147ms/step - loss: 0.1558 - mean_absolute_error: 0.1558 - val_loss: 0.1552 - val_mean_absolute_error: 0.1552
# Epoch 21/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1554 - mean_absolute_error: 0.1554
# Epoch 00021: val_loss did not improve from 0.15407
# 500/500 [==============================] - 74s 147ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.1550 - val_mean_absolute_error: 0.1550
# Epoch 22/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1543 - mean_absolute_error: 0.1543
# Epoch 00022: val_loss improved from 0.15407 to 0.15263, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1543 - mean_absolute_error: 0.1543 - val_loss: 0.1526 - val_mean_absolute_error: 0.1526
# Epoch 23/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1532 - mean_absolute_error: 0.1532
# Epoch 00023: val_loss did not improve from 0.15263
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.1529 - val_mean_absolute_error: 0.1529
# Epoch 24/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1532 - mean_absolute_error: 0.1532
# Epoch 00024: val_loss did not improve from 0.15263
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.1530 - val_mean_absolute_error: 0.1530
# Epoch 25/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1523 - mean_absolute_error: 0.1523
# Epoch 00025: val_loss did not improve from 0.15263
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1523 - mean_absolute_error: 0.1523 - val_loss: 0.1534 - val_mean_absolute_error: 0.1534
# Epoch 26/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1528 - mean_absolute_error: 0.1528
# Epoch 00026: val_loss improved from 0.15263 to 0.15116, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1528 - mean_absolute_error: 0.1528 - val_loss: 0.1512 - val_mean_absolute_error: 0.1512
# Epoch 27/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1520 - mean_absolute_error: 0.1520
# Epoch 00027: val_loss did not improve from 0.15116
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1518 - val_mean_absolute_error: 0.1518
# Epoch 28/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1503 - mean_absolute_error: 0.1503
# Epoch 00028: val_loss improved from 0.15116 to 0.15024, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# 500/500 [==============================] - 75s 150ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1502 - val_mean_absolute_error: 0.1502
# Epoch 29/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1510 - mean_absolute_error: 0.1510
# Epoch 00029: val_loss improved from 0.15024 to 0.14701, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_angles_tang_3.h5
# ...
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 51/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00051: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 52/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00052: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 53/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00053: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 54/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00054: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 55/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00055: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 56/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00056: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 57/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00057: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 58/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00058: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 59/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00059: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 60/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00060: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 61/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00061: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 62/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00062: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 63/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00063: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 64/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00064: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 65/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00065: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 66/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00066: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 67/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00067: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 68/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00068: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 69/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00069: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 70/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00070: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 71/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00071: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 72/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00072: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 73/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00073: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 74/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00074: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 75/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00075: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 76/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00076: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 77/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00077: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 78/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00078: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 79/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00079: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 80/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00080: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 81/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00081: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 146ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 82/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00082: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 83/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00083: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 84/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00084: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 85/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00085: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 86/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00086: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 87/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00087: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 88/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00088: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 89/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00089: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 90/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00090: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 91/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00091: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 92/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00092: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 93/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00093: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 148ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 94/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00094: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 95/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00095: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 96/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00096: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 146ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 97/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00097: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 98/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00098: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 99/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00099: val_loss did not improve from 0.22694
# 500/500 [==============================] - 74s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271
# Epoch 100/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2225 - mean_absolute_error: 0.2225
# Epoch 00100: val_loss did not improve from 0.22694
# 500/500 [==============================] - 73s 147ms/step - loss: 0.2225 - mean_absolute_error: 0.2225 - val_loss: 0.2271 - val_mean_absolute_error: 0.2271

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history[i+2].history['loss'])
    plt.plot(history[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history_ft[i+2].history['loss'])
    plt.plot(history_ft[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
