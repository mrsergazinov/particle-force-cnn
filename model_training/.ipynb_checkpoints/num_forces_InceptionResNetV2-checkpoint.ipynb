# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
from PIL.ImageOps import expand
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'val')
model_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                          'PhotoForceReconML', 'models', 'InceptionResNetV2_num_forces.h5')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels are inferred from the subdirectory names.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %%
# Define datagen and gaussian blur classes
gaussblur = GaussBlur(1)
datagen = ImageDataGenerator(
    rescale = 1 / 255,
    preprocessing_function = gaussblur.blur)

# %%
# Create directory iterator for reading in the data
datagen_flow_train = datagen.flow_from_directory(train_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
datagen_flow_val = datagen.flow_from_directory(val_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
# Out:
# Found 80000 images belonging to 5 classes.
# Found 20000 images belonging to 5 classes.

# %% [markdown]
# #### InceptionResNetV2 Model building

# %% [markdown]
# Convolutional neural network is defined and compiled in this step.

# %%
# Load XCEPTION model to be the base model
base_model = applications.InceptionResNetV2(
    include_top=False,
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(128, 128, 3))

# %%
# Freeze model weights
base_model.trainable = False
# Get output shape
base_model.output_shape
# Get model summary
base_model.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 63, 63, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 63, 63, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 63, 63, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 61, 61, 32)   9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 61, 61, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 61, 61, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 61, 61, 64)   18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 61, 61, 64)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 61, 61, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 30, 30, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 30, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 30, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 30, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 13, 13, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 13, 13, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 13, 13, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 13, 13, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 13, 13, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 13, 13, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 13, 13, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 13, 13, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 13, 13, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 13, 13, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 13, 13, 96)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 13, 13, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 13, 13, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 13, 13, 64)   12288       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 13, 13, 96)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 13, 13, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 13, 13, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 13, 13, 64)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 13, 13, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 13, 13, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 13, 13, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 13, 13, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 13, 13, 320)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 13, 13, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 13, 13, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 13, 13, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 13, 13, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 13, 13, 48)   13824       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 13, 13, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 13, 13, 48)   144         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 13, 13, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 13, 13, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 13, 13, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 13, 13, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 13, 13, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 13, 13, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 13, 13, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 13, 13, 64)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 13, 13, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 13, 13, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 13, 13, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 13, 13, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 13, 13, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 13, 13, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 13, 13, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 13, 13, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 13, 13, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 13, 13, 48)   13824       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 13, 13, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 13, 13, 48)   144         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 13, 13, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 13, 13, 48)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 13, 13, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 13, 13, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 13, 13, 64)   27648       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 13, 13, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 13, 13, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 13, 13, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 13, 13, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 13, 13, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 13, 13, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 13, 13, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 13, 13, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 13, 13, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 13, 13, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 13, 13, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 13, 13, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 13, 13, 48)   13824       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 13, 13, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 13, 13, 48)   144         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 13, 13, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 13, 13, 48)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 13, 13, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 13, 13, 32)   9216        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 13, 13, 64)   27648       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 13, 13, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 13, 13, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 13, 13, 64)   192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 13, 13, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 13, 13, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 13, 13, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 13, 13, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 13, 13, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 13, 13, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 13, 13, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 13, 13, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 13, 13, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 13, 13, 48)   13824       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 13, 13, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 13, 13, 48)   144         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 13, 13, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 13, 13, 48)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 13, 13, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 13, 13, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 13, 13, 64)   27648       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 13, 13, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 13, 13, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 13, 13, 64)   192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 13, 13, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 13, 13, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 13, 13, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 13, 13, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 13, 13, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 13, 13, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 13, 13, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 13, 13, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 13, 13, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 13, 13, 48)   13824       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 13, 13, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 13, 13, 48)   144         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 13, 13, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 13, 13, 48)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 13, 13, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 13, 13, 32)   9216        activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 13, 13, 64)   27648       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 13, 13, 32)   96          conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 13, 13, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 13, 13, 64)   192         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 13, 13, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 13, 13, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 13, 13, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 13, 13, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 13, 13, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 13, 13, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 13, 13, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 13, 13, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 13, 13, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 13, 13, 48)   13824       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 13, 13, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 13, 13, 48)   144         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 13, 13, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 13, 13, 48)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 13, 13, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 13, 13, 32)   9216        activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 13, 13, 64)   27648       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 13, 13, 32)   96          conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 13, 13, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 13, 13, 64)   192         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 13, 13, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 13, 13, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 13, 13, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 13, 13, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 13, 13, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 13, 13, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 13, 13, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 13, 13, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 13, 13, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 13, 13, 48)   13824       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 13, 13, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 13, 13, 48)   144         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 13, 13, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 13, 13, 48)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 13, 13, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 13, 13, 32)   9216        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 13, 13, 64)   27648       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 13, 13, 32)   96          conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 13, 13, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 13, 13, 64)   192         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 13, 13, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 13, 13, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 13, 13, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 13, 13, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 13, 13, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 13, 13, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 13, 13, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 13, 13, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 13, 13, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 13, 13, 48)   13824       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 13, 13, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 13, 13, 48)   144         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 13, 13, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 13, 13, 48)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 13, 13, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 13, 13, 32)   9216        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 13, 13, 64)   27648       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 13, 13, 32)   96          conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 13, 13, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 13, 13, 64)   192         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 13, 13, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 13, 13, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 13, 13, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 13, 13, 128)  0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 13, 13, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 13, 13, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 13, 13, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 13, 13, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 13, 13, 32)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 13, 13, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 13, 13, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 13, 13, 48)   13824       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 13, 13, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 13, 13, 48)   144         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 13, 13, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 13, 13, 48)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 13, 13, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 2, 2, 192)    576         conv2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 2, 2, 256)    768         conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 2, 2, 192)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 2, 2, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 2, 2, 448)    0           activation_183[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 2, 2, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 2, 2, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 2, 2, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 2, 2, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 2, 2, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 2, 2, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 2, 2, 224)    129024      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 2, 2, 224)    672         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 2, 2, 224)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 2, 2, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 2, 2, 256)    172032      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 2, 2, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 2, 2, 256)    768         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 2, 2, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 2, 2, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 2, 2, 448)    0           activation_187[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 2, 2, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 2, 2, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 2, 2, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 2, 2, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 2, 2, 192)    576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 2, 2, 192)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 2, 2, 224)    129024      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 2, 2, 224)    672         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 2, 2, 224)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 2, 2, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 2, 2, 256)    172032      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 2, 2, 192)    576         conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 2, 2, 256)    768         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 2, 2, 192)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 2, 2, 256)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 2, 2, 448)    0           activation_191[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 2, 2, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 2, 2, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 2, 2, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 2, 2, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 2, 2, 192)    576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 2, 2, 192)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 2, 2, 224)    129024      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 2, 2, 224)    672         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 2, 2, 224)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 2, 2, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 2, 2, 256)    172032      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 2, 2, 192)    576         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 2, 2, 256)    768         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 2, 2, 192)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 2, 2, 256)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 2, 2, 448)    0           activation_195[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 2, 2, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 2, 2, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 2, 2, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 2, 2, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 2, 2, 192)    576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 2, 2, 192)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 2, 2, 224)    129024      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 2, 2, 224)    672         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 2, 2, 224)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 2, 2, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 2, 2, 256)    172032      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 2, 2, 192)    576         conv2d_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 2, 2, 256)    768         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 2, 2, 192)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 2, 2, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 2, 2, 448)    0           activation_199[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 2, 2, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 2, 2, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 2, 2, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 2, 2, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 2, 2, 1536)   0           conv_7b_bn[0][0]
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 0
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
# Determine number of classes
num_classes = len(os.listdir(train_image_path))

# Define the model
inputs = Input(shape=(128, 128, 3))
x = base_model(inputs, training = False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 1,579,013
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %% [markdown]
# #### InceptionResNetV2 Model Training

# %% [markdown]
# The model is trained using Adam optimizer. The loss is defined to be categorical crossentropy. Best model selection across training epochs is implemented with model checkpoint tracking the validation loss. Early stopping is set with patience of 5 epochs.

# %%
# Compile model: define loss, optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(epsilon = 1e-07),
              loss='categorical_crossentropy', 
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose = 1, patience = 20)
mc = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 100

history = model.fit(datagen_flow_train,
                            epochs = epochs,
                            steps_per_epoch = len(datagen_flow_train),
                            validation_data = datagen_flow_val,
                            validation_steps = len(datagen_flow_val),
                            callbacks=[es, mc]
                           )
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8256 - categorical_crossentropy: 0.4417
# Epoch 00001: val_loss improved from inf to 0.29650, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.4417 - accuracy: 0.8256 - categorical_crossentropy: 0.4417 - val_loss: 0.2965 - val_accuracy: 0.8801 - val_categorical_crossentropy: 0.2965
# Epoch 2/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.8775 - categorical_crossentropy: 0.3044
# Epoch 00002: val_loss improved from 0.29650 to 0.27794, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.3044 - accuracy: 0.8775 - categorical_crossentropy: 0.3044 - val_loss: 0.2779 - val_accuracy: 0.9028 - val_categorical_crossentropy: 0.2779
# Epoch 3/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.8950 - categorical_crossentropy: 0.2677
# Epoch 00003: val_loss improved from 0.27794 to 0.27476, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 206s 82ms/step - loss: 0.2677 - accuracy: 0.8950 - categorical_crossentropy: 0.2677 - val_loss: 0.2748 - val_accuracy: 0.9111 - val_categorical_crossentropy: 0.2748
# Epoch 4/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9050 - categorical_crossentropy: 0.2430
# Epoch 00004: val_loss improved from 0.27476 to 0.27124, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 207s 83ms/step - loss: 0.2430 - accuracy: 0.9050 - categorical_crossentropy: 0.2430 - val_loss: 0.2712 - val_accuracy: 0.9086 - val_categorical_crossentropy: 0.2712
# Epoch 5/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9103 - categorical_crossentropy: 0.2286
# Epoch 00005: val_loss improved from 0.27124 to 0.26415, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.2286 - accuracy: 0.9103 - categorical_crossentropy: 0.2286 - val_loss: 0.2642 - val_accuracy: 0.9157 - val_categorical_crossentropy: 0.2642
# Epoch 6/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9169 - categorical_crossentropy: 0.2124
# Epoch 00006: val_loss improved from 0.26415 to 0.24975, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.2124 - accuracy: 0.9169 - categorical_crossentropy: 0.2124 - val_loss: 0.2498 - val_accuracy: 0.9174 - val_categorical_crossentropy: 0.2498
# Epoch 7/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9203 - categorical_crossentropy: 0.2026
# Epoch 00007: val_loss did not improve from 0.24975
# 2500/2500 [==============================] - 204s 82ms/step - loss: 0.2026 - accuracy: 0.9203 - categorical_crossentropy: 0.2026 - val_loss: 0.2579 - val_accuracy: 0.9201 - val_categorical_crossentropy: 0.2579
# Epoch 8/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9252 - categorical_crossentropy: 0.1941
# Epoch 00008: val_loss improved from 0.24975 to 0.24400, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.1941 - accuracy: 0.9252 - categorical_crossentropy: 0.1941 - val_loss: 0.2440 - val_accuracy: 0.9277 - val_categorical_crossentropy: 0.2440
# Epoch 9/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1836 - accuracy: 0.9299 - categorical_crossentropy: 0.1836
# Epoch 00009: val_loss did not improve from 0.24400
# 2500/2500 [==============================] - 204s 82ms/step - loss: 0.1836 - accuracy: 0.9299 - categorical_crossentropy: 0.1836 - val_loss: 0.2789 - val_accuracy: 0.9215 - val_categorical_crossentropy: 0.2789
# Epoch 10/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9315 - categorical_crossentropy: 0.1796
# Epoch 00010: val_loss improved from 0.24400 to 0.22856, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 206s 83ms/step - loss: 0.1796 - accuracy: 0.9315 - categorical_crossentropy: 0.1796 - val_loss: 0.2286 - val_accuracy: 0.9224 - val_categorical_crossentropy: 0.2286
# Epoch 11/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9340 - categorical_crossentropy: 0.1717
# Epoch 00011: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 207s 83ms/step - loss: 0.1717 - accuracy: 0.9340 - categorical_crossentropy: 0.1717 - val_loss: 0.2562 - val_accuracy: 0.9252 - val_categorical_crossentropy: 0.2562
# Epoch 12/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9358 - categorical_crossentropy: 0.1673
# Epoch 00012: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 206s 83ms/step - loss: 0.1673 - accuracy: 0.9358 - categorical_crossentropy: 0.1673 - val_loss: 0.3019 - val_accuracy: 0.9179 - val_categorical_crossentropy: 0.3019
# Epoch 13/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9376 - categorical_crossentropy: 0.1614
# Epoch 00013: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 207s 83ms/step - loss: 0.1614 - accuracy: 0.9376 - categorical_crossentropy: 0.1614 - val_loss: 0.2910 - val_accuracy: 0.9292 - val_categorical_crossentropy: 0.2910
# Epoch 14/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9402 - categorical_crossentropy: 0.1584
# Epoch 00014: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 203s 81ms/step - loss: 0.1584 - accuracy: 0.9402 - categorical_crossentropy: 0.1584 - val_loss: 0.2547 - val_accuracy: 0.9327 - val_categorical_crossentropy: 0.2547
# Epoch 15/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9409 - categorical_crossentropy: 0.1542
# Epoch 00015: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.1542 - accuracy: 0.9409 - categorical_crossentropy: 0.1542 - val_loss: 0.2944 - val_accuracy: 0.9268 - val_categorical_crossentropy: 0.2944
# Epoch 16/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9441 - categorical_crossentropy: 0.1465
# Epoch 00016: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 205s 82ms/step - loss: 0.1465 - accuracy: 0.9441 - categorical_crossentropy: 0.1465 - val_loss: 0.3110 - val_accuracy: 0.9301 - val_categorical_crossentropy: 0.3110
# Epoch 17/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9442 - categorical_crossentropy: 0.1461
# Epoch 00017: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 202s 81ms/step - loss: 0.1461 - accuracy: 0.9442 - categorical_crossentropy: 0.1461 - val_loss: 0.3310 - val_accuracy: 0.9352 - val_categorical_crossentropy: 0.3310
# Epoch 18/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9468 - categorical_crossentropy: 0.1411
# Epoch 00018: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 204s 81ms/step - loss: 0.1410 - accuracy: 0.9468 - categorical_crossentropy: 0.1410 - val_loss: 0.3317 - val_accuracy: 0.9325 - val_categorical_crossentropy: 0.3317
# Epoch 19/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1384 - accuracy: 0.9485 - categorical_crossentropy: 0.1384
# Epoch 00019: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1384 - accuracy: 0.9485 - categorical_crossentropy: 0.1384 - val_loss: 0.4170 - val_accuracy: 0.9331 - val_categorical_crossentropy: 0.4170
# Epoch 20/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9481 - categorical_crossentropy: 0.1358
# Epoch 00020: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1358 - accuracy: 0.9481 - categorical_crossentropy: 0.1358 - val_loss: 0.3318 - val_accuracy: 0.9374 - val_categorical_crossentropy: 0.3318
# Epoch 21/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9495 - categorical_crossentropy: 0.1334
# Epoch 00021: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1334 - accuracy: 0.9495 - categorical_crossentropy: 0.1334 - val_loss: 0.3709 - val_accuracy: 0.9352 - val_categorical_crossentropy: 0.3709
# Epoch 22/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9502 - categorical_crossentropy: 0.1300
# Epoch 00022: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 203s 81ms/step - loss: 0.1299 - accuracy: 0.9502 - categorical_crossentropy: 0.1299 - val_loss: 0.3620 - val_accuracy: 0.9388 - val_categorical_crossentropy: 0.3620
# Epoch 23/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9513 - categorical_crossentropy: 0.1301
# Epoch 00023: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1301 - accuracy: 0.9513 - categorical_crossentropy: 0.1301 - val_loss: 0.3016 - val_accuracy: 0.9294 - val_categorical_crossentropy: 0.3016
# Epoch 24/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9526 - categorical_crossentropy: 0.1249
# Epoch 00024: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1249 - accuracy: 0.9526 - categorical_crossentropy: 0.1249 - val_loss: 0.3255 - val_accuracy: 0.9276 - val_categorical_crossentropy: 0.3255
# Epoch 25/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9540 - categorical_crossentropy: 0.1234
# Epoch 00025: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 202s 81ms/step - loss: 0.1234 - accuracy: 0.9540 - categorical_crossentropy: 0.1234 - val_loss: 0.2805 - val_accuracy: 0.9360 - val_categorical_crossentropy: 0.2805
# Epoch 26/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9548 - categorical_crossentropy: 0.1208
# Epoch 00026: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 200s 80ms/step - loss: 0.1208 - accuracy: 0.9548 - categorical_crossentropy: 0.1208 - val_loss: 0.3509 - val_accuracy: 0.9354 - val_categorical_crossentropy: 0.3509
# Epoch 27/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9544 - categorical_crossentropy: 0.1234
# Epoch 00027: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 204s 81ms/step - loss: 0.1234 - accuracy: 0.9544 - categorical_crossentropy: 0.1234 - val_loss: 0.4171 - val_accuracy: 0.9416 - val_categorical_crossentropy: 0.4171
# Epoch 28/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9553 - categorical_crossentropy: 0.1197
# Epoch 00028: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 202s 81ms/step - loss: 0.1197 - accuracy: 0.9553 - categorical_crossentropy: 0.1197 - val_loss: 0.4553 - val_accuracy: 0.9377 - val_categorical_crossentropy: 0.4553
# Epoch 29/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9570 - categorical_crossentropy: 0.1164
# Epoch 00029: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 202s 81ms/step - loss: 0.1164 - accuracy: 0.9570 - categorical_crossentropy: 0.1164 - val_loss: 0.5184 - val_accuracy: 0.9347 - val_categorical_crossentropy: 0.5184
# Epoch 30/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1161 - accuracy: 0.9568 - categorical_crossentropy: 0.1161
# Epoch 00030: val_loss did not improve from 0.22856
# 2500/2500 [==============================] - 202s 81ms/step - loss: 0.1161 - accuracy: 0.9568 - categorical_crossentropy: 0.1161 - val_loss: 0.4097 - val_accuracy: 0.9324 - val_categorical_crossentropy: 0.4097
# Epoch 00030: early stopping

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# #### InceptionResNetV2 Model Fine-tuning

# %%
base_model.trainable = True
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 55,855,205
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
# Compile model: define loss, optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-06, epsilon = 1e-07),
              loss='categorical_crossentropy', 
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 100

history_tune = model.fit(datagen_flow_train,
                            epochs = epochs,
                            steps_per_epoch = len(datagen_flow_train),
                            validation_data = datagen_flow_val,
                            validation_steps = len(datagen_flow_val),
                            callbacks=[es, mc]
                           )
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9768 - categorical_crossentropy: 0.0623
# Epoch 00001: val_loss improved from inf to 0.31889, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 367s 147ms/step - loss: 0.0623 - accuracy: 0.9768 - categorical_crossentropy: 0.0623 - val_loss: 0.3189 - val_accuracy: 0.9628 - val_categorical_crossentropy: 0.3189
# Epoch 2/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9891 - categorical_crossentropy: 0.0285
# Epoch 00002: val_loss improved from 0.31889 to 0.29566, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 366s 146ms/step - loss: 0.0285 - accuracy: 0.9891 - categorical_crossentropy: 0.0285 - val_loss: 0.2957 - val_accuracy: 0.9707 - val_categorical_crossentropy: 0.2957
# Epoch 3/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9937 - categorical_crossentropy: 0.0176
# Epoch 00003: val_loss improved from 0.29566 to 0.15930, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 365s 146ms/step - loss: 0.0176 - accuracy: 0.9937 - categorical_crossentropy: 0.0176 - val_loss: 0.1593 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1593
# Epoch 4/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9960 - categorical_crossentropy: 0.0109
# Epoch 00004: val_loss did not improve from 0.15930
# 2500/2500 [==============================] - 364s 146ms/step - loss: 0.0109 - accuracy: 0.9960 - categorical_crossentropy: 0.0109 - val_loss: 0.2016 - val_accuracy: 0.9793 - val_categorical_crossentropy: 0.2016
# Epoch 5/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9970 - categorical_crossentropy: 0.0087
# Epoch 00005: val_loss did not improve from 0.15930
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0087 - accuracy: 0.9970 - categorical_crossentropy: 0.0087 - val_loss: 0.2849 - val_accuracy: 0.9801 - val_categorical_crossentropy: 0.2849
# Epoch 6/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9975 - categorical_crossentropy: 0.0067
# Epoch 00006: val_loss improved from 0.15930 to 0.12825, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 364s 146ms/step - loss: 0.0067 - accuracy: 0.9975 - categorical_crossentropy: 0.0067 - val_loss: 0.1283 - val_accuracy: 0.9823 - val_categorical_crossentropy: 0.1283
# Epoch 7/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9981 - categorical_crossentropy: 0.0051
# Epoch 00007: val_loss did not improve from 0.12825
# 2500/2500 [==============================] - 364s 146ms/step - loss: 0.0051 - accuracy: 0.9981 - categorical_crossentropy: 0.0051 - val_loss: 0.2460 - val_accuracy: 0.9848 - val_categorical_crossentropy: 0.2460
# Epoch 8/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9983 - categorical_crossentropy: 0.0049
# Epoch 00008: val_loss did not improve from 0.12825
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0049 - accuracy: 0.9983 - categorical_crossentropy: 0.0049 - val_loss: 0.1953 - val_accuracy: 0.9851 - val_categorical_crossentropy: 0.1953
# Epoch 9/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9984 - categorical_crossentropy: 0.0044
# Epoch 00009: val_loss did not improve from 0.12825
# 2500/2500 [==============================] - 364s 145ms/step - loss: 0.0044 - accuracy: 0.9984 - categorical_crossentropy: 0.0044 - val_loss: 0.1570 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.1570
# Epoch 10/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9988 - categorical_crossentropy: 0.0034
# Epoch 00010: val_loss improved from 0.12825 to 0.08419, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 365s 146ms/step - loss: 0.0034 - accuracy: 0.9988 - categorical_crossentropy: 0.0034 - val_loss: 0.0842 - val_accuracy: 0.9886 - val_categorical_crossentropy: 0.0842
# Epoch 11/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9987 - categorical_crossentropy: 0.0034
# Epoch 00011: val_loss did not improve from 0.08419
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0034 - accuracy: 0.9987 - categorical_crossentropy: 0.0034 - val_loss: 0.1472 - val_accuracy: 0.9880 - val_categorical_crossentropy: 0.1472
# Epoch 12/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991 - categorical_crossentropy: 0.0025
# Epoch 00012: val_loss did not improve from 0.08419
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0025 - accuracy: 0.9991 - categorical_crossentropy: 0.0025 - val_loss: 0.2154 - val_accuracy: 0.9869 - val_categorical_crossentropy: 0.2154
# Epoch 13/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9991 - categorical_crossentropy: 0.0031
# Epoch 00013: val_loss did not improve from 0.08419
# 2500/2500 [==============================] - 362s 145ms/step - loss: 0.0031 - accuracy: 0.9991 - categorical_crossentropy: 0.0031 - val_loss: 0.2036 - val_accuracy: 0.9876 - val_categorical_crossentropy: 0.2036
# Epoch 14/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995 - categorical_crossentropy: 0.0016
# Epoch 00014: val_loss did not improve from 0.08419
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0016 - accuracy: 0.9995 - categorical_crossentropy: 0.0016 - val_loss: 0.2418 - val_accuracy: 0.9837 - val_categorical_crossentropy: 0.2418
# Epoch 15/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992 - categorical_crossentropy: 0.0025
# Epoch 00015: val_loss did not improve from 0.08419
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0025 - accuracy: 0.9992 - categorical_crossentropy: 0.0025 - val_loss: 0.1155 - val_accuracy: 0.9891 - val_categorical_crossentropy: 0.1155
# Epoch 16/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018
# Epoch 00016: val_loss improved from 0.08419 to 0.07389, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 364s 146ms/step - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018 - val_loss: 0.0739 - val_accuracy: 0.9929 - val_categorical_crossentropy: 0.0739
# Epoch 17/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995 - categorical_crossentropy: 0.0020
# Epoch 00017: val_loss did not improve from 0.07389
# 2500/2500 [==============================] - 364s 145ms/step - loss: 0.0020 - accuracy: 0.9995 - categorical_crossentropy: 0.0020 - val_loss: 0.1245 - val_accuracy: 0.9883 - val_categorical_crossentropy: 0.1245
# Epoch 18/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018
# Epoch 00018: val_loss did not improve from 0.07389
# 2500/2500 [==============================] - 362s 145ms/step - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018 - val_loss: 0.0779 - val_accuracy: 0.9922 - val_categorical_crossentropy: 0.0779
# Epoch 19/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996 - categorical_crossentropy: 0.0016
# Epoch 00019: val_loss did not improve from 0.07389
# 2500/2500 [==============================] - 363s 145ms/step - loss: 0.0016 - accuracy: 0.9996 - categorical_crossentropy: 0.0016 - val_loss: 0.2641 - val_accuracy: 0.9870 - val_categorical_crossentropy: 0.2641
# Epoch 20/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995 - categorical_crossentropy: 0.0015
# Epoch 00020: val_loss did not improve from 0.07389
# 2500/2500 [==============================] - 362s 145ms/step - loss: 0.0015 - accuracy: 0.9995 - categorical_crossentropy: 0.0015 - val_loss: 0.1163 - val_accuracy: 0.9905 - val_categorical_crossentropy: 0.1163
# Epoch 21/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018
# Epoch 00021: val_loss improved from 0.07389 to 0.03759, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 364s 145ms/step - loss: 0.0018 - accuracy: 0.9994 - categorical_crossentropy: 0.0018 - val_loss: 0.0376 - val_accuracy: 0.9942 - val_categorical_crossentropy: 0.0376
# Epoch 22/100
# 2500/2500 [==============================] - ETA: 0s - loss: 8.4247e-04 - accuracy: 0.9997 - categorical_crossentropy: 8.4247e-04
# Epoch 00022: val_loss did not improve from 0.03759
# 2500/2500 [==============================] - 363s 145ms/step - loss: 8.4247e-04 - accuracy: 0.9997 - categorical_crossentropy: 8.4247e-04 - val_loss: 0.0957 - val_accuracy: 0.9907 - val_categorical_crossentropy: 0.0957
# Epoch 23/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996 - categorical_crossentropy: 0.0012
# Epoch 00023: val_loss did not improve from 0.03759
# 2500/2500 [==============================] - 362s 145ms/step - loss: 0.0012 - accuracy: 0.9996 - categorical_crossentropy: 0.0012 - val_loss: 0.0627 - val_accuracy: 0.9931 - val_categorical_crossentropy: 0.0627
# Epoch 24/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997 - categorical_crossentropy: 0.0011
# Epoch 00024: val_loss did not improve from 0.03759
# 2500/2500 [==============================] - 362s 145ms/step - loss: 0.0011 - accuracy: 0.9997 - categorical_crossentropy: 0.0011 - val_loss: 0.0900 - val_accuracy: 0.9915 - val_categorical_crossentropy: 0.0900
# Epoch 25/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996 - categorical_crossentropy: 0.0011
# Epoch 00025: val_loss did not improve from 0.03759
# 2500/2500 [==============================] - 367s 147ms/step - loss: 0.0011 - accuracy: 0.9996 - categorical_crossentropy: 0.0011 - val_loss: 0.1193 - val_accuracy: 0.9901 - val_categorical_crossentropy: 0.1193
# Epoch 26/100
# 2500/2500 [==============================] - ETA: 0s - loss: 9.9139e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.9139e-04
# Epoch 00026: val_loss did not improve from 0.03759
# 2500/2500 [==============================] - 371s 148ms/step - loss: 9.9139e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.9139e-04 - val_loss: 0.1788 - val_accuracy: 0.9882 - val_categorical_crossentropy: 0.1788
# Epoch 27/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997 - categorical_crossentropy: 0.0012
# Epoch 00027: val_loss improved from 0.03759 to 0.03176, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/InceptionResNetV2_num_forces.h5
# 2500/2500 [==============================] - 372s 149ms/step - loss: 0.0012 - accuracy: 0.9997 - categorical_crossentropy: 0.0012 - val_loss: 0.0318 - val_accuracy: 0.9956 - val_categorical_crossentropy: 0.0318
# Epoch 28/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996 - categorical_crossentropy: 0.0010
# Epoch 00028: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 369s 147ms/step - loss: 0.0010 - accuracy: 0.9996 - categorical_crossentropy: 0.0010 - val_loss: 0.2235 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.2235
# Epoch 29/100
# 2500/2500 [==============================] - ETA: 0s - loss: 9.0087e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.0087e-04
# Epoch 00029: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 9.0087e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.0087e-04 - val_loss: 0.1324 - val_accuracy: 0.9908 - val_categorical_crossentropy: 0.1324
# Epoch 30/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996 - categorical_crossentropy: 0.0014
# Epoch 00030: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 0.0014 - accuracy: 0.9996 - categorical_crossentropy: 0.0014 - val_loss: 0.1158 - val_accuracy: 0.9918 - val_categorical_crossentropy: 0.1158
# Epoch 31/100
# 2500/2500 [==============================] - ETA: 0s - loss: 6.6177e-04 - accuracy: 0.9998 - categorical_crossentropy: 6.6177e-04
# Epoch 00031: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 6.6177e-04 - accuracy: 0.9998 - categorical_crossentropy: 6.6177e-04 - val_loss: 0.0443 - val_accuracy: 0.9942 - val_categorical_crossentropy: 0.0443
# Epoch 32/100
# 2500/2500 [==============================] - ETA: 0s - loss: 7.9451e-04 - accuracy: 0.9998 - categorical_crossentropy: 7.9451e-04
# Epoch 00032: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 7.9451e-04 - accuracy: 0.9998 - categorical_crossentropy: 7.9451e-04 - val_loss: 0.1174 - val_accuracy: 0.9907 - val_categorical_crossentropy: 0.1174
# Epoch 33/100
# 2500/2500 [==============================] - ETA: 0s - loss: 9.4191e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.4191e-04
# Epoch 00033: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 9.4191e-04 - accuracy: 0.9997 - categorical_crossentropy: 9.4191e-04 - val_loss: 0.0628 - val_accuracy: 0.9927 - val_categorical_crossentropy: 0.0628
# Epoch 34/100
# 2500/2500 [==============================] - ETA: 0s - loss: 6.8405e-04 - accuracy: 0.9998 - categorical_crossentropy: 6.8405e-04
# Epoch 00034: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 369s 147ms/step - loss: 6.8405e-04 - accuracy: 0.9998 - categorical_crossentropy: 6.8405e-04 - val_loss: 0.1003 - val_accuracy: 0.9917 - val_categorical_crossentropy: 0.1003
# Epoch 35/100
# 2500/2500 [==============================] - ETA: 0s - loss: 8.2043e-04 - accuracy: 0.9997 - categorical_crossentropy: 8.2043e-04
# Epoch 00035: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 369s 147ms/step - loss: 8.2043e-04 - accuracy: 0.9997 - categorical_crossentropy: 8.2043e-04 - val_loss: 0.0463 - val_accuracy: 0.9945 - val_categorical_crossentropy: 0.0463
# Epoch 36/100
# 2500/2500 [==============================] - ETA: 0s - loss: 3.4392e-04 - accuracy: 0.9999 - categorical_crossentropy: 3.4392e-04
# Epoch 00036: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 368s 147ms/step - loss: 3.4392e-04 - accuracy: 0.9999 - categorical_crossentropy: 3.4392e-04 - val_loss: 0.1998 - val_accuracy: 0.9883 - val_categorical_crossentropy: 0.1998
# Epoch 37/100
# 2500/2500 [==============================] - ETA: 0s - loss: 9.1164e-04 - accuracy: 0.9998 - categorical_crossentropy: 9.1164e-04
# Epoch 00037: val_loss did not improve from 0.03176
# 2500/2500 [==============================] - 369s 148ms/step - loss: 9.1164e-04 - accuracy: 0.9998 - categorical_crossentropy: 9.1164e-04 - val_loss: 0.0467 - val_accuracy: 0.9956 - val_categorical_crossentropy: 0.0467
# Epoch 00037: early stopping

# %%
plt.plot(history_tune.history['loss'])
plt.plot(history_tune.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history_tune.history['accuracy'])
plt.plot(history_tune.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
