# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
from PIL.ImageOps import expand
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '400', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '400', 'val')
load_model_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                               'PhotoForceReconML', 'models', 'vgg19_num_forces.h5')
save_model_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                               'PhotoForceReconML', 'models', 'small', '400', 'vgg19_num_forces.h5')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels are inferred from the subdirectory names.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# Define gaussian blur class
class GaussBlur:
    def __init__(self, radius):
        self.radius = radius
    def blur(self, image):
        return gaussian_filter(image, sigma = self.radius)

# %%
# Define datagen and gaussian blur classes
gaussblur = GaussBlur(1)
datagen = ImageDataGenerator(
    rescale = 1 / 255,
    preprocessing_function = gaussblur.blur)

# %%
# Create directory iterator for reading in the data
datagen_flow_train = datagen.flow_from_directory(train_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
datagen_flow_val = datagen.flow_from_directory(val_image_path, 
                                         target_size = (128, 128),
                                         color_mode = "rgb",
                                         class_mode = "categorical",
                                         batch_size = 32,
                                         shuffle = True,
                                         seed = None,
                                         follow_links = False,
                                         interpolation = "nearest")
# Out:
# Found 1600 images belonging to 5 classes.
# Found 400 images belonging to 5 classes.

# %% [markdown]
# #### VGG19 Model building

# %% [markdown]
# Convolutional neural network is loaded (pre-trained) and compiled in this step.

# %%
# Load VGG19 model to be the base model
model = load_model(load_model_path)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 20,554,821
# Trainable params: 20,554,821
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### VGG19 Model Training

# %% [markdown]
# The model is trained using Adam optimizer. The loss is defined to be categorical crossentropy. Best model selection across training epochs is implemented with model checkpoint tracking the validation loss. Early stopping is set with patience of 20 epochs.

# %%
# Compile model: define loss, optimizer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-06, epsilon = 1e-07),
              loss='categorical_crossentropy', 
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint(save_model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 1000

history = model.fit(datagen_flow_train,
                            epochs = epochs,
                            steps_per_epoch = len(datagen_flow_train),
                            validation_data = datagen_flow_val,
                            validation_steps = len(datagen_flow_val),
                            callbacks=[es, mc]
                           )
# Out:
# Epoch 1/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.0360 - accuracy: 0.8419 - categorical_crossentropy: 3.0360
# Epoch 00001: val_loss improved from inf to 0.14097, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 28s 558ms/step - loss: 3.0360 - accuracy: 0.8419 - categorical_crossentropy: 3.0360 - val_loss: 0.1410 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1410
# Epoch 2/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.4613 - accuracy: 0.9481 - categorical_crossentropy: 0.4613
# Epoch 00002: val_loss improved from 0.14097 to 0.14075, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 117ms/step - loss: 0.4613 - accuracy: 0.9481 - categorical_crossentropy: 0.4613 - val_loss: 0.1407 - val_accuracy: 0.9725 - val_categorical_crossentropy: 0.1407
# Epoch 3/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.2502 - accuracy: 0.9606 - categorical_crossentropy: 0.2502
# Epoch 00003: val_loss improved from 0.14075 to 0.09100, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 115ms/step - loss: 0.2502 - accuracy: 0.9606 - categorical_crossentropy: 0.2502 - val_loss: 0.0910 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0910
# Epoch 4/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9650 - categorical_crossentropy: 0.2084
# Epoch 00004: val_loss did not improve from 0.09100
# 50/50 [==============================] - 6s 110ms/step - loss: 0.2084 - accuracy: 0.9650 - categorical_crossentropy: 0.2084 - val_loss: 0.0927 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0927
# Epoch 5/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9744 - categorical_crossentropy: 0.1168
# Epoch 00005: val_loss did not improve from 0.09100
# 50/50 [==============================] - 6s 111ms/step - loss: 0.1168 - accuracy: 0.9744 - categorical_crossentropy: 0.1168 - val_loss: 0.0986 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0986
# Epoch 6/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9787 - categorical_crossentropy: 0.0906
# Epoch 00006: val_loss did not improve from 0.09100
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0906 - accuracy: 0.9787 - categorical_crossentropy: 0.0906 - val_loss: 0.1584 - val_accuracy: 0.9675 - val_categorical_crossentropy: 0.1584
# Epoch 7/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9831 - categorical_crossentropy: 0.0642
# Epoch 00007: val_loss did not improve from 0.09100
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0642 - accuracy: 0.9831 - categorical_crossentropy: 0.0642 - val_loss: 0.0996 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0996
# Epoch 8/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9825 - categorical_crossentropy: 0.0630
# Epoch 00008: val_loss did not improve from 0.09100
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0630 - accuracy: 0.9825 - categorical_crossentropy: 0.0630 - val_loss: 0.1161 - val_accuracy: 0.9750 - val_categorical_crossentropy: 0.1161
# Epoch 9/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9850 - categorical_crossentropy: 0.0539
# Epoch 00009: val_loss improved from 0.09100 to 0.07054, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 117ms/step - loss: 0.0539 - accuracy: 0.9850 - categorical_crossentropy: 0.0539 - val_loss: 0.0705 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.0705
# Epoch 10/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9881 - categorical_crossentropy: 0.0448
# Epoch 00010: val_loss improved from 0.07054 to 0.06482, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 115ms/step - loss: 0.0448 - accuracy: 0.9881 - categorical_crossentropy: 0.0448 - val_loss: 0.0648 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.0648
# Epoch 11/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9956 - categorical_crossentropy: 0.0122
# Epoch 00011: val_loss improved from 0.06482 to 0.03542, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 117ms/step - loss: 0.0122 - accuracy: 0.9956 - categorical_crossentropy: 0.0122 - val_loss: 0.0354 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0354
# Epoch 12/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9925 - categorical_crossentropy: 0.0285
# Epoch 00012: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0285 - accuracy: 0.9925 - categorical_crossentropy: 0.0285 - val_loss: 0.1265 - val_accuracy: 0.9725 - val_categorical_crossentropy: 0.1265
# Epoch 13/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9931 - categorical_crossentropy: 0.0191
# Epoch 00013: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0191 - accuracy: 0.9931 - categorical_crossentropy: 0.0191 - val_loss: 0.0859 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0859
# Epoch 14/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9919 - categorical_crossentropy: 0.0161
# Epoch 00014: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0161 - accuracy: 0.9919 - categorical_crossentropy: 0.0161 - val_loss: 0.0791 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0791
# Epoch 15/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9950 - categorical_crossentropy: 0.0161
# Epoch 00015: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0161 - accuracy: 0.9950 - categorical_crossentropy: 0.0161 - val_loss: 0.0871 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0871
# Epoch 16/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9969 - categorical_crossentropy: 0.0118
# Epoch 00016: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0118 - accuracy: 0.9969 - categorical_crossentropy: 0.0118 - val_loss: 0.0608 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0608
# Epoch 17/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9956 - categorical_crossentropy: 0.0122
# Epoch 00017: val_loss did not improve from 0.03542
# 50/50 [==============================] - 6s 112ms/step - loss: 0.0122 - accuracy: 0.9956 - categorical_crossentropy: 0.0122 - val_loss: 0.1288 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1288
# Epoch 18/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9956 - categorical_crossentropy: 0.0139
# Epoch 00018: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0139 - accuracy: 0.9956 - categorical_crossentropy: 0.0139 - val_loss: 0.0357 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0357
# Epoch 19/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9950 - categorical_crossentropy: 0.0124
# Epoch 00019: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0124 - accuracy: 0.9950 - categorical_crossentropy: 0.0124 - val_loss: 0.0801 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0801
# Epoch 20/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9962 - categorical_crossentropy: 0.0066
# Epoch 00020: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0066 - accuracy: 0.9962 - categorical_crossentropy: 0.0066 - val_loss: 0.1329 - val_accuracy: 0.9725 - val_categorical_crossentropy: 0.1329
# Epoch 21/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987 - categorical_crossentropy: 0.0054
# Epoch 00021: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0054 - accuracy: 0.9987 - categorical_crossentropy: 0.0054 - val_loss: 0.1111 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1111
# Epoch 22/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9975 - categorical_crossentropy: 0.0056
# Epoch 00022: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0056 - accuracy: 0.9975 - categorical_crossentropy: 0.0056 - val_loss: 0.0425 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0425
# Epoch 23/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9994 - categorical_crossentropy: 0.0041
# Epoch 00023: val_loss did not improve from 0.03542
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0041 - accuracy: 0.9994 - categorical_crossentropy: 0.0041 - val_loss: 0.1227 - val_accuracy: 0.9750 - val_categorical_crossentropy: 0.1227
# Epoch 24/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9969 - categorical_crossentropy: 0.0061
# Epoch 00024: val_loss did not improve from 0.03542
# 50/50 [==============================] - 6s 112ms/step - loss: 0.0061 - accuracy: 0.9969 - categorical_crossentropy: 0.0061 - val_loss: 0.1004 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1004
# Epoch 25/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9975 - categorical_crossentropy: 0.0039
# Epoch 00025: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0039 - accuracy: 0.9975 - categorical_crossentropy: 0.0039 - val_loss: 0.0736 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0736
# Epoch 26/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9987 - categorical_crossentropy: 0.0033
# Epoch 00026: val_loss did not improve from 0.03542
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0033 - accuracy: 0.9987 - categorical_crossentropy: 0.0033 - val_loss: 0.0787 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0787
# Epoch 27/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994 - categorical_crossentropy: 0.0030
# Epoch 00027: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0030 - accuracy: 0.9994 - categorical_crossentropy: 0.0030 - val_loss: 0.0854 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0854
# Epoch 28/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9994 - categorical_crossentropy: 0.0032
# Epoch 00028: val_loss did not improve from 0.03542
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0032 - accuracy: 0.9994 - categorical_crossentropy: 0.0032 - val_loss: 0.0917 - val_accuracy: 0.9750 - val_categorical_crossentropy: 0.0917
# Epoch 29/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994 - categorical_crossentropy: 0.0029
# Epoch 00029: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0029 - accuracy: 0.9994 - categorical_crossentropy: 0.0029 - val_loss: 0.0859 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0859
# Epoch 30/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9969 - categorical_crossentropy: 0.0057
# Epoch 00030: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0057 - accuracy: 0.9969 - categorical_crossentropy: 0.0057 - val_loss: 0.0491 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0491
# Epoch 31/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994 - categorical_crossentropy: 0.0020
# Epoch 00031: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - categorical_crossentropy: 0.0020 - val_loss: 0.0610 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0610
# Epoch 32/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000 - categorical_crossentropy: 0.0013
# Epoch 00032: val_loss did not improve from 0.03542
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0013 - accuracy: 1.0000 - categorical_crossentropy: 0.0013 - val_loss: 0.1184 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1184
# Epoch 33/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9981 - categorical_crossentropy: 0.0099
# Epoch 00033: val_loss improved from 0.03542 to 0.03354, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 118ms/step - loss: 0.0099 - accuracy: 0.9981 - categorical_crossentropy: 0.0099 - val_loss: 0.0335 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0335
# Epoch 34/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9956 - categorical_crossentropy: 0.0071
# Epoch 00034: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0071 - accuracy: 0.9956 - categorical_crossentropy: 0.0071 - val_loss: 0.0355 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0355
# Epoch 35/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9987 - categorical_crossentropy: 0.0021
# Epoch 00035: val_loss did not improve from 0.03354
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0021 - accuracy: 0.9987 - categorical_crossentropy: 0.0021 - val_loss: 0.0692 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0692
# Epoch 36/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9981 - categorical_crossentropy: 0.0060
# Epoch 00036: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0060 - accuracy: 0.9981 - categorical_crossentropy: 0.0060 - val_loss: 0.0817 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0817
# Epoch 37/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9987 - categorical_crossentropy: 0.0032
# Epoch 00037: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0032 - accuracy: 0.9987 - categorical_crossentropy: 0.0032 - val_loss: 0.1213 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.1213
# Epoch 38/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9981 - categorical_crossentropy: 0.0051
# Epoch 00038: val_loss did not improve from 0.03354
# 50/50 [==============================] - 6s 110ms/step - loss: 0.0051 - accuracy: 0.9981 - categorical_crossentropy: 0.0051 - val_loss: 0.0876 - val_accuracy: 0.9775 - val_categorical_crossentropy: 0.0876
# Epoch 39/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.5278e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.5278e-04
# Epoch 00039: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 109ms/step - loss: 3.5278e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.5278e-04 - val_loss: 0.0724 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0724
# Epoch 40/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9981 - categorical_crossentropy: 0.0023
# Epoch 00040: val_loss did not improve from 0.03354
# 50/50 [==============================] - 6s 110ms/step - loss: 0.0023 - accuracy: 0.9981 - categorical_crossentropy: 0.0023 - val_loss: 0.0807 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0807
# Epoch 41/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9994 - categorical_crossentropy: 0.0015
# Epoch 00041: val_loss did not improve from 0.03354
# 50/50 [==============================] - 6s 110ms/step - loss: 0.0015 - accuracy: 0.9994 - categorical_crossentropy: 0.0015 - val_loss: 0.0642 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0642
# Epoch 42/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994 - categorical_crossentropy: 0.0012
# Epoch 00042: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0012 - accuracy: 0.9994 - categorical_crossentropy: 0.0012 - val_loss: 0.0897 - val_accuracy: 0.9750 - val_categorical_crossentropy: 0.0897
# Epoch 43/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000 - categorical_crossentropy: 0.0015
# Epoch 00043: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0015 - accuracy: 1.0000 - categorical_crossentropy: 0.0015 - val_loss: 0.0824 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0824
# Epoch 44/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011
# Epoch 00044: val_loss did not improve from 0.03354
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011 - val_loss: 0.1288 - val_accuracy: 0.9750 - val_categorical_crossentropy: 0.1288
# Epoch 45/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9987 - categorical_crossentropy: 0.0020
# Epoch 00045: val_loss improved from 0.03354 to 0.02674, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.0020 - accuracy: 0.9987 - categorical_crossentropy: 0.0020 - val_loss: 0.0267 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0267
# Epoch 46/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994 - categorical_crossentropy: 0.0021
# Epoch 00046: val_loss did not improve from 0.02674
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0021 - accuracy: 0.9994 - categorical_crossentropy: 0.0021 - val_loss: 0.0950 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0950
# Epoch 47/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9994 - categorical_crossentropy: 0.0013
# Epoch 00047: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0013 - accuracy: 0.9994 - categorical_crossentropy: 0.0013 - val_loss: 0.0439 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0439
# Epoch 48/1000
# 50/50 [==============================] - ETA: 0s - loss: 9.9922e-04 - accuracy: 0.9994 - categorical_crossentropy: 9.9922e-04
# Epoch 00048: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 9.9922e-04 - accuracy: 0.9994 - categorical_crossentropy: 9.9922e-04 - val_loss: 0.0684 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0684
# Epoch 49/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9994 - categorical_crossentropy: 0.0013
# Epoch 00049: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0013 - accuracy: 0.9994 - categorical_crossentropy: 0.0013 - val_loss: 0.1002 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.1002
# Epoch 50/1000
# 50/50 [==============================] - ETA: 0s - loss: 8.9671e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.9671e-04
# Epoch 00050: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 108ms/step - loss: 8.9671e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.9671e-04 - val_loss: 0.0357 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0357
# Epoch 51/1000
# 50/50 [==============================] - ETA: 0s - loss: 9.7935e-04 - accuracy: 0.9994 - categorical_crossentropy: 9.7935e-04
# Epoch 00051: val_loss did not improve from 0.02674
# 50/50 [==============================] - 6s 110ms/step - loss: 9.7935e-04 - accuracy: 0.9994 - categorical_crossentropy: 9.7935e-04 - val_loss: 0.0979 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0979
# Epoch 52/1000
# 50/50 [==============================] - ETA: 0s - loss: 8.2059e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.2059e-04
# Epoch 00052: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 8.2059e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.2059e-04 - val_loss: 0.0755 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0755
# Epoch 53/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.0214e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.0214e-04
# Epoch 00053: val_loss did not improve from 0.02674
# 50/50 [==============================] - 6s 110ms/step - loss: 4.0214e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.0214e-04 - val_loss: 0.0731 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0731
# Epoch 54/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011
# Epoch 00054: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011 - val_loss: 0.1022 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.1022
# Epoch 55/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.4827e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.4827e-04
# Epoch 00055: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 4.4827e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.4827e-04 - val_loss: 0.0351 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0351
# Epoch 56/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.5047e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.5047e-04
# Epoch 00056: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 6.5047e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.5047e-04 - val_loss: 0.1136 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.1136
# Epoch 57/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.3212e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.3212e-04
# Epoch 00057: val_loss did not improve from 0.02674
# 50/50 [==============================] - 6s 110ms/step - loss: 3.3212e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.3212e-04 - val_loss: 0.0818 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0818
# Epoch 58/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.5244e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.5244e-04
# Epoch 00058: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 2.5244e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.5244e-04 - val_loss: 0.0288 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0288
# Epoch 59/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.5499e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.5499e-04
# Epoch 00059: val_loss did not improve from 0.02674
# 50/50 [==============================] - 6s 111ms/step - loss: 4.5499e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.5499e-04 - val_loss: 0.0709 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0709
# Epoch 60/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.4695e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.4695e-04
# Epoch 00060: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 109ms/step - loss: 7.4695e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.4695e-04 - val_loss: 0.1037 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.1037
# Epoch 61/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.7671e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.7671e-04
# Epoch 00061: val_loss did not improve from 0.02674
# 50/50 [==============================] - 5s 110ms/step - loss: 3.7671e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.7671e-04 - val_loss: 0.0950 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0950
# Epoch 62/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994 - categorical_crossentropy: 0.0014
# Epoch 00062: val_loss improved from 0.02674 to 0.02130, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 118ms/step - loss: 0.0014 - accuracy: 0.9994 - categorical_crossentropy: 0.0014 - val_loss: 0.0213 - val_accuracy: 0.9950 - val_categorical_crossentropy: 0.0213
# Epoch 63/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.6307e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.6307e-04
# Epoch 00063: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 110ms/step - loss: 6.6307e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.6307e-04 - val_loss: 0.1302 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.1302
# Epoch 64/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.8215e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.8215e-04
# Epoch 00064: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 111ms/step - loss: 1.8215e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.8215e-04 - val_loss: 0.0907 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0907
# Epoch 65/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.4753e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.4753e-04
# Epoch 00065: val_loss did not improve from 0.02130
# 50/50 [==============================] - 5s 108ms/step - loss: 4.4753e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.4753e-04 - val_loss: 0.0809 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0809
# Epoch 66/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.9288e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.9288e-04
# Epoch 00066: val_loss did not improve from 0.02130
# 50/50 [==============================] - 5s 110ms/step - loss: 7.9288e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.9288e-04 - val_loss: 0.0698 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0698
# Epoch 67/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - categorical_crossentropy: 0.0011
# Epoch 00067: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - categorical_crossentropy: 0.0011 - val_loss: 0.0644 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0644
# Epoch 68/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.0560e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.0560e-04
# Epoch 00068: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 111ms/step - loss: 7.0560e-04 - accuracy: 1.0000 - categorical_crossentropy: 7.0560e-04 - val_loss: 0.0680 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0680
# Epoch 69/1000
# 50/50 [==============================] - ETA: 0s - loss: 5.0117e-04 - accuracy: 1.0000 - categorical_crossentropy: 5.0117e-04
# Epoch 00069: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 110ms/step - loss: 5.0117e-04 - accuracy: 1.0000 - categorical_crossentropy: 5.0117e-04 - val_loss: 0.0947 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0947
# Epoch 70/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.3798e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3798e-04
# Epoch 00070: val_loss did not improve from 0.02130
# 50/50 [==============================] - 5s 108ms/step - loss: 2.3798e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3798e-04 - val_loss: 0.0709 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0709
# Epoch 71/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.3063e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3063e-04
# Epoch 00071: val_loss did not improve from 0.02130
# 50/50 [==============================] - 6s 111ms/step - loss: 1.3063e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3063e-04 - val_loss: 0.0709 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0709
# Epoch 72/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.6584e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.6584e-04
# Epoch 00072: val_loss did not improve from 0.02130
# 50/50 [==============================] - 5s 109ms/step - loss: 1.6584e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.6584e-04 - val_loss: 0.1115 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.1115
# Epoch 73/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.7652e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.7652e-04
# Epoch 00073: val_loss improved from 0.02130 to 0.01324, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_num_forces.h5
# 50/50 [==============================] - 6s 118ms/step - loss: 6.7652e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.7652e-04 - val_loss: 0.0132 - val_accuracy: 0.9950 - val_categorical_crossentropy: 0.0132
# Epoch 74/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.1477e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.1477e-04
# Epoch 00074: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 2.1477e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.1477e-04 - val_loss: 0.1447 - val_accuracy: 0.9725 - val_categorical_crossentropy: 0.1447
# Epoch 75/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.8114e-04 - accuracy: 0.9994 - categorical_crossentropy: 7.8114e-04
# Epoch 00075: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 7.8114e-04 - accuracy: 0.9994 - categorical_crossentropy: 7.8114e-04 - val_loss: 0.0969 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0969
# Epoch 76/1000
# 50/50 [==============================] - ETA: 0s - loss: 8.4627e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.4627e-04
# Epoch 00076: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 8.4627e-04 - accuracy: 1.0000 - categorical_crossentropy: 8.4627e-04 - val_loss: 0.0201 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0201
# Epoch 77/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994 - categorical_crossentropy: 0.0022
# Epoch 00077: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 0.0022 - accuracy: 0.9994 - categorical_crossentropy: 0.0022 - val_loss: 0.0642 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0642
# Epoch 78/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.6282e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.6282e-04
# Epoch 00078: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 2.6282e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.6282e-04 - val_loss: 0.0659 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0659
# Epoch 79/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.6125e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.6125e-04
# Epoch 00079: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 109ms/step - loss: 2.6125e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.6125e-04 - val_loss: 0.0719 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0719
# Epoch 80/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9987 - categorical_crossentropy: 0.0013
# Epoch 00080: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0013 - accuracy: 0.9987 - categorical_crossentropy: 0.0013 - val_loss: 0.0795 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0795
# Epoch 81/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.1510e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.1510e-04
# Epoch 00081: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 109ms/step - loss: 4.1510e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.1510e-04 - val_loss: 0.0833 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0833
# Epoch 82/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.6549e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.6549e-04
# Epoch 00082: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 3.6549e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.6549e-04 - val_loss: 0.0823 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0823
# Epoch 83/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.5013e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.5013e-04
# Epoch 00083: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 114ms/step - loss: 3.5013e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.5013e-04 - val_loss: 0.1374 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.1374
# Epoch 84/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.3392e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3392e-04
# Epoch 00084: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 109ms/step - loss: 2.3392e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3392e-04 - val_loss: 0.0942 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0942
# Epoch 85/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.1789e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.1789e-04
# Epoch 00085: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 109ms/step - loss: 2.1789e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.1789e-04 - val_loss: 0.0608 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0608
# Epoch 86/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.0912e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0912e-04
# Epoch 00086: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 1.0912e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0912e-04 - val_loss: 0.0719 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0719
# Epoch 87/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9937 - categorical_crossentropy: 0.0208
# Epoch 00087: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 0.0208 - accuracy: 0.9937 - categorical_crossentropy: 0.0208 - val_loss: 0.0137 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0137
# Epoch 88/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.9289e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.9289e-04
# Epoch 00088: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 6.9289e-04 - accuracy: 1.0000 - categorical_crossentropy: 6.9289e-04 - val_loss: 0.0785 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0785
# Epoch 89/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9987 - categorical_crossentropy: 0.0016
# Epoch 00089: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0016 - accuracy: 0.9987 - categorical_crossentropy: 0.0016 - val_loss: 0.0848 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0848
# Epoch 90/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981 - categorical_crossentropy: 0.0056
# Epoch 00090: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0056 - accuracy: 0.9981 - categorical_crossentropy: 0.0056 - val_loss: 0.0856 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0856
# Epoch 91/1000
# 50/50 [==============================] - ETA: 0s - loss: 5.1378e-04 - accuracy: 1.0000 - categorical_crossentropy: 5.1378e-04
# Epoch 00091: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 5.1378e-04 - accuracy: 1.0000 - categorical_crossentropy: 5.1378e-04 - val_loss: 0.0724 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0724
# Epoch 92/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.7060e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.7060e-04
# Epoch 00092: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 3.7060e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.7060e-04 - val_loss: 0.0688 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0688
# Epoch 93/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.5641e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.5641e-04
# Epoch 00093: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 4.5641e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.5641e-04 - val_loss: 0.0725 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0725
# Epoch 94/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.3768e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3768e-04
# Epoch 00094: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 2.3768e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.3768e-04 - val_loss: 0.0755 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0755
# Epoch 95/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.7806e-05 - accuracy: 1.0000 - categorical_crossentropy: 7.7806e-05
# Epoch 00095: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 7.7806e-05 - accuracy: 1.0000 - categorical_crossentropy: 7.7806e-05 - val_loss: 0.0880 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0880
# Epoch 96/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.3999e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3999e-04
# Epoch 00096: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 1.3999e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3999e-04 - val_loss: 0.0768 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0768
# Epoch 97/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.3030e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3030e-04
# Epoch 00097: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 1.3030e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3030e-04 - val_loss: 0.0906 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0906
# Epoch 98/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.2160e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.2160e-04
# Epoch 00098: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 2.2160e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.2160e-04 - val_loss: 0.0711 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0711
# Epoch 99/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.3006e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3006e-04
# Epoch 00099: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 1.3006e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.3006e-04 - val_loss: 0.1210 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.1210
# Epoch 100/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.2484e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.2484e-04
# Epoch 00100: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 1.2484e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.2484e-04 - val_loss: 0.0648 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0648
# Epoch 101/1000
# 50/50 [==============================] - ETA: 0s - loss: 5.2442e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.2442e-05
# Epoch 00101: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 5.2442e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.2442e-05 - val_loss: 0.0788 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0788
# Epoch 102/1000
# 50/50 [==============================] - ETA: 0s - loss: 9.5690e-04 - accuracy: 1.0000 - categorical_crossentropy: 9.5690e-04
# Epoch 00102: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 9.5690e-04 - accuracy: 1.0000 - categorical_crossentropy: 9.5690e-04 - val_loss: 0.0853 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0853
# Epoch 103/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.4630e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.4630e-04
# Epoch 00103: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 1.4630e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.4630e-04 - val_loss: 0.0955 - val_accuracy: 0.9800 - val_categorical_crossentropy: 0.0955
# Epoch 104/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994 - categorical_crossentropy: 0.0023
# Epoch 00104: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 0.0023 - accuracy: 0.9994 - categorical_crossentropy: 0.0023 - val_loss: 0.1679 - val_accuracy: 0.9675 - val_categorical_crossentropy: 0.1679
# Epoch 105/1000
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011
# Epoch 00105: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 0.0011 - accuracy: 0.9994 - categorical_crossentropy: 0.0011 - val_loss: 0.0792 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0792
# Epoch 106/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.8503e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.8503e-04
# Epoch 00106: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 3.8503e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.8503e-04 - val_loss: 0.1009 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.1009
# Epoch 107/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.1343e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.1343e-04
# Epoch 00107: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 3.1343e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.1343e-04 - val_loss: 0.0769 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0769
# Epoch 108/1000
# 50/50 [==============================] - ETA: 0s - loss: 8.3965e-05 - accuracy: 1.0000 - categorical_crossentropy: 8.3965e-05
# Epoch 00108: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 8.3965e-05 - accuracy: 1.0000 - categorical_crossentropy: 8.3965e-05 - val_loss: 0.0685 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0685
# Epoch 109/1000
# 50/50 [==============================] - ETA: 0s - loss: 9.7938e-05 - accuracy: 1.0000 - categorical_crossentropy: 9.7938e-05
# Epoch 00109: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 9.7938e-05 - accuracy: 1.0000 - categorical_crossentropy: 9.7938e-05 - val_loss: 0.1230 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.1230
# Epoch 110/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.5771e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.5771e-04
# Epoch 00110: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 1.5771e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.5771e-04 - val_loss: 0.0736 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0736
# Epoch 111/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.7113e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.7113e-05
# Epoch 00111: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 4.7113e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.7113e-05 - val_loss: 0.0473 - val_accuracy: 0.9825 - val_categorical_crossentropy: 0.0473
# Epoch 112/1000
# 50/50 [==============================] - ETA: 0s - loss: 7.4404e-04 - accuracy: 0.9994 - categorical_crossentropy: 7.4404e-04
# Epoch 00112: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 7.4404e-04 - accuracy: 0.9994 - categorical_crossentropy: 7.4404e-04 - val_loss: 0.1413 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.1413
# Epoch 113/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.3802e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.3802e-04
# Epoch 00113: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 4.3802e-04 - accuracy: 1.0000 - categorical_crossentropy: 4.3802e-04 - val_loss: 0.0214 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0214
# Epoch 114/1000
# 50/50 [==============================] - ETA: 0s - loss: 2.2713e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.2713e-04
# Epoch 00114: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 2.2713e-04 - accuracy: 1.0000 - categorical_crossentropy: 2.2713e-04 - val_loss: 0.1139 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.1139
# Epoch 115/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.4984e-05 - accuracy: 1.0000 - categorical_crossentropy: 6.4984e-05
# Epoch 00115: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 6.4984e-05 - accuracy: 1.0000 - categorical_crossentropy: 6.4984e-05 - val_loss: 0.0205 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0205
# Epoch 116/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.0981e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0981e-04
# Epoch 00116: val_loss did not improve from 0.01324
# 50/50 [==============================] - 5s 110ms/step - loss: 1.0981e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0981e-04 - val_loss: 0.0701 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0701
# Epoch 117/1000
# 50/50 [==============================] - ETA: 0s - loss: 6.2304e-05 - accuracy: 1.0000 - categorical_crossentropy: 6.2304e-05
# Epoch 00117: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 113ms/step - loss: 6.2304e-05 - accuracy: 1.0000 - categorical_crossentropy: 6.2304e-05 - val_loss: 0.0641 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.0641
# Epoch 118/1000
# 50/50 [==============================] - ETA: 0s - loss: 5.6791e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.6791e-05
# Epoch 00118: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 5.6791e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.6791e-05 - val_loss: 0.0634 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0634
# Epoch 119/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.7686e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.7686e-05
# Epoch 00119: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 4.7686e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.7686e-05 - val_loss: 0.0644 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0644
# Epoch 120/1000
# 50/50 [==============================] - ETA: 0s - loss: 5.4319e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.4319e-05
# Epoch 00120: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 110ms/step - loss: 5.4319e-05 - accuracy: 1.0000 - categorical_crossentropy: 5.4319e-05 - val_loss: 0.0660 - val_accuracy: 0.9900 - val_categorical_crossentropy: 0.0660
# Epoch 121/1000
# 50/50 [==============================] - ETA: 0s - loss: 3.9529e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.9529e-04
# Epoch 00121: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 111ms/step - loss: 3.9529e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.9529e-04 - val_loss: 0.1207 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.1207
# Epoch 122/1000
# 50/50 [==============================] - ETA: 0s - loss: 4.1325e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.1325e-05
# Epoch 00122: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 112ms/step - loss: 4.1325e-05 - accuracy: 1.0000 - categorical_crossentropy: 4.1325e-05 - val_loss: 0.0404 - val_accuracy: 0.9850 - val_categorical_crossentropy: 0.0404
# Epoch 123/1000
# 50/50 [==============================] - ETA: 0s - loss: 1.0950e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0950e-04
# Epoch 00123: val_loss did not improve from 0.01324
# 50/50 [==============================] - 6s 113ms/step - loss: 1.0950e-04 - accuracy: 1.0000 - categorical_crossentropy: 1.0950e-04 - val_loss: 0.0808 - val_accuracy: 0.9875 - val_categorical_crossentropy: 0.0808
# Epoch 00123: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
