# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import Sequence
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '4000', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '4000', 'val')
train_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '4000', 'train')
val_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '4000', 'val')
load_models_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                               'PhotoForceReconML', 'models')
save_models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '4000')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels should be loaded from a separate directory. Each label corresponds to two particles.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Loading the data

# %%
# Load the train and validation sets

X_train, X_val = {}, {}
y_train, y_val = {}, {}

for k in range(5):
    i = k + 2
    X_path_train = os.path.join(train_image_path, str(i))
    X_path_val = os.path.join(val_image_path, str(i))
    X_train[i] = [os.path.join(X_path_train, name) for name in sorted(os.listdir(X_path_train), key = sorter)]
    X_val[i] = [os.path.join(X_path_val, name) for name in sorted(os.listdir(X_path_val), key = sorter)]
    y_train[i] = np.load(os.path.join(train_labels_path, str(i), 'mags.npy'))
    y_val[i] = np.load(os.path.join(val_labels_path, str(i), 'mags.npy'))

# %%
# Apply data generators
gaussblur = GaussBlur(1)
params = {'batch_size': 32, 
          'dim': (128, 128), 
          'n_channels': 3, 
          'rescale': 1 / 255, 
          'shuffle': True, 
          'save_dir': None,
          'preprocessing_func': gaussblur.blur
          }

training_generator = {}
validation_generator = {}

for k in range(5):
    i = k + 2
    training_generator[i] = DataGeneratorTrain(X_train[i], y_train[i], **params)
    validation_generator[i] = DataGeneratorTrain(X_val[i], y_val[i], **params)

# %% [markdown]
# #### InceptionResNetV2 Models Building

# %% [markdown]
# Convolutional neural networks is defined and compiled in this step.

# %%
# Load models
models_m = dict()                         
for k in range(5):
     i = k + 2
     models_m[i] = load_model(os.path.join(load_models_path, 'InceptionResNetV2_mags_'+str(i)+'.h5'))

# %%
for k in range(5):
    i = k + 2
    models_m[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 55,912,674
# Trainable params: 55,852,130
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1536)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 55,913,699
# Trainable params: 55,853,155
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 55,914,724
# Trainable params: 55,854,180
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1536)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 55,855,205
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1536)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 55,916,774
# Trainable params: 55,856,230
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
for k in range(5):
    i = 2 + k
    models_m[i].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = dict()
for k in range(5):
    i = k + 2
    model_path = os.path.join(save_models_path, 'InceptionResNetV2_mags_'+str(i)+'.h5')
    mc[i] = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
epochs = 1000
history = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history[i] = models_m[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0906 - mean_absolute_error: 0.0906
# Epoch 00001: val_loss improved from inf to 0.01387, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 18s 180ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139
# Epoch 2/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0265 - mean_absolute_error: 0.0265
# Epoch 00002: val_loss improved from 0.01387 to 0.00808, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 163ms/step - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0081 - val_mean_absolute_error: 0.0081
# Epoch 3/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0249 - mean_absolute_error: 0.0249
# Epoch 00003: val_loss improved from 0.00808 to 0.00791, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 163ms/step - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079
# Epoch 4/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0240 - mean_absolute_error: 0.0240
# Epoch 00004: val_loss improved from 0.00791 to 0.00731, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073
# Epoch 5/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0224 - mean_absolute_error: 0.0224
# Epoch 00005: val_loss did not improve from 0.00731
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076
# Epoch 6/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0227 - mean_absolute_error: 0.0227
# Epoch 00006: val_loss improved from 0.00731 to 0.00711, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0227 - mean_absolute_error: 0.0227 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071
# Epoch 7/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0221 - mean_absolute_error: 0.0221
# Epoch 00007: val_loss did not improve from 0.00711
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076
# Epoch 8/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0222 - mean_absolute_error: 0.0222
# Epoch 00008: val_loss improved from 0.00711 to 0.00606, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0222 - mean_absolute_error: 0.0222 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061
# Epoch 9/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0224 - mean_absolute_error: 0.0224
# Epoch 00009: val_loss did not improve from 0.00606
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0068 - val_mean_absolute_error: 0.0068
# Epoch 10/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0219 - mean_absolute_error: 0.0219
# Epoch 00010: val_loss improved from 0.00606 to 0.00581, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 163ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 11/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0223 - mean_absolute_error: 0.0223
# Epoch 00011: val_loss did not improve from 0.00581
# 100/100 [==============================] - 15s 152ms/step - loss: 0.0223 - mean_absolute_error: 0.0223 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063
# Epoch 12/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0214 - mean_absolute_error: 0.0214
# Epoch 00012: val_loss did not improve from 0.00581
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 13/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0217 - mean_absolute_error: 0.0217
# Epoch 00013: val_loss did not improve from 0.00581
# 100/100 [==============================] - 15s 152ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - val_loss: 0.0059 - val_mean_absolute_error: 0.0059
# Epoch 14/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0223 - mean_absolute_error: 0.0223
# Epoch 00014: val_loss improved from 0.00581 to 0.00549, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 17s 174ms/step - loss: 0.0223 - mean_absolute_error: 0.0223 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 15/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0217 - mean_absolute_error: 0.0217
# Epoch 00015: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 152ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 16/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0217 - mean_absolute_error: 0.0217
# Epoch 00016: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060
# Epoch 17/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0206 - mean_absolute_error: 0.0206
# Epoch 00017: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 18/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0208 - mean_absolute_error: 0.0208
# Epoch 00018: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 153ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063
# Epoch 19/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0222 - mean_absolute_error: 0.0222
# Epoch 00019: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0222 - mean_absolute_error: 0.0222 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 20/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0214 - mean_absolute_error: 0.0214
# Epoch 00020: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 21/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0216 - mean_absolute_error: 0.0216
# Epoch 00021: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 22/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0208 - mean_absolute_error: 0.0208
# Epoch 00022: val_loss did not improve from 0.00549
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060
# Epoch 23/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00023: val_loss improved from 0.00549 to 0.00517, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 24/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 00024: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0062 - val_mean_absolute_error: 0.0062
# Epoch 25/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0215 - mean_absolute_error: 0.0215
# Epoch 00025: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 26/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0216 - mean_absolute_error: 0.0216
# Epoch 00026: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 27/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0211 - mean_absolute_error: 0.0211
# Epoch 00027: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0211 - mean_absolute_error: 0.0211 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 28/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 00028: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053
# Epoch 29/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00029: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 30/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00030: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053
# Epoch 31/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00031: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 32/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0208 - mean_absolute_error: 0.0208
# Epoch 00032: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.0066 - val_mean_absolute_error: 0.0066
# Epoch 33/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0204 - mean_absolute_error: 0.0204
# Epoch 00033: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0204 - mean_absolute_error: 0.0204 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 34/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00034: val_loss did not improve from 0.00517
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 35/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0207 - mean_absolute_error: 0.0207
# Epoch 00035: val_loss improved from 0.00517 to 0.00497, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 161ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 36/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0206 - mean_absolute_error: 0.0206
# Epoch 00036: val_loss did not improve from 0.00497
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 37/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0208 - mean_absolute_error: 0.0208
# Epoch 00037: val_loss did not improve from 0.00497
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 38/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00038: val_loss did not improve from 0.00497
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 39/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00039: val_loss did not improve from 0.00497
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053
# Epoch 40/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00040: val_loss improved from 0.00497 to 0.00486, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 41/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00041: val_loss did not improve from 0.00486
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053
# Epoch 42/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0207 - mean_absolute_error: 0.0207
# Epoch 00042: val_loss did not improve from 0.00486
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 43/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00043: val_loss did not improve from 0.00486
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 44/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0206 - mean_absolute_error: 0.0206
# Epoch 00044: val_loss improved from 0.00486 to 0.00469, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 161ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 45/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0207 - mean_absolute_error: 0.0207
# Epoch 00045: val_loss did not improve from 0.00469
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 46/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00046: val_loss did not improve from 0.00469
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 47/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00047: val_loss did not improve from 0.00469
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 48/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00048: val_loss did not improve from 0.00469
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 49/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0204 - mean_absolute_error: 0.0204
# Epoch 00049: val_loss improved from 0.00469 to 0.00467, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0204 - mean_absolute_error: 0.0204 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 50/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0206 - mean_absolute_error: 0.0206
# Epoch 00050: val_loss did not improve from 0.00467
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 51/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00051: val_loss did not improve from 0.00467
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 52/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0200 - mean_absolute_error: 0.0200
# Epoch 00052: val_loss did not improve from 0.00467
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0200 - mean_absolute_error: 0.0200 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 53/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00053: val_loss improved from 0.00467 to 0.00467, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 161ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 54/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0204 - mean_absolute_error: 0.0204
# Epoch 00054: val_loss did not improve from 0.00467
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0204 - mean_absolute_error: 0.0204 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 55/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00055: val_loss did not improve from 0.00467
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 56/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00056: val_loss improved from 0.00467 to 0.00452, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 163ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 57/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00057: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 58/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00058: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 59/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00059: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 60/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00060: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 61/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00061: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 62/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0200 - mean_absolute_error: 0.0200
# Epoch 00062: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0200 - mean_absolute_error: 0.0200 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 63/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00063: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 64/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0205
# Epoch 00064: val_loss improved from 0.00452 to 0.00452, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 65/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00065: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 66/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0200 - mean_absolute_error: 0.0200
# Epoch 00066: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0200 - mean_absolute_error: 0.0200 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 67/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00067: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 68/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00068: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 69/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00069: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 70/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00070: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 71/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00071: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 72/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00072: val_loss did not improve from 0.00452
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073
# Epoch 73/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00073: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 74/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00074: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 75/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00075: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 76/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00076: val_loss did not improve from 0.00452
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 77/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00077: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 78/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00078: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069
# Epoch 79/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00079: val_loss did not improve from 0.00452
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 80/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0202 - mean_absolute_error: 0.0202
# Epoch 00080: val_loss improved from 0.00452 to 0.00425, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 161ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 81/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00081: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 82/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00082: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075
# Epoch 83/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00083: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 84/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0203 - mean_absolute_error: 0.0203
# Epoch 00084: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 85/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00085: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 86/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00086: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 87/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00087: val_loss did not improve from 0.00425
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0060 - val_mean_absolute_error: 0.0060
# Epoch 88/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00088: val_loss did not improve from 0.00425
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 89/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00089: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 90/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00090: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 91/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00091: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 92/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00092: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070
# Epoch 93/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00093: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0075 - val_mean_absolute_error: 0.0075
# Epoch 94/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00094: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 95/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00095: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 96/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00096: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 97/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00097: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 98/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00098: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 99/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00099: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061
# Epoch 100/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00100: val_loss did not improve from 0.00425
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 101/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00101: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 102/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00102: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 103/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00103: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 104/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00104: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 105/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00105: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 106/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00106: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 107/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00107: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0065 - val_mean_absolute_error: 0.0065
# Epoch 108/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00108: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 109/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00109: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 110/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00110: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 111/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0199 - mean_absolute_error: 0.0199
# Epoch 00111: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 112/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00112: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 113/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00113: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 114/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00114: val_loss did not improve from 0.00425
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 115/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00115: val_loss improved from 0.00425 to 0.00419, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/4000/InceptionResNetV2_mags_2.h5
# 100/100 [==============================] - 16s 162ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 116/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00116: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 117/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0201 - mean_absolute_error: 0.0201
# Epoch 00117: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 118/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00118: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 119/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00119: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 120/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00120: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 121/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00121: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 122/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00122: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 123/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0202 - mean_absolute_error: 0.0202
# Epoch 00123: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 124/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00124: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 125/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00125: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 126/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00126: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 127/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00127: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 128/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00128: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 129/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00129: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 130/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00130: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 131/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0189 - mean_absolute_error: 0.0189
# Epoch 00131: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 132/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0192 - mean_absolute_error: 0.0192
# Epoch 00132: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 133/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00133: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0061 - val_mean_absolute_error: 0.0061
# Epoch 134/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0198 - mean_absolute_error: 0.0198
# Epoch 00134: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0198 - mean_absolute_error: 0.0198 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 135/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0196 - mean_absolute_error: 0.0196
# Epoch 00135: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 136/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0197 - mean_absolute_error: 0.0197
# Epoch 00136: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 137/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00137: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 138/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0190 - mean_absolute_error: 0.0190
# Epoch 00138: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 139/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00139: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 140/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00140: val_loss did not improve from 0.00419
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 141/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0194 - mean_absolute_error: 0.0194
# Epoch 00141: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 142/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00142: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 143/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0193 - mean_absolute_error: 0.0193
# Epoch 00143: val_loss did not improve from 0.00419
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 144/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0191 - mean_absolute_error: 0.0191
# Epoch 00144: val_loss did not improve from 0.00419
# ...
# Epoch 279/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0551 - mean_absolute_error: 0.0551
# Epoch 00279: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 280/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0565 - mean_absolute_error: 0.0565
# Epoch 00280: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 281/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0562 - mean_absolute_error: 0.0562
# Epoch 00281: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0562 - mean_absolute_error: 0.0562 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 282/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0559 - mean_absolute_error: 0.0559
# Epoch 00282: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 283/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0558 - mean_absolute_error: 0.0558
# Epoch 00283: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 284/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00284: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 285/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0576 - mean_absolute_error: 0.0576
# Epoch 00285: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 286/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00286: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416
# Epoch 287/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0566 - mean_absolute_error: 0.0566
# Epoch 00287: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 288/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0554 - mean_absolute_error: 0.0554
# Epoch 00288: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 289/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0562 - mean_absolute_error: 0.0562
# Epoch 00289: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0562 - mean_absolute_error: 0.0562 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 290/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0574 - mean_absolute_error: 0.0574
# Epoch 00290: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0574 - mean_absolute_error: 0.0574 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 291/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0563 - mean_absolute_error: 0.0563
# Epoch 00291: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 292/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0569 - mean_absolute_error: 0.0569
# Epoch 00292: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0569 - mean_absolute_error: 0.0569 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 293/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0569 - mean_absolute_error: 0.0569
# Epoch 00293: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0569 - mean_absolute_error: 0.0569 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 294/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00294: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 295/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0565 - mean_absolute_error: 0.0565
# Epoch 00295: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416
# Epoch 296/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0566 - mean_absolute_error: 0.0566
# Epoch 00296: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 297/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0560 - mean_absolute_error: 0.0560
# Epoch 00297: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412
# Epoch 298/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0557 - mean_absolute_error: 0.0557
# Epoch 00298: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 299/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0559 - mean_absolute_error: 0.0559
# Epoch 00299: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 300/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0562 - mean_absolute_error: 0.0562
# Epoch 00300: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0562 - mean_absolute_error: 0.0562 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 301/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0557 - mean_absolute_error: 0.0557
# Epoch 00301: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414
# Epoch 302/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0554 - mean_absolute_error: 0.0554
# Epoch 00302: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416
# Epoch 303/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0557 - mean_absolute_error: 0.0557
# Epoch 00303: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414
# Epoch 304/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0560 - mean_absolute_error: 0.0560
# Epoch 00304: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - val_loss: 0.0423 - val_mean_absolute_error: 0.0423
# Epoch 305/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0560 - mean_absolute_error: 0.0560
# Epoch 00305: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416
# Epoch 306/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0570 - mean_absolute_error: 0.0570
# Epoch 00306: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412
# Epoch 307/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00307: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 308/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0558 - mean_absolute_error: 0.0558
# Epoch 00308: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 309/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0541 - mean_absolute_error: 0.0541
# Epoch 00309: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 310/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0557 - mean_absolute_error: 0.0557
# Epoch 00310: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 311/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0553 - mean_absolute_error: 0.0553
# Epoch 00311: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 312/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0555 - mean_absolute_error: 0.0555
# Epoch 00312: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0555 - mean_absolute_error: 0.0555 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412
# Epoch 313/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0553 - mean_absolute_error: 0.0553
# Epoch 00313: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414
# Epoch 314/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0542 - mean_absolute_error: 0.0542
# Epoch 00314: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.0416 - val_mean_absolute_error: 0.0416
# Epoch 315/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00315: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 316/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0558 - mean_absolute_error: 0.0558
# Epoch 00316: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0420 - val_mean_absolute_error: 0.0420
# Epoch 317/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0545 - mean_absolute_error: 0.0545
# Epoch 00317: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 318/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0553 - mean_absolute_error: 0.0553
# Epoch 00318: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 319/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0543 - mean_absolute_error: 0.0543
# Epoch 00319: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412
# Epoch 320/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0551 - mean_absolute_error: 0.0551
# Epoch 00320: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0421 - val_mean_absolute_error: 0.0421
# Epoch 321/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0561 - mean_absolute_error: 0.0561
# Epoch 00321: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0561 - mean_absolute_error: 0.0561 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 322/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0555 - mean_absolute_error: 0.0555
# Epoch 00322: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 145ms/step - loss: 0.0555 - mean_absolute_error: 0.0555 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 323/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0542 - mean_absolute_error: 0.0542
# Epoch 00323: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 324/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0550 - mean_absolute_error: 0.0550
# Epoch 00324: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 325/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0544 - mean_absolute_error: 0.0544
# Epoch 00325: val_loss did not improve from 0.04111
# 100/100 [==============================] - 15s 146ms/step - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 326/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0556 - mean_absolute_error: 0.0556
# Epoch 00326: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0556 - mean_absolute_error: 0.0556 - val_loss: 0.0413 - val_mean_absolute_error: 0.0413
# Epoch 327/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0549 - mean_absolute_error: 0.0549
# Epoch 00327: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 144ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 328/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0554 - mean_absolute_error: 0.0554
# Epoch 00328: val_loss did not improve from 0.04111
# 100/100 [==============================] - 14s 145ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.0412 - val_mean_absolute_error: 0.0412
# Epoch 00328: early stopping

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history[i+2].history['loss'])
    plt.plot(history[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
