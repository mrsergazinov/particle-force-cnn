# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import Sequence
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '1000', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '1000', 'val')
train_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '1000', 'train')
val_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '1000', 'val')
load_models_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                               'PhotoForceReconML', 'models')
save_models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '1000')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Sort the labels according to the inner (contact) angle.

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %%
# Load the train and validation sets

X_train, X_val = {}, {}
y_train, y_val = {}, {}

for k in range(5):
    i = k + 2
    X_path_train = os.path.join(train_image_path, str(i))
    X_path_val = os.path.join(val_image_path, str(i))
    X_train[i] = [os.path.join(X_path_train, name) for name in sorted(os.listdir(X_path_train), key = sorter)]
    X_val[i] = [os.path.join(X_path_val, name) for name in sorted(os.listdir(X_path_val), key = sorter)]
    y_train[i] = np.load(os.path.join(train_labels_path, str(i), 'angles_tang.npy'))
    y_val[i] = np.load(os.path.join(val_labels_path, str(i), 'angles_tang.npy'))

# %% [markdown]
# Data generators are created and defind here. Images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1]. The images are further rescaled to 128*128 with Nearest interpolation.

# %%
# Apply data generators
gaussblur = GaussBlur(1)
params = {'batch_size': 32, 
          'dim': (128, 128), 
          'n_channels': 3, 
          'rescale': 1 / 255, 
          'shuffle': True, 
          'save_dir': None,
          'preprocessing_func': gaussblur.blur
          }

training_generator = {}
validation_generator = {}

for k in range(5):
    i = k + 2
    training_generator[i] = DataGeneratorTrain(X_train[i], y_train[i], **params)
    validation_generator[i] = DataGeneratorTrain(X_val[i], y_val[i], **params)

# %%
# Generate a sample of images for inspection

test_generator = {}
for k in range(5):
    i = k + 2
    test_generator[i] = DataGenerator(X_train[i], y_train[i], **params)
    x, y = test_generator[i].__getitem__(0)
    plt.figure()
    plt.imshow(np.asarray(x[3, ]))
    print(y[3])
# Out:
# [-0.14925073  0.14925073]
# [-0.21356     0.10325401  0.11776991]
# [-0.45472443  0.06119077 -0.00252451  0.27017916]
# [-0.60219328  0.55428401  0.00878012  0.091871    0.28949272]
# [-0.28088685 -0.17283358  0.16445061  0.32590813  0.08023243 -0.12142542]

# %% [markdown]
# #### XCEPTION Training

# %%
# Load models
models_at = dict()                         
for k in range(5):
     i = k + 2
     models_at[i] = load_model(os.path.join(load_models_path, 'xception_angles_tang_'+str(i)+'.h5'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = dict()
for k in range(5):
    i = k + 2
    model_path = os.path.join(save_models_path, 'xception_angles_tang_'+str(i)+'.h5')
    mc[i] = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
for k in range(5):
    i = k + 2
    models_at[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 22,961,706
# Trainable params: 22,907,178
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 22,962,731
# Trainable params: 22,908,203
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 22,963,756
# Trainable params: 22,909,228
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 22,964,781
# Trainable params: 22,910,253
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# xception (Model)             (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 22,965,806
# Trainable params: 22,911,278
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
for k in range(5):
    i = 2 + k
    models_at[i].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5, epsilon=0.1),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
epochs = 1000
history_ft = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history_ft[i] = models_at[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0856 - mean_absolute_error: 0.0856
# Epoch 00001: val_loss improved from inf to 0.06381, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 162ms/step - loss: 0.0856 - mean_absolute_error: 0.0856 - val_loss: 0.0638 - val_mean_absolute_error: 0.0638
# Epoch 2/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0838 - mean_absolute_error: 0.0838
# Epoch 00002: val_loss improved from 0.06381 to 0.06378, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 156ms/step - loss: 0.0838 - mean_absolute_error: 0.0838 - val_loss: 0.0638 - val_mean_absolute_error: 0.0638
# Epoch 3/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0822 - mean_absolute_error: 0.0822
# Epoch 00003: val_loss improved from 0.06378 to 0.06289, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0822 - mean_absolute_error: 0.0822 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629
# Epoch 4/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0801 - mean_absolute_error: 0.0801
# Epoch 00004: val_loss improved from 0.06289 to 0.06160, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0801 - mean_absolute_error: 0.0801 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616
# Epoch 5/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0780 - mean_absolute_error: 0.0780
# Epoch 00005: val_loss improved from 0.06160 to 0.06139, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0780 - mean_absolute_error: 0.0780 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614
# Epoch 6/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0781 - mean_absolute_error: 0.0781
# Epoch 00006: val_loss improved from 0.06139 to 0.05883, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0781 - mean_absolute_error: 0.0781 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588
# Epoch 7/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0766 - mean_absolute_error: 0.0766
# Epoch 00007: val_loss did not improve from 0.05883
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0766 - mean_absolute_error: 0.0766 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591
# Epoch 8/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0756 - mean_absolute_error: 0.0756
# Epoch 00008: val_loss improved from 0.05883 to 0.05778, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0756 - mean_absolute_error: 0.0756 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578
# Epoch 9/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0749 - mean_absolute_error: 0.0749
# Epoch 00009: val_loss improved from 0.05778 to 0.05537, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0749 - mean_absolute_error: 0.0749 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554
# Epoch 10/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0711 - mean_absolute_error: 0.0711
# Epoch 00010: val_loss improved from 0.05537 to 0.05422, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542
# Epoch 11/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0723 - mean_absolute_error: 0.0723
# Epoch 00011: val_loss did not improve from 0.05422
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0723 - mean_absolute_error: 0.0723 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548
# Epoch 12/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0709 - mean_absolute_error: 0.0709
# Epoch 00012: val_loss improved from 0.05422 to 0.05346, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0709 - mean_absolute_error: 0.0709 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535
# Epoch 13/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0698 - mean_absolute_error: 0.0698
# Epoch 00013: val_loss improved from 0.05346 to 0.05300, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530
# Epoch 14/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0674 - mean_absolute_error: 0.0674
# Epoch 00014: val_loss improved from 0.05300 to 0.05160, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516
# Epoch 15/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0675 - mean_absolute_error: 0.0675
# Epoch 00015: val_loss improved from 0.05160 to 0.05144, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514
# Epoch 16/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0682 - mean_absolute_error: 0.0682
# Epoch 00016: val_loss improved from 0.05144 to 0.04921, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492
# Epoch 17/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0666 - mean_absolute_error: 0.0666
# Epoch 00017: val_loss did not improve from 0.04921
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498
# Epoch 18/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0642 - mean_absolute_error: 0.0642
# Epoch 00018: val_loss did not improve from 0.04921
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0642 - mean_absolute_error: 0.0642 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498
# Epoch 19/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0679 - mean_absolute_error: 0.0679
# Epoch 00019: val_loss improved from 0.04921 to 0.04715, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471
# Epoch 20/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0620 - mean_absolute_error: 0.0620
# Epoch 00020: val_loss did not improve from 0.04715
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497
# Epoch 21/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0610 - mean_absolute_error: 0.0610
# Epoch 00021: val_loss did not improve from 0.04715
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0610 - mean_absolute_error: 0.0610 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489
# Epoch 22/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0624 - mean_absolute_error: 0.0624
# Epoch 00022: val_loss did not improve from 0.04715
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478
# Epoch 23/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0592 - mean_absolute_error: 0.0592
# Epoch 00023: val_loss did not improve from 0.04715
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0592 - mean_absolute_error: 0.0592 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481
# Epoch 24/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0586 - mean_absolute_error: 0.0586
# Epoch 00024: val_loss improved from 0.04715 to 0.04709, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0586 - mean_absolute_error: 0.0586 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471
# Epoch 25/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0591 - mean_absolute_error: 0.0591
# Epoch 00025: val_loss did not improve from 0.04709
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0591 - mean_absolute_error: 0.0591 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474
# Epoch 26/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0594 - mean_absolute_error: 0.0594
# Epoch 00026: val_loss did not improve from 0.04709
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0594 - mean_absolute_error: 0.0594 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474
# Epoch 27/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0580 - mean_absolute_error: 0.0580
# Epoch 00027: val_loss improved from 0.04709 to 0.04633, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0580 - mean_absolute_error: 0.0580 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463
# Epoch 28/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0576 - mean_absolute_error: 0.0576
# Epoch 00028: val_loss did not improve from 0.04633
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0465 - val_mean_absolute_error: 0.0465
# Epoch 29/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00029: val_loss improved from 0.04633 to 0.04591, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0459 - val_mean_absolute_error: 0.0459
# Epoch 30/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0559 - mean_absolute_error: 0.0559
# Epoch 00030: val_loss improved from 0.04591 to 0.04530, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0453 - val_mean_absolute_error: 0.0453
# Epoch 31/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0578 - mean_absolute_error: 0.0578
# Epoch 00031: val_loss improved from 0.04530 to 0.04512, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451
# Epoch 32/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0566 - mean_absolute_error: 0.0566
# Epoch 00032: val_loss did not improve from 0.04512
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0452 - val_mean_absolute_error: 0.0452
# Epoch 33/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0579 - mean_absolute_error: 0.0579
# Epoch 00033: val_loss improved from 0.04512 to 0.04416, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0579 - mean_absolute_error: 0.0579 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442
# Epoch 34/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0564 - mean_absolute_error: 0.0564
# Epoch 00034: val_loss improved from 0.04416 to 0.04337, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0434 - val_mean_absolute_error: 0.0434
# Epoch 35/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0534 - mean_absolute_error: 0.0534
# Epoch 00035: val_loss did not improve from 0.04337
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0447 - val_mean_absolute_error: 0.0447
# Epoch 36/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0546 - mean_absolute_error: 0.0546
# Epoch 00036: val_loss did not improve from 0.04337
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442
# Epoch 37/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0524 - mean_absolute_error: 0.0524
# Epoch 00037: val_loss did not improve from 0.04337
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0524 - mean_absolute_error: 0.0524 - val_loss: 0.0439 - val_mean_absolute_error: 0.0439
# Epoch 38/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0529 - mean_absolute_error: 0.0529
# Epoch 00038: val_loss did not improve from 0.04337
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0529 - mean_absolute_error: 0.0529 - val_loss: 0.0444 - val_mean_absolute_error: 0.0444
# Epoch 39/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0549 - mean_absolute_error: 0.0549
# Epoch 00039: val_loss improved from 0.04337 to 0.04330, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0433 - val_mean_absolute_error: 0.0433
# Epoch 40/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0539 - mean_absolute_error: 0.0539
# Epoch 00040: val_loss improved from 0.04330 to 0.04203, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0420 - val_mean_absolute_error: 0.0420
# Epoch 41/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0540 - mean_absolute_error: 0.0540
# Epoch 00041: val_loss did not improve from 0.04203
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427
# Epoch 42/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0532 - mean_absolute_error: 0.0532
# Epoch 00042: val_loss did not improve from 0.04203
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0532 - mean_absolute_error: 0.0532 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430
# Epoch 43/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0523 - mean_absolute_error: 0.0523
# Epoch 00043: val_loss did not improve from 0.04203
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431
# Epoch 44/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0527 - mean_absolute_error: 0.0527
# Epoch 00044: val_loss did not improve from 0.04203
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0527 - mean_absolute_error: 0.0527 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431
# Epoch 45/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0543 - mean_absolute_error: 0.0543
# Epoch 00045: val_loss improved from 0.04203 to 0.04175, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.0418 - val_mean_absolute_error: 0.0418
# Epoch 46/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0541 - mean_absolute_error: 0.0541
# Epoch 00046: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - val_loss: 0.0435 - val_mean_absolute_error: 0.0435
# Epoch 47/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0508 - mean_absolute_error: 0.0508
# Epoch 00047: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.0437 - val_mean_absolute_error: 0.0437
# Epoch 48/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0513 - mean_absolute_error: 0.0513
# Epoch 00048: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0513 - mean_absolute_error: 0.0513 - val_loss: 0.0422 - val_mean_absolute_error: 0.0422
# Epoch 49/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0509 - mean_absolute_error: 0.0509
# Epoch 00049: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 50/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0513 - mean_absolute_error: 0.0513
# Epoch 00050: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0513 - mean_absolute_error: 0.0513 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
# Epoch 51/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0503 - mean_absolute_error: 0.0503
# Epoch 00051: val_loss did not improve from 0.04175
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427
# Epoch 52/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0503 - mean_absolute_error: 0.0503
# Epoch 00052: val_loss improved from 0.04175 to 0.04170, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 53/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0522 - mean_absolute_error: 0.0522
# Epoch 00053: val_loss improved from 0.04170 to 0.04147, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 54/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0512 - mean_absolute_error: 0.0512
# Epoch 00054: val_loss did not improve from 0.04147
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0512 - mean_absolute_error: 0.0512 - val_loss: 0.0422 - val_mean_absolute_error: 0.0422
# Epoch 55/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0525 - mean_absolute_error: 0.0525
# Epoch 00055: val_loss did not improve from 0.04147
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0420 - val_mean_absolute_error: 0.0420
# Epoch 56/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0496 - mean_absolute_error: 0.0496
# Epoch 00056: val_loss did not improve from 0.04147
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0496 - mean_absolute_error: 0.0496 - val_loss: 0.0421 - val_mean_absolute_error: 0.0421
# Epoch 57/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0505 - mean_absolute_error: 0.0505
# Epoch 00057: val_loss improved from 0.04147 to 0.03874, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387
# Epoch 58/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0497 - mean_absolute_error: 0.0497
# Epoch 00058: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0497 - mean_absolute_error: 0.0497 - val_loss: 0.0410 - val_mean_absolute_error: 0.0410
# Epoch 59/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0499 - mean_absolute_error: 0.0499
# Epoch 00059: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 60/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0482 - mean_absolute_error: 0.0482
# Epoch 00060: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0482 - mean_absolute_error: 0.0482 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
# Epoch 61/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0500 - mean_absolute_error: 0.0500
# Epoch 00061: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0500 - mean_absolute_error: 0.0500 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404
# Epoch 62/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0479 - mean_absolute_error: 0.0479
# Epoch 00062: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
# Epoch 63/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0467 - mean_absolute_error: 0.0467
# Epoch 00063: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400
# Epoch 64/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0489 - mean_absolute_error: 0.0489
# Epoch 00064: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0489 - mean_absolute_error: 0.0489 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402
# Epoch 65/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0520 - mean_absolute_error: 0.0520
# Epoch 00065: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0520 - mean_absolute_error: 0.0520 - val_loss: 0.0409 - val_mean_absolute_error: 0.0409
# Epoch 66/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0478 - mean_absolute_error: 0.0478
# Epoch 00066: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402
# Epoch 67/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0510 - mean_absolute_error: 0.0510
# Epoch 00067: val_loss did not improve from 0.03874
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408
# Epoch 68/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0474 - mean_absolute_error: 0.0474
# Epoch 00068: val_loss improved from 0.03874 to 0.03862, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386
# Epoch 69/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0488 - mean_absolute_error: 0.0488
# Epoch 00069: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393
# Epoch 70/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0470 - mean_absolute_error: 0.0470
# Epoch 00070: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398
# Epoch 71/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0481 - mean_absolute_error: 0.0481
# Epoch 00071: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0481 - mean_absolute_error: 0.0481 - val_loss: 0.0404 - val_mean_absolute_error: 0.0404
# Epoch 72/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0505 - mean_absolute_error: 0.0505
# Epoch 00072: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0405 - val_mean_absolute_error: 0.0405
# Epoch 73/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0464 - mean_absolute_error: 0.0464
# Epoch 00073: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406
# Epoch 74/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0441 - mean_absolute_error: 0.0441
# Epoch 00074: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406
# Epoch 75/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0465 - mean_absolute_error: 0.0465
# Epoch 00075: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401
# Epoch 76/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0465 - mean_absolute_error: 0.0465
# Epoch 00076: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392
# Epoch 77/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0488 - mean_absolute_error: 0.0488
# Epoch 00077: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396
# Epoch 78/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0462 - mean_absolute_error: 0.0462
# Epoch 00078: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393
# Epoch 79/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0477 - mean_absolute_error: 0.0477
# Epoch 00079: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0477 - mean_absolute_error: 0.0477 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391
# Epoch 80/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0469 - mean_absolute_error: 0.0469
# Epoch 00080: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401
# Epoch 81/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0454 - mean_absolute_error: 0.0454
# Epoch 00081: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0454 - mean_absolute_error: 0.0454 - val_loss: 0.0389 - val_mean_absolute_error: 0.0389
# Epoch 82/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0456 - mean_absolute_error: 0.0456
# Epoch 00082: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.0403 - val_mean_absolute_error: 0.0403
# Epoch 83/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0467 - mean_absolute_error: 0.0467
# Epoch 00083: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0398 - val_mean_absolute_error: 0.0398
# Epoch 84/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0474 - mean_absolute_error: 0.0474
# Epoch 00084: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400
# Epoch 85/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0453 - mean_absolute_error: 0.0453
# Epoch 00085: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0400 - val_mean_absolute_error: 0.0400
# Epoch 86/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0459 - mean_absolute_error: 0.0459
# Epoch 00086: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392
# Epoch 87/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0448 - mean_absolute_error: 0.0448
# Epoch 00087: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391
# Epoch 88/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0477 - mean_absolute_error: 0.0477
# Epoch 00088: val_loss did not improve from 0.03862
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0477 - mean_absolute_error: 0.0477 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394
# Epoch 89/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0453 - mean_absolute_error: 0.0453
# Epoch 00089: val_loss improved from 0.03862 to 0.03723, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372
# Epoch 90/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0445 - mean_absolute_error: 0.0445
# Epoch 00090: val_loss did not improve from 0.03723
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401
# Epoch 91/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0451 - mean_absolute_error: 0.0451
# Epoch 00091: val_loss did not improve from 0.03723
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - val_loss: 0.0395 - val_mean_absolute_error: 0.0395
# Epoch 92/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0442 - mean_absolute_error: 0.0442
# Epoch 00092: val_loss did not improve from 0.03723
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391
# Epoch 93/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0451 - mean_absolute_error: 0.0451
# Epoch 00093: val_loss improved from 0.03723 to 0.03706, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - val_loss: 0.0371 - val_mean_absolute_error: 0.0371
# Epoch 94/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0436 - mean_absolute_error: 0.0436
# Epoch 00094: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393
# Epoch 95/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0439 - mean_absolute_error: 0.0439
# Epoch 00095: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386
# Epoch 96/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0444 - mean_absolute_error: 0.0444
# Epoch 00096: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390
# Epoch 97/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0450 - mean_absolute_error: 0.0450
# Epoch 00097: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - val_loss: 0.0391 - val_mean_absolute_error: 0.0391
# Epoch 98/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0460 - mean_absolute_error: 0.0460
# Epoch 00098: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387
# Epoch 99/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0453 - mean_absolute_error: 0.0453
# Epoch 00099: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0385 - val_mean_absolute_error: 0.0385
# Epoch 100/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0470 - mean_absolute_error: 0.0470
# Epoch 00100: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392
# Epoch 101/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0456 - mean_absolute_error: 0.0456
# Epoch 00101: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.0386 - val_mean_absolute_error: 0.0386
# Epoch 102/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0449 - mean_absolute_error: 0.0449
# Epoch 00102: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379
# Epoch 103/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0444 - mean_absolute_error: 0.0444
# Epoch 00103: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0392 - val_mean_absolute_error: 0.0392
# Epoch 104/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0429 - mean_absolute_error: 0.0429
# Epoch 00104: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0429 - mean_absolute_error: 0.0429 - val_loss: 0.0381 - val_mean_absolute_error: 0.0381
# Epoch 105/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0437 - mean_absolute_error: 0.0437
# Epoch 00105: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372
# Epoch 106/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0434 - mean_absolute_error: 0.0434
# Epoch 00106: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393
# Epoch 107/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0432 - mean_absolute_error: 0.0432
# Epoch 00107: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0381 - val_mean_absolute_error: 0.0381
# Epoch 108/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0427 - mean_absolute_error: 0.0427
# Epoch 00108: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0389 - val_mean_absolute_error: 0.0389
# Epoch 109/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0446 - mean_absolute_error: 0.0446
# Epoch 00109: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0396 - val_mean_absolute_error: 0.0396
# Epoch 110/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0434 - mean_absolute_error: 0.0434
# Epoch 00110: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390
# Epoch 111/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0440 - mean_absolute_error: 0.0440
# Epoch 00111: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383
# Epoch 112/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0421 - mean_absolute_error: 0.0421
# Epoch 00112: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378
# Epoch 113/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0433 - mean_absolute_error: 0.0433
# Epoch 00113: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0433 - mean_absolute_error: 0.0433 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390
# Epoch 114/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0430 - mean_absolute_error: 0.0430
# Epoch 00114: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0430 - mean_absolute_error: 0.0430 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374
# Epoch 115/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0424 - mean_absolute_error: 0.0424
# Epoch 00115: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0387 - val_mean_absolute_error: 0.0387
# Epoch 116/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0434 - mean_absolute_error: 0.0434
# Epoch 00116: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380
# Epoch 117/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0437 - mean_absolute_error: 0.0437
# Epoch 00117: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0389 - val_mean_absolute_error: 0.0389
# Epoch 118/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0416 - mean_absolute_error: 0.0416
# Epoch 00118: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0385 - val_mean_absolute_error: 0.0385
# Epoch 119/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0423 - mean_absolute_error: 0.0423
# Epoch 00119: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0423 - mean_absolute_error: 0.0423 - val_loss: 0.0373 - val_mean_absolute_error: 0.0373
# Epoch 120/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0431 - mean_absolute_error: 0.0431
# Epoch 00120: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0431 - mean_absolute_error: 0.0431 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375
# Epoch 121/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0432 - mean_absolute_error: 0.0432
# Epoch 00121: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378
# Epoch 122/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0422 - mean_absolute_error: 0.0422
# Epoch 00122: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375
# Epoch 123/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0416 - mean_absolute_error: 0.0416
# Epoch 00123: val_loss did not improve from 0.03706
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0376 - val_mean_absolute_error: 0.0376
# Epoch 124/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0441 - mean_absolute_error: 0.0441
# Epoch 00124: val_loss improved from 0.03706 to 0.03685, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0368 - val_mean_absolute_error: 0.0368
# Epoch 125/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0413 - mean_absolute_error: 0.0413
# Epoch 00125: val_loss did not improve from 0.03685
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374
# Epoch 126/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0427 - mean_absolute_error: 0.0427
# Epoch 00126: val_loss did not improve from 0.03685
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0373 - val_mean_absolute_error: 0.0373
# Epoch 127/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0406 - mean_absolute_error: 0.0406
# Epoch 00127: val_loss did not improve from 0.03685
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380
# Epoch 128/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0430 - mean_absolute_error: 0.0430
# Epoch 00128: val_loss improved from 0.03685 to 0.03654, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0430 - mean_absolute_error: 0.0430 - val_loss: 0.0365 - val_mean_absolute_error: 0.0365
# Epoch 129/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0413 - mean_absolute_error: 0.0413
# Epoch 00129: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374
# Epoch 130/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0429 - mean_absolute_error: 0.0429
# Epoch 00130: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0429 - mean_absolute_error: 0.0429 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380
# Epoch 131/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0427 - mean_absolute_error: 0.0427
# Epoch 00131: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378
# Epoch 132/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0414 - mean_absolute_error: 0.0414
# Epoch 00132: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0414 - mean_absolute_error: 0.0414 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383
# Epoch 133/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0418 - mean_absolute_error: 0.0418
# Epoch 00133: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0372 - val_mean_absolute_error: 0.0372
# Epoch 134/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0437 - mean_absolute_error: 0.0437
# Epoch 00134: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0370 - val_mean_absolute_error: 0.0370
# Epoch 135/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0428 - mean_absolute_error: 0.0428
# Epoch 00135: val_loss did not improve from 0.03654
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374
# Epoch 136/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0415 - mean_absolute_error: 0.0415
# Epoch 00136: val_loss improved from 0.03654 to 0.03606, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/xception_angles_tang_2.h5
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0361 - val_mean_absolute_error: 0.0361
# Epoch 137/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0411 - mean_absolute_error: 0.0411
# Epoch 00137: val_loss did not improve from 0.03606
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0411 - mean_absolute_error: 0.0411 - val_loss: 0.0376 - val_mean_absolute_error: 0.0376
# Epoch 138/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0410 - mean_absolute_error: 0.0410
# Epoch 00138: val_loss did not improve from 0.03606
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379
# Epoch 139/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0429 - mean_absolute_error: 0.0429
# Epoch 00139: val_loss did not improve from 0.03606
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0429 - mean_absolute_error: 0.0429 - val_loss: 0.0367 - val_mean_absolute_error: 0.0367
# Epoch 140/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0423 - mean_absolute_error: 0.0423
# Epoch 00140: val_loss did not improve from 0.03606
# ...
# 25/25 [==============================] - 4s 146ms/step - loss: 0.1878 - mean_absolute_error: 0.1878 - val_loss: 0.2115 - val_mean_absolute_error: 0.2115
# Epoch 158/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1907 - mean_absolute_error: 0.1907
# Epoch 00158: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1907 - mean_absolute_error: 0.1907 - val_loss: 0.2157 - val_mean_absolute_error: 0.2157
# Epoch 159/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1909 - mean_absolute_error: 0.1909
# Epoch 00159: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1909 - mean_absolute_error: 0.1909 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146
# Epoch 160/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1900 - mean_absolute_error: 0.1900
# Epoch 00160: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1900 - mean_absolute_error: 0.1900 - val_loss: 0.2153 - val_mean_absolute_error: 0.2153
# Epoch 161/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1868 - mean_absolute_error: 0.1868
# Epoch 00161: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1868 - mean_absolute_error: 0.1868 - val_loss: 0.2127 - val_mean_absolute_error: 0.2127
# Epoch 162/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.1870
# Epoch 00162: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.2160 - val_mean_absolute_error: 0.2160
# Epoch 163/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1890 - mean_absolute_error: 0.1890
# Epoch 00163: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1890 - mean_absolute_error: 0.1890 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148
# Epoch 164/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1896 - mean_absolute_error: 0.1896
# Epoch 00164: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1896 - mean_absolute_error: 0.1896 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148
# Epoch 165/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1894 - mean_absolute_error: 0.1894
# Epoch 00165: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1894 - mean_absolute_error: 0.1894 - val_loss: 0.2153 - val_mean_absolute_error: 0.2153
# Epoch 166/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1881 - mean_absolute_error: 0.1881
# Epoch 00166: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1881 - mean_absolute_error: 0.1881 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145
# Epoch 167/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.1870
# Epoch 00167: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148
# Epoch 168/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1853 - mean_absolute_error: 0.1853
# Epoch 00168: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1853 - mean_absolute_error: 0.1853 - val_loss: 0.2134 - val_mean_absolute_error: 0.2134
# Epoch 169/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.1873
# Epoch 00169: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 0.2147 - val_mean_absolute_error: 0.2147
# Epoch 170/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1875 - mean_absolute_error: 0.1875
# Epoch 00170: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1875 - mean_absolute_error: 0.1875 - val_loss: 0.2151 - val_mean_absolute_error: 0.2151
# Epoch 171/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1867 - mean_absolute_error: 0.1867
# Epoch 00171: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1867 - mean_absolute_error: 0.1867 - val_loss: 0.2154 - val_mean_absolute_error: 0.2154
# Epoch 172/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1865 - mean_absolute_error: 0.1865
# Epoch 00172: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1865 - mean_absolute_error: 0.1865 - val_loss: 0.2125 - val_mean_absolute_error: 0.2125
# Epoch 173/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.1870
# Epoch 00173: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.2149 - val_mean_absolute_error: 0.2149
# Epoch 174/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1880 - mean_absolute_error: 0.1880
# Epoch 00174: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1880 - mean_absolute_error: 0.1880 - val_loss: 0.2131 - val_mean_absolute_error: 0.2131
# Epoch 175/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1858 - mean_absolute_error: 0.1858
# Epoch 00175: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1858 - mean_absolute_error: 0.1858 - val_loss: 0.2149 - val_mean_absolute_error: 0.2149
# Epoch 176/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1867 - mean_absolute_error: 0.1867
# Epoch 00176: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1867 - mean_absolute_error: 0.1867 - val_loss: 0.2143 - val_mean_absolute_error: 0.2143
# Epoch 177/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1873 - mean_absolute_error: 0.1873
# Epoch 00177: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 0.2132 - val_mean_absolute_error: 0.2132
# Epoch 178/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1857 - mean_absolute_error: 0.1857
# Epoch 00178: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1857 - mean_absolute_error: 0.1857 - val_loss: 0.2139 - val_mean_absolute_error: 0.2139
# Epoch 179/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1859 - mean_absolute_error: 0.1859
# Epoch 00179: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1859 - mean_absolute_error: 0.1859 - val_loss: 0.2133 - val_mean_absolute_error: 0.2133
# Epoch 180/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1861 - mean_absolute_error: 0.1861
# Epoch 00180: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - val_loss: 0.2150 - val_mean_absolute_error: 0.2150
# Epoch 181/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1841 - mean_absolute_error: 0.1841
# Epoch 00181: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1841 - mean_absolute_error: 0.1841 - val_loss: 0.2154 - val_mean_absolute_error: 0.2154
# Epoch 182/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1849 - mean_absolute_error: 0.1849
# Epoch 00182: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 127ms/step - loss: 0.1849 - mean_absolute_error: 0.1849 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146
# Epoch 183/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1861 - mean_absolute_error: 0.1861
# Epoch 00183: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - val_loss: 0.2133 - val_mean_absolute_error: 0.2133
# Epoch 184/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1874 - mean_absolute_error: 0.1874
# Epoch 00184: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1874 - mean_absolute_error: 0.1874 - val_loss: 0.2153 - val_mean_absolute_error: 0.2153
# Epoch 185/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1869 - mean_absolute_error: 0.1869
# Epoch 00185: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1869 - mean_absolute_error: 0.1869 - val_loss: 0.2156 - val_mean_absolute_error: 0.2156
# Epoch 186/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1852 - mean_absolute_error: 0.1852
# Epoch 00186: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1852 - mean_absolute_error: 0.1852 - val_loss: 0.2161 - val_mean_absolute_error: 0.2161
# Epoch 187/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1854 - mean_absolute_error: 0.1854
# Epoch 00187: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1854 - mean_absolute_error: 0.1854 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145
# Epoch 188/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1839 - mean_absolute_error: 0.1839
# Epoch 00188: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1839 - mean_absolute_error: 0.1839 - val_loss: 0.2134 - val_mean_absolute_error: 0.2134
# Epoch 189/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1832 - mean_absolute_error: 0.1832
# Epoch 00189: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1832 - mean_absolute_error: 0.1832 - val_loss: 0.2150 - val_mean_absolute_error: 0.2150
# Epoch 190/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1843 - mean_absolute_error: 0.1843
# Epoch 00190: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1843 - mean_absolute_error: 0.1843 - val_loss: 0.2141 - val_mean_absolute_error: 0.2141
# Epoch 191/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1831 - mean_absolute_error: 0.1831
# Epoch 00191: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1831 - mean_absolute_error: 0.1831 - val_loss: 0.2137 - val_mean_absolute_error: 0.2137
# Epoch 192/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1861 - mean_absolute_error: 0.1861
# Epoch 00192: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 122ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - val_loss: 0.2128 - val_mean_absolute_error: 0.2128
# Epoch 193/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1843 - mean_absolute_error: 0.1843
# Epoch 00193: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 127ms/step - loss: 0.1843 - mean_absolute_error: 0.1843 - val_loss: 0.2136 - val_mean_absolute_error: 0.2136
# Epoch 194/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1841 - mean_absolute_error: 0.1841
# Epoch 00194: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1841 - mean_absolute_error: 0.1841 - val_loss: 0.2152 - val_mean_absolute_error: 0.2152
# Epoch 195/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1879 - mean_absolute_error: 0.1879
# Epoch 00195: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1879 - mean_absolute_error: 0.1879 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145
# Epoch 196/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1833 - mean_absolute_error: 0.1833
# Epoch 00196: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1833 - mean_absolute_error: 0.1833 - val_loss: 0.2133 - val_mean_absolute_error: 0.2133
# Epoch 197/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1826 - mean_absolute_error: 0.1826
# Epoch 00197: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1826 - mean_absolute_error: 0.1826 - val_loss: 0.2143 - val_mean_absolute_error: 0.2143
# Epoch 198/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1833 - mean_absolute_error: 0.1833
# Epoch 00198: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1833 - mean_absolute_error: 0.1833 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145
# Epoch 199/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1837 - mean_absolute_error: 0.1837
# Epoch 00199: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1837 - mean_absolute_error: 0.1837 - val_loss: 0.2143 - val_mean_absolute_error: 0.2143
# Epoch 200/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1838 - mean_absolute_error: 0.1838
# Epoch 00200: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1838 - mean_absolute_error: 0.1838 - val_loss: 0.2132 - val_mean_absolute_error: 0.2132
# Epoch 201/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1824 - mean_absolute_error: 0.1824
# Epoch 00201: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 121ms/step - loss: 0.1824 - mean_absolute_error: 0.1824 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148
# Epoch 202/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1841 - mean_absolute_error: 0.1841
# Epoch 00202: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1841 - mean_absolute_error: 0.1841 - val_loss: 0.2153 - val_mean_absolute_error: 0.2153
# Epoch 203/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1820 - mean_absolute_error: 0.1820
# Epoch 00203: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 127ms/step - loss: 0.1820 - mean_absolute_error: 0.1820 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146
# Epoch 204/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1826 - mean_absolute_error: 0.1826
# Epoch 00204: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1826 - mean_absolute_error: 0.1826 - val_loss: 0.2139 - val_mean_absolute_error: 0.2139
# Epoch 205/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1819 - mean_absolute_error: 0.1819
# Epoch 00205: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1819 - mean_absolute_error: 0.1819 - val_loss: 0.2124 - val_mean_absolute_error: 0.2124
# Epoch 206/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1831 - mean_absolute_error: 0.1831
# Epoch 00206: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1831 - mean_absolute_error: 0.1831 - val_loss: 0.2149 - val_mean_absolute_error: 0.2149
# Epoch 207/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1818 - mean_absolute_error: 0.1818
# Epoch 00207: val_loss did not improve from 0.21154
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1818 - mean_absolute_error: 0.1818 - val_loss: 0.2141 - val_mean_absolute_error: 0.2141
# Epoch 00207: early stopping

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history_ft[i+2].history['loss'])
    plt.plot(history_ft[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
