# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import Sequence
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
train_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '1000', 'train')
val_image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', '1000', 'val')
train_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '1000', 'train')
val_labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', '1000', 'val')
load_models_path = os.path.join('/home', 'renat_sergazinov', 'python-git-workspace', 
                               'PhotoForceReconML', 'models')
save_models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '1000')

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels should be loaded from a separate directory. Each label corresponds to two particles.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Loading the data

# %%
# Load the train and validation sets

X_train, X_val = {}, {}
y_train, y_val = {}, {}

for k in range(5):
    i = k + 2
    X_path_train = os.path.join(train_image_path, str(i))
    X_path_val = os.path.join(val_image_path, str(i))
    X_train[i] = [os.path.join(X_path_train, name) for name in sorted(os.listdir(X_path_train), key = sorter)]
    X_val[i] = [os.path.join(X_path_val, name) for name in sorted(os.listdir(X_path_val), key = sorter)]
    y_train[i] = np.load(os.path.join(train_labels_path, str(i), 'mags.npy'))
    y_val[i] = np.load(os.path.join(val_labels_path, str(i), 'mags.npy'))

# %%
# Apply data generators
gaussblur = GaussBlur(1)
params = {'batch_size': 32, 
          'dim': (128, 128), 
          'n_channels': 3, 
          'rescale': 1 / 255, 
          'shuffle': True, 
          'save_dir': None,
          'preprocessing_func': gaussblur.blur
          }

training_generator = {}
validation_generator = {}

for k in range(5):
    i = k + 2
    training_generator[i] = DataGeneratorTrain(X_train[i], y_train[i], **params)
    validation_generator[i] = DataGeneratorTrain(X_val[i], y_val[i], **params)

# %% [markdown]
# #### InceptionResNetV2 Models Building

# %% [markdown]
# Convolutional neural networks is defined and compiled in this step.

# %%
# Load models
models_m = dict()                         
for k in range(5):
     i = k + 2
     models_m[i] = load_model(os.path.join(load_models_path, 'InceptionResNetV2_mags_'+str(i)+'.h5'))

# %%
for k in range(5):
    i = k + 2
    models_m[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 55,912,674
# Trainable params: 55,852,130
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1536)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 55,913,699
# Trainable params: 55,853,155
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 55,914,724
# Trainable params: 55,854,180
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1536)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 55,915,749
# Trainable params: 55,855,205
# Non-trainable params: 60,544
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Model)  (None, 2, 2, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1536)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1573888
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 55,916,774
# Trainable params: 55,856,230
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
for k in range(5):
    i = 2 + k
    models_m[i].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = dict()
for k in range(5):
    i = k + 2
    model_path = os.path.join(save_models_path, 'InceptionResNetV2_mags_'+str(i)+'.h5')
    mc[i] = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
epochs = 1000
history = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history[i] = models_m[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.1808 - mean_absolute_error: 0.1808
# Epoch 00001: val_loss improved from inf to 0.12427, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 7s 279ms/step - loss: 0.1808 - mean_absolute_error: 0.1808 - val_loss: 0.1243 - val_mean_absolute_error: 0.1243
# Epoch 2/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0861 - mean_absolute_error: 0.0861
# Epoch 00002: val_loss improved from 0.12427 to 0.04455, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - val_loss: 0.0445 - val_mean_absolute_error: 0.0445
# Epoch 3/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0284 - mean_absolute_error: 0.0284
# Epoch 00003: val_loss improved from 0.04455 to 0.01815, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 4/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.0195
# Epoch 00004: val_loss improved from 0.01815 to 0.00981, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098
# Epoch 5/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0166 - mean_absolute_error: 0.0166
# Epoch 00005: val_loss improved from 0.00981 to 0.00769, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0166 - mean_absolute_error: 0.0166 - val_loss: 0.0077 - val_mean_absolute_error: 0.0077
# Epoch 6/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0156 - mean_absolute_error: 0.0156
# Epoch 00006: val_loss improved from 0.00769 to 0.00727, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0156 - mean_absolute_error: 0.0156 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073
# Epoch 7/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0151 - mean_absolute_error: 0.0151
# Epoch 00007: val_loss improved from 0.00727 to 0.00698, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 6s 254ms/step - loss: 0.0151 - mean_absolute_error: 0.0151 - val_loss: 0.0070 - val_mean_absolute_error: 0.0070
# Epoch 8/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0145 - mean_absolute_error: 0.0145
# Epoch 00008: val_loss improved from 0.00698 to 0.00638, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0145 - mean_absolute_error: 0.0145 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064
# Epoch 9/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0146 - mean_absolute_error: 0.0146
# Epoch 00009: val_loss improved from 0.00638 to 0.00636, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0146 - mean_absolute_error: 0.0146 - val_loss: 0.0064 - val_mean_absolute_error: 0.0064
# Epoch 10/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0139 - mean_absolute_error: 0.0139
# Epoch 00010: val_loss improved from 0.00636 to 0.00627, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0139 - mean_absolute_error: 0.0139 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063
# Epoch 11/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0141 - mean_absolute_error: 0.0141
# Epoch 00011: val_loss improved from 0.00627 to 0.00621, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0062 - val_mean_absolute_error: 0.0062
# Epoch 12/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0143 - mean_absolute_error: 0.0143
# Epoch 00012: val_loss improved from 0.00621 to 0.00580, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 13/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0136 - mean_absolute_error: 0.0136
# Epoch 00013: val_loss improved from 0.00580 to 0.00564, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 14/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0140 - mean_absolute_error: 0.0140
# Epoch 00014: val_loss improved from 0.00564 to 0.00563, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 6s 227ms/step - loss: 0.0140 - mean_absolute_error: 0.0140 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 15/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0132 - mean_absolute_error: 0.0132
# Epoch 00015: val_loss improved from 0.00563 to 0.00547, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0132 - mean_absolute_error: 0.0132 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 16/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0136 - mean_absolute_error: 0.0136
# Epoch 00016: val_loss improved from 0.00547 to 0.00539, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 17/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0133 - mean_absolute_error: 0.0133
# Epoch 00017: val_loss did not improve from 0.00539
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 18/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0134 - mean_absolute_error: 0.0134
# Epoch 00018: val_loss improved from 0.00539 to 0.00524, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 19/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0130 - mean_absolute_error: 0.0130
# Epoch 00019: val_loss did not improve from 0.00524
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0053 - val_mean_absolute_error: 0.0053
# Epoch 20/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0133 - mean_absolute_error: 0.0133
# Epoch 00020: val_loss did not improve from 0.00524
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 21/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0134 - mean_absolute_error: 0.0134
# Epoch 00021: val_loss improved from 0.00524 to 0.00489, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 22/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0137 - mean_absolute_error: 0.0137
# Epoch 00022: val_loss did not improve from 0.00489
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0137 - mean_absolute_error: 0.0137 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 23/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0134 - mean_absolute_error: 0.0134
# Epoch 00023: val_loss improved from 0.00489 to 0.00489, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 24/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0129 - mean_absolute_error: 0.0129
# Epoch 00024: val_loss improved from 0.00489 to 0.00468, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 219ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 25/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 00025: val_loss did not improve from 0.00468
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0056 - val_mean_absolute_error: 0.0056
# Epoch 26/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0129 - mean_absolute_error: 0.0129
# Epoch 00026: val_loss did not improve from 0.00468
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 27/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0134 - mean_absolute_error: 0.0134
# Epoch 00027: val_loss did not improve from 0.00468
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 28/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 00028: val_loss did not improve from 0.00468
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 29/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0130 - mean_absolute_error: 0.0130
# Epoch 00029: val_loss did not improve from 0.00468
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 30/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0132 - mean_absolute_error: 0.0132
# Epoch 00030: val_loss improved from 0.00468 to 0.00461, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 6s 229ms/step - loss: 0.0132 - mean_absolute_error: 0.0132 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 31/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 00031: val_loss did not improve from 0.00461
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 32/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 00032: val_loss improved from 0.00461 to 0.00460, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 33/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0131 - mean_absolute_error: 0.0131
# Epoch 00033: val_loss did not improve from 0.00460
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 34/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0129 - mean_absolute_error: 0.0129
# Epoch 00034: val_loss did not improve from 0.00460
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 35/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00035: val_loss did not improve from 0.00460
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 36/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - mean_absolute_error: 0.0125
# Epoch 00036: val_loss did not improve from 0.00460
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 37/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0130 - mean_absolute_error: 0.0130
# Epoch 00037: val_loss improved from 0.00460 to 0.00459, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 38/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00038: val_loss did not improve from 0.00459
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 39/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0130 - mean_absolute_error: 0.0130
# Epoch 00039: val_loss did not improve from 0.00459
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 40/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00040: val_loss did not improve from 0.00459
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 41/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00041: val_loss did not improve from 0.00459
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0063 - val_mean_absolute_error: 0.0063
# Epoch 42/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00042: val_loss improved from 0.00459 to 0.00452, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 43/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00043: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 44/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0127 - mean_absolute_error: 0.0127
# Epoch 00044: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 45/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00045: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 46/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00046: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 47/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - mean_absolute_error: 0.0125
# Epoch 00047: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 48/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00048: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 49/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00049: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0055 - val_mean_absolute_error: 0.0055
# Epoch 50/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00050: val_loss did not improve from 0.00452
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 51/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00051: val_loss improved from 0.00452 to 0.00439, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 52/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00052: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 53/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00053: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 54/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00054: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 55/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00055: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 56/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00056: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 57/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00057: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 58/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0128
# Epoch 00058: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 59/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.0114
# Epoch 00059: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 60/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00060: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 61/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - mean_absolute_error: 0.0125
# Epoch 00061: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 62/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00062: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 63/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00063: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 64/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00064: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 65/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00065: val_loss improved from 0.00439 to 0.00439, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 66/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0127 - mean_absolute_error: 0.0127
# Epoch 00066: val_loss did not improve from 0.00439
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 67/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00067: val_loss improved from 0.00439 to 0.00426, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 68/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0133 - mean_absolute_error: 0.0133
# Epoch 00068: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 69/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00069: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 70/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00070: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 71/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00071: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 72/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00072: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 73/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.0117
# Epoch 00073: val_loss did not improve from 0.00426
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 74/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0126
# Epoch 00074: val_loss improved from 0.00426 to 0.00419, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 75/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00075: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 76/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00076: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 77/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00077: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 78/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00078: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 79/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00079: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 80/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00080: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 81/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0115
# Epoch 00081: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0058 - val_mean_absolute_error: 0.0058
# Epoch 82/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00082: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 83/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00083: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 84/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00084: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 85/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00085: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 86/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00086: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 87/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00087: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 88/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00088: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 89/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0115
# Epoch 00089: val_loss did not improve from 0.00419
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 90/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00090: val_loss improved from 0.00419 to 0.00417, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 91/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00091: val_loss did not improve from 0.00417
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 92/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00092: val_loss improved from 0.00417 to 0.00411, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041
# Epoch 93/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00093: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041
# Epoch 94/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00094: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 95/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0121 - mean_absolute_error: 0.0121
# Epoch 00095: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 96/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00096: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 97/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0121 - mean_absolute_error: 0.0121
# Epoch 00097: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 98/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00098: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 99/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.0114
# Epoch 00099: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 100/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00100: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 101/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0115
# Epoch 00101: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041
# Epoch 102/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00102: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 103/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0121 - mean_absolute_error: 0.0121
# Epoch 00103: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 104/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.0117
# Epoch 00104: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 105/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00105: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 106/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00106: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 107/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0122
# Epoch 00107: val_loss did not improve from 0.00411
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0052 - val_mean_absolute_error: 0.0052
# Epoch 108/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00108: val_loss improved from 0.00411 to 0.00402, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_2.h5
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0040 - val_mean_absolute_error: 0.0040
# Epoch 109/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.0117
# Epoch 00109: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 110/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00110: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 111/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00111: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 112/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0112 - mean_absolute_error: 0.0112
# Epoch 00112: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 113/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00113: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 114/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0115
# Epoch 00114: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 115/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00115: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 116/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00116: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 117/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00117: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0045 - val_mean_absolute_error: 0.0045
# Epoch 118/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00118: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0069 - val_mean_absolute_error: 0.0069
# Epoch 119/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00119: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 120/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00120: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 121/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00121: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0057 - val_mean_absolute_error: 0.0057
# Epoch 122/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0111 - mean_absolute_error: 0.0111
# Epoch 00122: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0054 - val_mean_absolute_error: 0.0054
# Epoch 123/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00123: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 124/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0123
# Epoch 00124: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041
# Epoch 125/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00125: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 126/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00126: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0050 - val_mean_absolute_error: 0.0050
# Epoch 127/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0119
# Epoch 00127: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0049 - val_mean_absolute_error: 0.0049
# Epoch 128/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00128: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 129/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0121 - mean_absolute_error: 0.0121
# Epoch 00129: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0041 - val_mean_absolute_error: 0.0041
# Epoch 130/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00130: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0046 - val_mean_absolute_error: 0.0046
# Epoch 131/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0115
# Epoch 00131: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 132/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0112 - mean_absolute_error: 0.0112
# Epoch 00132: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 133/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0125 - mean_absolute_error: 0.0125
# Epoch 00133: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 134/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00134: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 135/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.0117
# Epoch 00135: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 136/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0118
# Epoch 00136: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0048 - val_mean_absolute_error: 0.0048
# Epoch 137/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0124
# Epoch 00137: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0043 - val_mean_absolute_error: 0.0043
# Epoch 138/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0113 - mean_absolute_error: 0.0113
# Epoch 00138: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.0042 - val_mean_absolute_error: 0.0042
# Epoch 139/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0120
# Epoch 00139: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0047 - val_mean_absolute_error: 0.0047
# Epoch 140/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.0116
# Epoch 00140: val_loss did not improve from 0.00402
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0044 - val_mean_absolute_error: 0.0044
# Epoch 141/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.0114
# Epoch 00141: val_loss did not improve from 0.00402
# ...
# Epoch 00081: val_loss improved from 0.07169 to 0.07158, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/1000/InceptionResNetV2_mags_6.h5
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0638 - mean_absolute_error: 0.0638 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 82/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0648 - mean_absolute_error: 0.0648
# Epoch 00082: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740
# Epoch 83/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0636 - mean_absolute_error: 0.0636
# Epoch 00083: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0636 - mean_absolute_error: 0.0636 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732
# Epoch 84/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0631 - mean_absolute_error: 0.0631
# Epoch 00084: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 85/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0666 - mean_absolute_error: 0.0666
# Epoch 00085: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.0729 - val_mean_absolute_error: 0.0729
# Epoch 86/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0637 - mean_absolute_error: 0.0637
# Epoch 00086: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0637 - mean_absolute_error: 0.0637 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723
# Epoch 87/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0619 - mean_absolute_error: 0.0619
# Epoch 00087: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 88/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0661 - mean_absolute_error: 0.0661
# Epoch 00088: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0661 - mean_absolute_error: 0.0661 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 89/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0653 - mean_absolute_error: 0.0653
# Epoch 00089: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - val_loss: 0.0736 - val_mean_absolute_error: 0.0736
# Epoch 90/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0650 - mean_absolute_error: 0.0650
# Epoch 00090: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 91/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0627 - mean_absolute_error: 0.0627
# Epoch 00091: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0627 - mean_absolute_error: 0.0627 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725
# Epoch 92/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0640 - mean_absolute_error: 0.0640
# Epoch 00092: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - val_loss: 0.0720 - val_mean_absolute_error: 0.0720
# Epoch 93/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0628 - mean_absolute_error: 0.0628
# Epoch 00093: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 94/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0630 - mean_absolute_error: 0.0630
# Epoch 00094: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.0737 - val_mean_absolute_error: 0.0737
# Epoch 95/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0620 - mean_absolute_error: 0.0620
# Epoch 00095: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.0744 - val_mean_absolute_error: 0.0744
# Epoch 96/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0633 - mean_absolute_error: 0.0633
# Epoch 00096: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738
# Epoch 97/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0633 - mean_absolute_error: 0.0633
# Epoch 00097: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0747 - val_mean_absolute_error: 0.0747
# Epoch 98/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0626 - mean_absolute_error: 0.0626
# Epoch 00098: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.0735 - val_mean_absolute_error: 0.0735
# Epoch 99/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0646 - mean_absolute_error: 0.0646
# Epoch 00099: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0646 - mean_absolute_error: 0.0646 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 100/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0644 - mean_absolute_error: 0.0644
# Epoch 00100: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0644 - mean_absolute_error: 0.0644 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 101/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0650 - mean_absolute_error: 0.0650
# Epoch 00101: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732
# Epoch 102/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0657 - mean_absolute_error: 0.0657
# Epoch 00102: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.0742 - val_mean_absolute_error: 0.0742
# Epoch 103/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0621 - mean_absolute_error: 0.0621
# Epoch 00103: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0621 - mean_absolute_error: 0.0621 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
# Epoch 104/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0633 - mean_absolute_error: 0.0633
# Epoch 00104: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 105/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0641 - mean_absolute_error: 0.0641
# Epoch 00105: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0641 - mean_absolute_error: 0.0641 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 106/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0632 - mean_absolute_error: 0.0632
# Epoch 00106: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.0742 - val_mean_absolute_error: 0.0742
# Epoch 107/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0632 - mean_absolute_error: 0.0632
# Epoch 00107: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 108/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0631 - mean_absolute_error: 0.0631
# Epoch 00108: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732
# Epoch 109/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0625 - mean_absolute_error: 0.0625
# Epoch 00109: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721
# Epoch 110/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0615 - mean_absolute_error: 0.0615
# Epoch 00110: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0615 - mean_absolute_error: 0.0615 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734
# Epoch 111/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0619 - mean_absolute_error: 0.0619
# Epoch 00111: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722
# Epoch 112/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0611 - mean_absolute_error: 0.0611
# Epoch 00112: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0611 - mean_absolute_error: 0.0611 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734
# Epoch 113/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0628 - mean_absolute_error: 0.0628
# Epoch 00113: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0729 - val_mean_absolute_error: 0.0729
# Epoch 114/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0625 - mean_absolute_error: 0.0625
# Epoch 00114: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 147ms/step - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 115/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0615 - mean_absolute_error: 0.0615
# Epoch 00115: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0615 - mean_absolute_error: 0.0615 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721
# Epoch 116/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0602 - mean_absolute_error: 0.0602
# Epoch 00116: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0602 - mean_absolute_error: 0.0602 - val_loss: 0.0741 - val_mean_absolute_error: 0.0741
# Epoch 117/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0615 - mean_absolute_error: 0.0615
# Epoch 00117: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0615 - mean_absolute_error: 0.0615 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728
# Epoch 118/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0622 - mean_absolute_error: 0.0622
# Epoch 00118: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0741 - val_mean_absolute_error: 0.0741
# Epoch 119/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0628 - mean_absolute_error: 0.0628
# Epoch 00119: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738
# Epoch 120/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0624 - mean_absolute_error: 0.0624
# Epoch 00120: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.0744 - val_mean_absolute_error: 0.0744
# Epoch 121/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0649 - mean_absolute_error: 0.0649
# Epoch 00121: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.0737 - val_mean_absolute_error: 0.0737
# Epoch 122/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0616 - mean_absolute_error: 0.0616
# Epoch 00122: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740
# Epoch 123/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0645 - mean_absolute_error: 0.0645
# Epoch 00123: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0645 - mean_absolute_error: 0.0645 - val_loss: 0.0736 - val_mean_absolute_error: 0.0736
# Epoch 124/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0639 - mean_absolute_error: 0.0639
# Epoch 00124: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 148ms/step - loss: 0.0639 - mean_absolute_error: 0.0639 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732
# Epoch 125/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0621 - mean_absolute_error: 0.0621
# Epoch 00125: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0621 - mean_absolute_error: 0.0621 - val_loss: 0.0733 - val_mean_absolute_error: 0.0733
# Epoch 126/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0628 - mean_absolute_error: 0.0628
# Epoch 00126: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 127/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0618 - mean_absolute_error: 0.0618
# Epoch 00127: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 151ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725
# Epoch 128/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0618 - mean_absolute_error: 0.0618
# Epoch 00128: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746
# Epoch 129/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0606 - mean_absolute_error: 0.0606
# Epoch 00129: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.0729 - val_mean_absolute_error: 0.0729
# Epoch 130/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0617 - mean_absolute_error: 0.0617
# Epoch 00130: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 131/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.0622 - mean_absolute_error: 0.0622
# Epoch 00131: val_loss did not improve from 0.07158
# 25/25 [==============================] - 4s 150ms/step - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0760 - val_mean_absolute_error: 0.0760
# Epoch 00131: early stopping

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history[i+2].history['loss'])
    plt.plot(history[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
