# %% [markdown]
# #### Loading libraries

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import to_categorical
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', 'test')
labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', 'test')
models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '1000')

# %% [markdown]
# #### Define image processor and data generator

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Load the data

# %%
#--- Load images ---#
# Extract individual image paths
img_paths = {}
for k in range(2, 7):
    path_prefix = os.path.join(image_path, str(k))
    img_paths[k] = [os.path.join(path_prefix, name) for name in sorted(os.listdir(path_prefix), key = sorter)]
# Create data generators
gaussblur = GaussBlur(1)
params = {'dim': (128, 128), 'n_channels': 3, 'rescale': 1 / 255, 
          'preprocessing_func': gaussblur.blur}
# Load images (for all number of forces) as matrix
X = dict()
for k in range(2, 7): 
    test_generator = DataGenerator(img_paths[k], **params)   
    X[k] = test_generator.generate()

# %%
#--- Load magnitude labels ---#
y_lm = dict()
for k in range(2, 7): y_lm[k] = np.load(os.path.join(labels_path, str(k), 'mags.npy'))

# %%
#--- Histogram of mean magnitudes ---#
for k in range(2,7):
    n, bins, patches = plt.hist(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30), facecolor='g', alpha=0.75)
    plt.xlabel('Magnitude')
    plt.ylabel('Count')
    plt.title('Histogram of mean magnitudes for ' + str(k) + ' forces')
    plt.xlim(-0.1, 1.6)
    plt.grid(True)
    plt.show()

# %%
#--- Split magnitudes into bins ---#
bins = {}
bin_edges = np.linspace(0,1.5,30)
for k in range(2, 7): bins[k] = np.digitize(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30))

# %% [markdown]
# #### Load and test models

# %%
#--- Load models ---#
models_m = dict()                         
for k in range(2, 7): 
    models_m[k] = load_model(os.path.join(models_path, 'InceptionResNetV2_mags_'+str(k)+'.h5'))
    models_m[k].compile(metrics = ['mean_absolute_error', "mean_absolute_percentage_error"])

# %%
#--- Test models ---#
error_mae = np.empty([len(bin_edges) - 1, 5]) * np.nan 
error_mape = np.empty([len(bin_edges) - 1, 5]) * np.nan
for k in range(2, 7):
    print("Num forces: ", k)
    for i in range(1, len(bin_edges) - 1):
        if (sum(bins[k] == i) > 0):
            print("Bin: ", i)
            loss = models_m[k].evaluate(X[k][bins[k] == i, ], y_lm[k][bins[k] == i, ])
            error_mae[i - 1, k - 2] = loss[1]
            error_mape[i - 1, k - 2] = loss[2]
# Out:
# Num forces:  2
# Bin:  2
# 4/4 [==============================] - 62s 15s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.2874
# Bin:  3
# 8/8 [==============================] - 65s 8s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 2.4147
# Bin:  4
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 1.6899
# Bin:  5
# 7/7 [==============================] - 66s 9s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 1.6881
# Bin:  6
# 5/5 [==============================] - 67s 13s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.9800
# Bin:  7
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 1.8003
# Bin:  8
# 2/2 [==============================] - 63s 31s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0077 - mean_absolute_percentage_error: 1.8786
# Bin:  9
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0072 - mean_absolute_percentage_error: 1.6386
# Bin:  10
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0093 - mean_absolute_percentage_error: 1.8977
# Bin:  11
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0198 - mean_absolute_percentage_error: 3.7202
# Bin:  12
# 3/3 [==============================] - 64s 21s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 2.3449
# Bin:  13
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0310 - mean_absolute_percentage_error: 4.7481
# Bin:  14
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0219 - mean_absolute_percentage_error: 3.2211
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 5.8965
# Bin:  16
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 6.0880
# Bin:  18
# 4/4 [==============================] - 65s 16s/step - loss: 0.0000e+00 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 12.4076
# Bin:  19
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1247 - mean_absolute_percentage_error: 13.1739
# Bin:  20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2371 - mean_absolute_percentage_error: 24.0477
# Bin:  22
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2177 - mean_absolute_percentage_error: 20.0106
# Num forces:  3
# Bin:  2
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0067 - mean_absolute_percentage_error: 11.9825
# Bin:  3
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0168 - mean_absolute_percentage_error: 16.8363
# Bin:  4
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0227 - mean_absolute_percentage_error: 16.6737
# Bin:  5
# 11/11 [==============================] - 73s 7s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 5.8392
# Bin:  6
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 4.8193
# Bin:  7
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0188 - mean_absolute_percentage_error: 5.9810
# Bin:  8
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0467 - mean_absolute_percentage_error: 23.3652
# Bin:  9
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0261 - mean_absolute_percentage_error: 6.6395
# Bin:  10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0371 - mean_absolute_percentage_error: 7.9914
# Bin:  11
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0389 - mean_absolute_percentage_error: 7.9401
# Bin:  12
# 6/6 [==============================] - 72s 12s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0441 - mean_absolute_percentage_error: 7.6896
# Bin:  13
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0368 - mean_absolute_percentage_error: 5.7478
# Bin:  14
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 5.3345
# Bin:  15
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0694 - mean_absolute_percentage_error: 10.0953
# Bin:  16
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0665 - mean_absolute_percentage_error: 7.9782
# Bin:  18
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 11.7481
# Bin:  19
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1511 - mean_absolute_percentage_error: 14.0763
# Bin:  21
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2470 - mean_absolute_percentage_error: 20.3715
# Bin:  22
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2696 - mean_absolute_percentage_error: 21.7504
# Num forces:  4
# Bin:  1
# 9/9 [==============================] - 83s 9s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0091 - mean_absolute_percentage_error: 36.8824
# Bin:  2
# 17/17 [==============================] - 83s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0120 - mean_absolute_percentage_error: 17.5420
# Bin:  3
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0148 - mean_absolute_percentage_error: 15.8887
# Bin:  4
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0180 - mean_absolute_percentage_error: 15.5197
# Bin:  5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0243 - mean_absolute_percentage_error: 11.5311
# Bin:  6
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0367 - mean_absolute_percentage_error: 12.6152
# Bin:  7
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0378 - mean_absolute_percentage_error: 13.5836
# Bin:  8
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 12.1325
# Bin:  9
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0444 - mean_absolute_percentage_error: 10.3526
# Bin:  10
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 11.4227
# Bin:  11
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0822 - mean_absolute_percentage_error: 19.0305
# Bin:  12
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0681 - mean_absolute_percentage_error: 12.0966
# Bin:  13
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 7.6293
# Bin:  15
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0988 - mean_absolute_percentage_error: 14.5300
# Bin:  16
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1885 - mean_absolute_percentage_error: 24.1424
# Bin:  17
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1185 - mean_absolute_percentage_error: 14.5289
# Bin:  18
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1362 - mean_absolute_percentage_error: 14.3168
# Bin:  20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1329 - mean_absolute_percentage_error: 12.5182
# Bin:  21
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2581 - mean_absolute_percentage_error: 24.5258
# Bin:  25
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.4862 - mean_absolute_percentage_error: 38.6382
# Num forces:  5
# Bin:  1
# 16/16 [==============================] - 86s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0264 - mean_absolute_percentage_error: 103.2927
# Bin:  2
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 34.9224
# Bin:  3
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0205 - mean_absolute_percentage_error: 19.8771
# Bin:  4
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0306 - mean_absolute_percentage_error: 18.0585
# Bin:  5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0234 - mean_absolute_percentage_error: 10.5982
# Bin:  6
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0395 - mean_absolute_percentage_error: 14.5261
# Bin:  7
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 12.3478
# Bin:  8
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0354 - mean_absolute_percentage_error: 9.4693
# Bin:  9
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0712 - mean_absolute_percentage_error: 17.2080
# Bin:  10
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 23.0276
# Bin:  11
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0798 - mean_absolute_percentage_error: 16.4150
# Bin:  12
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0837 - mean_absolute_percentage_error: 15.7380
# Bin:  13
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0919 - mean_absolute_percentage_error: 15.6485
# Bin:  14
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1238 - mean_absolute_percentage_error: 18.8008
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1652 - mean_absolute_percentage_error: 24.3738
# Bin:  16
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1237 - mean_absolute_percentage_error: 17.9726
# Bin:  17
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1215 - mean_absolute_percentage_error: 13.9109
# Num forces:  6
# Bin:  1
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0163 - mean_absolute_percentage_error: 66.6674
# Bin:  2
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 23.6894
# Bin:  3
# 8/8 [==============================] - 89s 11s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0194 - mean_absolute_percentage_error: 14.4262
# Bin:  4
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0217 - mean_absolute_percentage_error: 12.2069
# Bin:  5
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0332 - mean_absolute_percentage_error: 15.1614
# Bin:  6
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 16.8994
# Bin:  7
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0465 - mean_absolute_percentage_error: 15.1828
# Bin:  8
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0521 - mean_absolute_percentage_error: 14.2700
# Bin:  9
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0564 - mean_absolute_percentage_error: 14.1071
# Bin:  10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0515 - mean_absolute_percentage_error: 10.5205
# Bin:  13
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 10.4297
# Bin:  14
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1307 - mean_absolute_percentage_error: 22.5409
# Bin:  15
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1839 - mean_absolute_percentage_error: 32.0064
# Bin:  16
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1306 - mean_absolute_percentage_error: 16.3109
# Bin:  17
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1693 - mean_absolute_percentage_error: 18.9287

# %%
df_error_mae = pd.DataFrame(error_mae, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mae["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mae = pd.melt(df_error_mae, id_vars=["Mean bin magnitude"], value_name="Mean absolute error", var_name="Forces")
sns.set_theme(style="whitegrid")
s = sns.lineplot(data=df_error_mae, x="Mean bin magnitude", y="Mean absolute error", hue="Forces")
s.set(ylim = (0,1))
plt.legend(bbox_to_anchor=(1.02, 0.375), loc='upper left', borderaxespad=0)
plt.savefig('magnitude_error_1000.pdf', dpi=300, bbox_inches='tight')

# %%
df_error_mape = pd.DataFrame(error_mape, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mape["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mape = pd.melt(df_error_mape, id_vars=["Mean bin magnitude"], value_name="Mean absolute percent error", var_name="Forces")
sns.lineplot(data=df_error_mape, x="Mean bin magnitude", y="Mean absolute percent error", hue="Forces")
s.set(ylim = (0,100))
plt.legend(bbox_to_anchor=(1.02, 0.375), loc='upper left', borderaxespad=0)
plt.savefig('magnitude_percent_error_1000.pdf', dpi=300, bbox_inches='tight')

# %%
df_error_mape.to_pickle("magnitude_mape.pkl")
df_error_mae.to_pickle("magnitude_mae.pkl")
