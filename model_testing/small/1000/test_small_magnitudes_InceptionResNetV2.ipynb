# %% [markdown]
# #### Loading libraries

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import to_categorical
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', 'test')
labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', 'test')
models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '400')

# %% [markdown]
# #### Define image processor and data generator

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Load the data

# %%
#--- Load images ---#
# Extract individual image paths
img_paths = {}
for k in range(2, 7):
    path_prefix = os.path.join(image_path, str(k))
    img_paths[k] = [os.path.join(path_prefix, name) for name in sorted(os.listdir(path_prefix), key = sorter)]
# Create data generators
gaussblur = GaussBlur(1)
params = {'dim': (128, 128), 'n_channels': 3, 'rescale': 1 / 255, 
          'preprocessing_func': gaussblur.blur}
# Load images (for all number of forces) as matrix
X = dict()
for k in range(2, 7): 
    test_generator = DataGenerator(img_paths[k], **params)   
    X[k] = test_generator.generate()

# %%
#--- Load magnitude labels ---#
y_lm = dict()
for k in range(2, 7): y_lm[k] = np.load(os.path.join(labels_path, str(k), 'mags.npy'))

# %%
#--- Histogram of mean magnitudes ---#
for k in range(2,7):
    n, bins, patches = plt.hist(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30), facecolor='g', alpha=0.75)
    plt.xlabel('Magnitude')
    plt.ylabel('Count')
    plt.title('Histogram of mean magnitudes for ' + str(k) + ' forces')
    plt.xlim(-0.1, 1.6)
    plt.grid(True)
    plt.show()

# %%
#--- Split magnitudes into bins ---#
bins = {}
bin_edges = np.linspace(0,1.5,30)
for k in range(2, 7): bins[k] = np.digitize(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30))

# %% [markdown]
# #### Load and test models

# %%
#--- Load models ---#
models_m = dict()                         
for k in range(2, 7): 
    models_m[k] = load_model(os.path.join(models_path, 'InceptionResNetV2_mags_'+str(k)+'.h5'))
    models_m[k].compile(metrics = ['mean_absolute_error', "mean_absolute_percentage_error"])

# %%
#--- Test models ---#
error_mae = np.empty([len(bin_edges) - 1, 5]) * np.nan 
error_mape = np.empty([len(bin_edges) - 1, 5]) * np.nan
for k in range(2, 7):
    print("Num forces: ", k)
    for i in range(1, len(bin_edges) - 1):
        if (sum(bins[k] == i) > 0):
            print("Bin: ", i)
            loss = models_m[k].evaluate(X[k][bins[k] == i, ], y_lm[k][bins[k] == i, ])
            error_mae[i - 1, k - 2] = loss[1]
            error_mape[i - 1, k - 2] = loss[2]
# Out:
# Num forces:  2
# Bin:  2
# 4/4 [==============================] - 47s 12s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 7.6463
# Bin:  3
# 8/8 [==============================] - 47s 6s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 4.4716
# Bin:  4
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0090 - mean_absolute_percentage_error: 4.8784
# Bin:  5
# 7/7 [==============================] - 51s 7s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0070 - mean_absolute_percentage_error: 2.9620
# Bin:  6
# 5/5 [==============================] - 51s 10s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0076 - mean_absolute_percentage_error: 2.5874
# Bin:  7
# 8/8 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0085 - mean_absolute_percentage_error: 2.5451
# Bin:  8
# 2/2 [==============================] - 52s 26s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0095 - mean_absolute_percentage_error: 2.3138
# Bin:  9
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0092 - mean_absolute_percentage_error: 2.0872
# Bin:  10
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 2.4955
# Bin:  11
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0187 - mean_absolute_percentage_error: 3.5237
# Bin:  12
# 3/3 [==============================] - 49s 16s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 2.5859
# Bin:  13
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0253 - mean_absolute_percentage_error: 3.8760
# Bin:  14
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0183 - mean_absolute_percentage_error: 2.6954
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0401 - mean_absolute_percentage_error: 5.4231
# Bin:  16
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0219 - mean_absolute_percentage_error: 2.7112
# Bin:  18
# 4/4 [==============================] - 49s 12s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0651 - mean_absolute_percentage_error: 7.2913
# Bin:  19
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0870 - mean_absolute_percentage_error: 9.1898
# Bin:  20
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1996 - mean_absolute_percentage_error: 20.2438
# Bin:  22
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1779 - mean_absolute_percentage_error: 16.3579
# Num forces:  3
# Bin:  2
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0074 - mean_absolute_percentage_error: 13.9633
# Bin:  3
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0177 - mean_absolute_percentage_error: 17.6233
# Bin:  4
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0287 - mean_absolute_percentage_error: 22.3775
# Bin:  5
# 11/11 [==============================] - 56s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0171 - mean_absolute_percentage_error: 7.8941
# Bin:  6
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0160 - mean_absolute_percentage_error: 5.9882
# Bin:  7
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0234 - mean_absolute_percentage_error: 7.6243
# Bin:  8
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0589 - mean_absolute_percentage_error: 31.9468
# Bin:  9
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0342 - mean_absolute_percentage_error: 8.8386
# Bin:  10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 7.8556
# Bin:  11
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0423 - mean_absolute_percentage_error: 8.3581
# Bin:  12
# 6/6 [==============================] - 57s 10s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0448 - mean_absolute_percentage_error: 7.6945
# Bin:  13
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0478 - mean_absolute_percentage_error: 7.4690
# Bin:  14
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 6.4544
# Bin:  15
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0743 - mean_absolute_percentage_error: 10.2228
# Bin:  16
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0740 - mean_absolute_percentage_error: 8.9632
# Bin:  18
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 11.2120
# Bin:  19
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 10.7234
# Bin:  21
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1531 - mean_absolute_percentage_error: 12.9013
# Bin:  22
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1774 - mean_absolute_percentage_error: 14.1911
# Num forces:  4
# Bin:  1
# 9/9 [==============================] - 58s 6s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0061 - mean_absolute_percentage_error: 23.2821
# Bin:  2
# 17/17 [==============================] - 55s 3s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0304 - mean_absolute_percentage_error: 42.5178
# Bin:  3
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0228 - mean_absolute_percentage_error: 24.9151
# Bin:  4
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0264 - mean_absolute_percentage_error: 23.3610
# Bin:  5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0253 - mean_absolute_percentage_error: 12.1631
# Bin:  6
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0316 - mean_absolute_percentage_error: 11.5193
# Bin:  7
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0341 - mean_absolute_percentage_error: 12.2129
# Bin:  8
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0458 - mean_absolute_percentage_error: 12.1091
# Bin:  9
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 11.3434
# Bin:  10
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0646 - mean_absolute_percentage_error: 12.9763
# Bin:  11
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0824 - mean_absolute_percentage_error: 18.6273
# Bin:  12
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0739 - mean_absolute_percentage_error: 12.9667
# Bin:  13
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 6.8515
# Bin:  15
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1321 - mean_absolute_percentage_error: 17.7727
# Bin:  16
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2331 - mean_absolute_percentage_error: 29.5478
# Bin:  17
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1674 - mean_absolute_percentage_error: 18.6818
# Bin:  18
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1893 - mean_absolute_percentage_error: 19.2716
# Bin:  20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2942 - mean_absolute_percentage_error: 26.6045
# Bin:  21
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.3660 - mean_absolute_percentage_error: 32.0815
# Bin:  25
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.6415 - mean_absolute_percentage_error: 51.2165
# Num forces:  5
# Bin:  1
# 16/16 [==============================] - 63s 4s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0067 - mean_absolute_percentage_error: 27.9756
# Bin:  2
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 14.4469
# Bin:  3
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0140 - mean_absolute_percentage_error: 12.3949
# Bin:  4
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0301 - mean_absolute_percentage_error: 19.4782
# Bin:  5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0268 - mean_absolute_percentage_error: 12.4641
# Bin:  6
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0404 - mean_absolute_percentage_error: 15.5583
# Bin:  7
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0486 - mean_absolute_percentage_error: 13.4074
# Bin:  8
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0480 - mean_absolute_percentage_error: 12.5921
# Bin:  9
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 18.1645
# Bin:  10
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 22.4020
# Bin:  11
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0824 - mean_absolute_percentage_error: 17.2349
# Bin:  12
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0857 - mean_absolute_percentage_error: 15.9072
# Bin:  13
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 19.0246
# Bin:  14
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1210 - mean_absolute_percentage_error: 18.8714
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1643 - mean_absolute_percentage_error: 23.8396
# Bin:  16
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1511 - mean_absolute_percentage_error: 22.7833
# Bin:  17
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1515 - mean_absolute_percentage_error: 17.7100
# Num forces:  6
# Bin:  1
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0178 - mean_absolute_percentage_error: 68.8863
# Bin:  2
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 24.9536
# Bin:  3
# 8/8 [==============================] - 62s 8s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0241 - mean_absolute_percentage_error: 19.3885
# Bin:  4
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0269 - mean_absolute_percentage_error: 16.2806
# Bin:  5
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0342 - mean_absolute_percentage_error: 16.8182
# Bin:  6
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0420 - mean_absolute_percentage_error: 17.7789
# Bin:  7
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0485 - mean_absolute_percentage_error: 16.2827
# Bin:  8
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0695 - mean_absolute_percentage_error: 20.0634
# Bin:  9
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0697 - mean_absolute_percentage_error: 17.9348
# Bin:  10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 14.2749
# Bin:  13
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 10.1802
# Bin:  14
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1259 - mean_absolute_percentage_error: 23.6199
# Bin:  15
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1707 - mean_absolute_percentage_error: 30.1334
# Bin:  16
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1300 - mean_absolute_percentage_error: 16.2751
# Bin:  17
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1667 - mean_absolute_percentage_error: 18.2828

# %%
df_error_mae = pd.DataFrame(error_mae, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mae["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mae = pd.melt(df_error_mae, id_vars=["Mean bin magnitude"], value_name="Mean absolute error", var_name="Forces")
sns.set_theme(style="whitegrid")
sns.lineplot(data=df_error_mae, x="Mean bin magnitude", y="Mean absolute error", hue="Forces")
# Out:
# <AxesSubplot:xlabel='Mean bin magnitude', ylabel='Mean absolute error'>

# %%
df_error_mape = pd.DataFrame(error_mape, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mape["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mape = pd.melt(df_error_mape, id_vars=["Mean bin magnitude"], value_name="Mean absolute percent error", var_name="Forces")
sns.lineplot(data=df_error_mape, x="Mean bin magnitude", y="Mean absolute percent error", hue="Forces")
# Out:
# <AxesSubplot:xlabel='Mean bin magnitude', ylabel='Mean absolute percent error'>
