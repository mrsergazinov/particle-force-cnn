# %% [markdown]
# #### Loading libraries

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import to_categorical
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pylab as plt
import gc

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pylab as plt
import gc
import pickle5 as pickle

# %% [markdown]
# #### Define paths

# %%
image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'small', 'test')
labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'small', 'test')
models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models', 'small', '4000')

# %% [markdown]
# #### Define image processor and data generator

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Load the data

# %%
#--- Load images ---#
# Extract individual image paths
img_paths = {}
for k in range(2, 7):
    path_prefix = os.path.join(image_path, str(k))
    img_paths[k] = [os.path.join(path_prefix, name) for name in sorted(os.listdir(path_prefix), key = sorter)]
# Create data generators
gaussblur = GaussBlur(1)
params = {'dim': (128, 128), 'n_channels': 3, 'rescale': 1 / 255, 
          'preprocessing_func': gaussblur.blur}
# Load images (for all number of forces) as matrix
X = dict()
for k in range(2, 7): 
    test_generator = DataGenerator(img_paths[k], **params)   
    X[k] = test_generator.generate()

# %%
#--- Load magnitude labels ---#
y_lm = dict()
for k in range(2, 7): y_lm[k] = np.load(os.path.join(labels_path, str(k), 'mags.npy'))

# %%
#--- Histogram of mean magnitudes ---#
for k in range(2,7):
    n, bins, patches = plt.hist(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30), facecolor='g', alpha=0.75)
    plt.xlabel('Magnitude')
    plt.ylabel('Count')
    plt.title('Histogram of mean magnitudes for ' + str(k) + ' forces')
    plt.xlim(-0.1, 1.6)
    plt.grid(True)
    plt.show()

# %%
#--- Split magnitudes into bins ---#
bins = {}
bin_edges = np.linspace(0,1.5,30)
for k in range(2, 7): bins[k] = np.digitize(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30))

# %% [markdown]
# #### Load and test models

# %%
#--- Load models ---#
models_m = dict()                         
for k in range(2, 7): 
    models_m[k] = load_model(os.path.join(models_path, 'InceptionResNetV2_mags_'+str(k)+'.h5'))
    models_m[k].compile(metrics = ['mean_absolute_error', "mean_absolute_percentage_error"])

# %%
#--- Test models ---#
error_mae = np.empty([len(bin_edges) - 1, 5]) * np.nan 
error_mape = np.empty([len(bin_edges) - 1, 5]) * np.nan
for k in range(2, 7):
    print("Num forces: ", k)
    for i in range(1, len(bin_edges) - 1):
        if (sum(bins[k] == i) > 0):
            print("Bin: ", i)
            loss = models_m[k].evaluate(X[k][bins[k] == i, ], y_lm[k][bins[k] == i, ])
            error_mae[i - 1, k - 2] = loss[1]
            error_mape[i - 1, k - 2] = loss[2]
# Out:
# Num forces:  2
# Bin:  2
# 4/4 [==============================] - 65s 16s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.7034
# Bin:  3
# 8/8 [==============================] - 64s 8s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 1.9820
# Bin:  4
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.1161
# Bin:  5
# 7/7 [==============================] - 63s 9s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 1.3850
# Bin:  6
# 5/5 [==============================] - 65s 13s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 1.4752
# Bin:  7
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 1.3076
# Bin:  8
# 2/2 [==============================] - 70s 35s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 1.2189
# Bin:  9
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 1.2805
# Bin:  10
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 1.1844
# Bin:  11
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0078 - mean_absolute_percentage_error: 1.4670
# Bin:  12
# 3/3 [==============================] - 71s 24s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0070 - mean_absolute_percentage_error: 1.2062
# Bin:  13
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 2.0964
# Bin:  14
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0108 - mean_absolute_percentage_error: 1.5836
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0211 - mean_absolute_percentage_error: 2.8549
# Bin:  16
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 1.6321
# Bin:  18
# 4/4 [==============================] - 71s 18s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0167 - mean_absolute_percentage_error: 1.8652
# Bin:  19
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0230 - mean_absolute_percentage_error: 2.4274
# Bin:  20
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0325 - mean_absolute_percentage_error: 3.3004
# Bin:  22
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 3.3580
# Num forces:  3
# Bin:  2
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0071 - mean_absolute_percentage_error: 13.3681
# Bin:  3
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0095 - mean_absolute_percentage_error: 9.2652
# Bin:  4
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0130 - mean_absolute_percentage_error: 8.9265
# Bin:  5
# 11/11 [==============================] - 74s 7s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0101 - mean_absolute_percentage_error: 4.5089
# Bin:  6
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 4.4192
# Bin:  7
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0171 - mean_absolute_percentage_error: 5.5627
# Bin:  8
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0406 - mean_absolute_percentage_error: 18.8969
# Bin:  9
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0221 - mean_absolute_percentage_error: 5.5070
# Bin:  10
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0259 - mean_absolute_percentage_error: 5.6997
# Bin:  11
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0291 - mean_absolute_percentage_error: 5.7469
# Bin:  12
# 6/6 [==============================] - 80s 13s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0310 - mean_absolute_percentage_error: 5.3668
# Bin:  13
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0307 - mean_absolute_percentage_error: 4.7918
# Bin:  14
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0284 - mean_absolute_percentage_error: 4.0026
# Bin:  15
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 6.4606
# Bin:  16
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 5.5471
# Bin:  18
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 6.4446
# Bin:  19
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0665 - mean_absolute_percentage_error: 6.6615
# Bin:  21
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1689 - mean_absolute_percentage_error: 15.3856
# Bin:  22
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1405 - mean_absolute_percentage_error: 11.8373
# Num forces:  4
# Bin:  1
# 9/9 [==============================] - 79s 9s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 18.2408
# Bin:  2
# 17/17 [==============================] - 82s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 11.7860
# Bin:  3
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 13.0311
# Bin:  4
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0228 - mean_absolute_percentage_error: 17.6984
# Bin:  5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0209 - mean_absolute_percentage_error: 9.6881
# Bin:  6
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0279 - mean_absolute_percentage_error: 9.7720
# Bin:  7
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0284 - mean_absolute_percentage_error: 9.7462
# Bin:  8
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0377 - mean_absolute_percentage_error: 9.9645
# Bin:  9
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0341 - mean_absolute_percentage_error: 8.4045
# Bin:  10
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 8.9656
# Bin:  11
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0638 - mean_absolute_percentage_error: 14.1773
# Bin:  12
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 7.8250
# Bin:  13
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 6.8549
# Bin:  15
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0744 - mean_absolute_percentage_error: 10.7097
# Bin:  16
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1717 - mean_absolute_percentage_error: 24.8926
# Bin:  17
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0934 - mean_absolute_percentage_error: 11.5941
# Bin:  18
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 13.5032
# Bin:  20
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1282 - mean_absolute_percentage_error: 12.0908
# Bin:  21
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1646 - mean_absolute_percentage_error: 16.4527
# Bin:  25
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2148 - mean_absolute_percentage_error: 16.8017
# Num forces:  5
# Bin:  1
# 16/16 [==============================] - 85s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 30.8677
# Bin:  2
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0104 - mean_absolute_percentage_error: 11.9481
# Bin:  3
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0117 - mean_absolute_percentage_error: 10.3858
# Bin:  4
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0280 - mean_absolute_percentage_error: 17.5448
# Bin:  5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0238 - mean_absolute_percentage_error: 10.8417
# Bin:  6
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0338 - mean_absolute_percentage_error: 12.3408
# Bin:  7
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0453 - mean_absolute_percentage_error: 13.7795
# Bin:  8
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0318 - mean_absolute_percentage_error: 8.4963
# Bin:  9
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0601 - mean_absolute_percentage_error: 14.4689
# Bin:  10
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0811 - mean_absolute_percentage_error: 17.9074
# Bin:  11
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0675 - mean_absolute_percentage_error: 13.3847
# Bin:  12
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0698 - mean_absolute_percentage_error: 13.0166
# Bin:  13
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0771 - mean_absolute_percentage_error: 12.8355
# Bin:  14
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 16.7297
# Bin:  15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1224 - mean_absolute_percentage_error: 17.1617
# Bin:  16
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1327 - mean_absolute_percentage_error: 19.9348
# Bin:  17
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0907 - mean_absolute_percentage_error: 10.7836
# Num forces:  6
# Bin:  1
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0061 - mean_absolute_percentage_error: 25.4822
# Bin:  2
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0099 - mean_absolute_percentage_error: 18.2457
# Bin:  3
# 8/8 [==============================] - 92s 11s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0189 - mean_absolute_percentage_error: 14.3116
# Bin:  4
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0194 - mean_absolute_percentage_error: 10.9752
# Bin:  5
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0308 - mean_absolute_percentage_error: 13.9809
# Bin:  6
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0394 - mean_absolute_percentage_error: 15.5047
# Bin:  7
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 14.6084
# Bin:  8
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0592 - mean_absolute_percentage_error: 16.0720
# Bin:  9
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0500 - mean_absolute_percentage_error: 12.4591
# Bin:  10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 9.0390
# Bin:  13
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0671 - mean_absolute_percentage_error: 10.4175
# Bin:  14
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 19.4514
# Bin:  15
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1534 - mean_absolute_percentage_error: 28.1825
# Bin:  16
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1460 - mean_absolute_percentage_error: 18.2865
# Bin:  17
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1471 - mean_absolute_percentage_error: 16.6247

# %%
df_error_mae = pd.DataFrame(error_mae, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mae["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mae = pd.melt(df_error_mae, id_vars=["Mean bin magnitude"], value_name="Mean absolute error", var_name="Forces")
sns.set_theme(style="whitegrid")
s = sns.lineplot(data=df_error_mae, x="Mean bin magnitude", y="Mean absolute error", hue="Forces")
s.set(ylim = (0,1))
plt.legend(bbox_to_anchor=(1.02, 0.375), loc='upper left', borderaxespad=0)
plt.savefig('magnitude_error_4000.pdf', dpi=300, bbox_inches='tight')

# %%
with open("magnitude_mape.pkl", "rb") as fh:
  df_error_mape = pickle.load(fh)

# %%
df_error_mape
# Out:
#      Mean bin magnitude    Forces  Mean absolute percent error
# 0              0.025862  2 forces                          NaN
# 1              0.077586  2 forces                     2.703357
# 2              0.129310  2 forces                     1.982005
# 3              0.181034  2 forces                     1.116139
# 4              0.232759  2 forces                     1.385028
# ..                  ...       ...                          ...
# 140            1.267241  6 forces                          NaN
# 141            1.318966  6 forces                          NaN
# 142            1.370690  6 forces                          NaN
# 143            1.422414  6 forces                          NaN
# 144            1.474138  6 forces                          NaN
#
# [145 rows x 3 columns]

# %%
# df_error_mape = pd.DataFrame(error_mape, columns = [str(i) + " forces" for i in range(2, 7)])
# df_error_mape["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
# df_error_mape = pd.melt(df_error_mape, id_vars=["Mean bin magnitude"], value_name="Mean absolute percent error", var_name="Forces")
sns.set_theme(style="whitegrid")
s = sns.lineplot(data=df_error_mape, x="Mean bin magnitude", y="Mean absolute percent error", hue="Forces")
s.set(ylim = (0,100))
plt.legend(bbox_to_anchor=(1.02, 0.375), loc='upper left', borderaxespad=0)
plt.savefig('magnitude_percent_error_4000.pdf', dpi=300, bbox_inches='tight')

# %%
df_error_mape.to_pickle("magnitude_mape.pkl")
df_error_mae.to_pickle("magnitude_mae.pkl")
