# %% [markdown]
# #### Loading libraries

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import to_categorical
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Define paths

# %%
image_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'image_data', 'test')
labels_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'labels', 'test')
models_path = os.path.join('/home', 'renat_sergazinov', 
                          'python-git-workspace', 'PhotoForceReconML', 'models')

# %% [markdown]
# #### Define image processor and data generator

# %%
# %run '/home/renat_sergazinov/python-git-workspace/PhotoForceReconML/data_loader.py'

# %% [markdown]
# #### Load the data

# %%
#--- Load images ---#
# Extract individual image paths
img_paths = {}
for k in range(2, 7):
    path_prefix = os.path.join(image_path, str(k))
    img_paths[k] = [os.path.join(path_prefix, name) for name in sorted(os.listdir(path_prefix), key = sorter)]
# Create data generators
gaussblur = GaussBlur(1)
params = {'dim': (128, 128), 'n_channels': 3, 'rescale': 1 / 255, 
          'preprocessing_func': gaussblur.blur}
# Load images (for all number of forces) as matrix
X = dict()
for k in range(2, 7): 
    test_generator = DataGenerator(img_paths[k], **params)   
    X[k] = test_generator.generate()

# %%
#--- Load magnitude labels ---#
y_lm = dict()
for k in range(2, 7): y_lm[k] = np.load(os.path.join(labels_path, str(k), 'mags.npy'))

# %%
#--- Histogram of mean magnitudes ---#
for k in range(2,7):
    n, bins, patches = plt.hist(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30), facecolor='g', alpha=0.75)
    plt.xlabel('Magnitude')
    plt.ylabel('Count')
    plt.title('Histogram of mean magnitudes for ' + str(k) + ' forces')
    plt.xlim(-0.1, 1.6)
    plt.grid(True)
    plt.show()

# %%
#--- Split magnitudes into bins ---#
bins = {}
bin_edges = np.linspace(0,1.5,30)
for k in range(2, 7): bins[k] = np.digitize(np.mean(y_lm[k], 1), bins = np.linspace(0,1.5,30))

# %% [markdown]
# #### Load and test models

# %%
#--- Load models ---#
models_m = dict()                         
for k in range(2, 7): 
    models_m[k] = load_model(os.path.join(models_path, 'InceptionResNetV2_mags_'+str(k)+'.h5'))
    models_m[k].compile(metrics = ['mean_absolute_error', "mean_absolute_percentage_error"])

# %%
#--- Test models ---#
error_mae = np.empty([len(bin_edges) - 1, 5]) * np.nan 
error_mape = np.empty([len(bin_edges) - 1, 5]) * np.nan
for k in range(2, 7):
    print("Num forces: ", k)
    for i in range(1, len(bin_edges) - 1):
        if (sum(bins[k] == i) > 0):
            print("Bin: ", i)
            loss = models_m[k].evaluate(X[k][bins[k] == i, ], y_lm[k][bins[k] == i, ])
            error_mae[i - 1, k - 2] = loss[1]
            error_mape[i - 1, k - 2] = loss[2]
# Out:
# Num forces:  2
# Bin:  1
# 14/14 [==============================] - 73s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 13.4644
# Bin:  2
# 15/15 [==============================] - 71s 5s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.7553
# Bin:  3
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.5006
# Bin:  4
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 0.9826
# Bin:  5
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.0253
# Bin:  6
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 1.1063
# Bin:  7
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 1.0009
# Bin:  8
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 0.9641
# Bin:  9
# 12/12 [==============================] - 80s 7s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.9439
# Bin:  10
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 0.9152
# Bin:  11
# 4/4 [==============================] - 78s 20s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 0.9628
# Bin:  12
# 2/2 [==============================] - 79s 39s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 0.8263
# Bin:  13
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0070 - mean_absolute_percentage_error: 1.0552
# Bin:  14
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0083 - mean_absolute_percentage_error: 1.1603
# Bin:  15
# 3/3 [==============================] - 79s 26s/step - loss: 0.0000e+00 - mean_absolute_error: 0.0104 - mean_absolute_percentage_error: 1.3827
# Bin:  16
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0101 - mean_absolute_percentage_error: 1.2644
# Bin:  17
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0091 - mean_absolute_percentage_error: 1.0551
# Bin:  18
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 1.2462
# Bin:  19
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 1.2904
# Bin:  20
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 1.2595
# Num forces:  3
# Bin:  1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 9.2267
# Bin:  2
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 11.2710
# Bin:  3
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0089 - mean_absolute_percentage_error: 7.9326
# Bin:  4
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0110 - mean_absolute_percentage_error: 6.6259
# Bin:  5
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0105 - mean_absolute_percentage_error: 4.9010
# Bin:  6
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0156 - mean_absolute_percentage_error: 5.8625
# Bin:  7
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0187 - mean_absolute_percentage_error: 5.7508
# Bin:  8
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0199 - mean_absolute_percentage_error: 5.3137
# Bin:  9
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0288 - mean_absolute_percentage_error: 7.5153
# Bin:  10
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0310 - mean_absolute_percentage_error: 8.0937
# Bin:  11
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0204 - mean_absolute_percentage_error: 3.8470
# Bin:  12
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0290 - mean_absolute_percentage_error: 5.0630
# Bin:  13
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0317 - mean_absolute_percentage_error: 4.9201
# Bin:  14
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 8.4096
# Bin:  15
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0367 - mean_absolute_percentage_error: 5.0741
# Bin:  16
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0406 - mean_absolute_percentage_error: 4.9838
# Bin:  17
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0354 - mean_absolute_percentage_error: 4.3842
# Bin:  22
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0481 - mean_absolute_percentage_error: 4.3090
# Num forces:  4
# Bin:  1
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 21.9898
# Bin:  2
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0074 - mean_absolute_percentage_error: 12.0773
# Bin:  3
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0143 - mean_absolute_percentage_error: 14.4181
# Bin:  4
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0145 - mean_absolute_percentage_error: 8.5159
# Bin:  5
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0205 - mean_absolute_percentage_error: 9.3795
# Bin:  6
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0277 - mean_absolute_percentage_error: 10.3846
# Bin:  7
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0272 - mean_absolute_percentage_error: 8.6701
# Bin:  8
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0336 - mean_absolute_percentage_error: 9.3852
# Bin:  9
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 12.3570
# Bin:  10
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0382 - mean_absolute_percentage_error: 7.8824
# Bin:  11
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0742 - mean_absolute_percentage_error: 16.2692
# Bin:  12
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0649 - mean_absolute_percentage_error: 11.9575
# Bin:  13
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 12.1367
# Bin:  14
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0614 - mean_absolute_percentage_error: 9.1519
# Bin:  15
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0650 - mean_absolute_percentage_error: 8.5751
# Bin:  16
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0782 - mean_absolute_percentage_error: 9.9282
# Bin:  17
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0890 - mean_absolute_percentage_error: 11.5632
# Bin:  18
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0870 - mean_absolute_percentage_error: 10.1592
# Bin:  19
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1022 - mean_absolute_percentage_error: 11.3088
# Bin:  20
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1428 - mean_absolute_percentage_error: 15.9238
# Bin:  21
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1630 - mean_absolute_percentage_error: 15.0929
# Bin:  22
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1203 - mean_absolute_percentage_error: 10.8471
# Bin:  28
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1948 - mean_absolute_percentage_error: 12.2625
# Num forces:  5
# Bin:  1
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 23.3548
# Bin:  2
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 15.9031
# Bin:  3
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0169 - mean_absolute_percentage_error: 15.2813
# Bin:  4
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0218 - mean_absolute_percentage_error: 13.6392
# Bin:  5
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0279 - mean_absolute_percentage_error: 14.0946
# Bin:  6
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0286 - mean_absolute_percentage_error: 10.9227
# Bin:  7
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0300 - mean_absolute_percentage_error: 8.9275
# Bin:  8
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 11.7081
# Bin:  9
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 13.2074
# Bin:  10
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0536 - mean_absolute_percentage_error: 11.3026
# Bin:  11
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0653 - mean_absolute_percentage_error: 11.8763
# Bin:  12
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0714 - mean_absolute_percentage_error: 12.5988
# Bin:  13
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0692 - mean_absolute_percentage_error: 11.2865
# Bin:  14
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0936 - mean_absolute_percentage_error: 13.7190
# Bin:  15
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0863 - mean_absolute_percentage_error: 12.3736
# Bin:  16
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 13.6360
# Bin:  17
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 12.4258
# Bin:  18
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1377 - mean_absolute_percentage_error: 16.3947
# Num forces:  6
# Bin:  1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0090 - mean_absolute_percentage_error: 19.0444
# Bin:  2
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0136 - mean_absolute_percentage_error: 16.6816
# Bin:  3
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0203 - mean_absolute_percentage_error: 17.6461
# Bin:  4
# 17/17 [==============================] - 1s 40ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0238 - mean_absolute_percentage_error: 13.9289
# Bin:  5
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0344 - mean_absolute_percentage_error: 17.1130
# Bin:  6
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0297 - mean_absolute_percentage_error: 10.8724
# Bin:  7
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0360 - mean_absolute_percentage_error: 10.6780
# Bin:  8
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0390 - mean_absolute_percentage_error: 9.4943
# Bin:  9
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0467 - mean_absolute_percentage_error: 11.4402
# Bin:  10
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0608 - mean_absolute_percentage_error: 14.1949
# Bin:  11
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0597 - mean_absolute_percentage_error: 11.2926
# Bin:  12
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0856 - mean_absolute_percentage_error: 15.1885
# Bin:  13
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.0838 - mean_absolute_percentage_error: 14.0218
# Bin:  14
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1606 - mean_absolute_percentage_error: 27.4338
# Bin:  15
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 15.3090
# Bin:  16
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1021 - mean_absolute_percentage_error: 13.1627
# Bin:  17
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1303 - mean_absolute_percentage_error: 16.3278
# Bin:  18
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1257 - mean_absolute_percentage_error: 13.3679
# Bin:  19
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.1576 - mean_absolute_percentage_error: 16.0203
# Bin:  20
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - mean_absolute_error: 0.2066 - mean_absolute_percentage_error: 19.0578

# %%
df_error_mae = pd.DataFrame(error_mae, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mae["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mae = pd.melt(df_error_mae, id_vars=["Mean bin magnitude"], value_name="Mean absolute error", var_name="Forces")

# %%
sns.set_theme(style="whitegrid")
sns.lineplot(data=df_error_mae, x="Mean bin magnitude", y="Mean absolute error", hue="Forces")
# Out:
# <AxesSubplot:xlabel='Mean bin magnitude', ylabel='Mean absolute error'>

# %%
df_error_mape = pd.DataFrame(error_mape, columns = [str(i) + " forces" for i in range(2, 7)])
df_error_mape["Mean bin magnitude"] = (bin_edges[1:] - bin_edges[:-1]) / 2 + bin_edges[:-1]
df_error_mape = pd.melt(df_error_mape, id_vars=["Mean bin magnitude"], value_name="Mean absolute percent error", var_name="Forces")

# %%
sns.lineplot(data=df_error_mape, x="Mean bin magnitude", y="Mean absolute percent error", hue="Forces")
# Out:
# <AxesSubplot:xlabel='Mean bin magnitude', ylabel='Mean absolute percent error'>
