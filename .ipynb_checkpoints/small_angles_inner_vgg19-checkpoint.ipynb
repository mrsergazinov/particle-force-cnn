# %% [markdown]
# #### Loading the necessary libraries and packages

# %%
# Load tensorflow
import tensorflow as tf
# Below command is to avoid the known bug which prevents computation on some GPU devices
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Load preprocessing tools
from tensorflow.keras.utils import Sequence
from scipy.ndimage.filters import gaussian_filter
from PIL import Image
# Load model building blocks
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
# Load pre-trained model library
from tensorflow.keras import applications
# Load miscelaneous libraries
import numpy as np
import os
import matplotlib.pylab as plt
import gc

# %% [markdown]
# #### Sort labels according to the increasing angle

# %%
# Define algorithm for reordering the data based on the index array
def reorder(ind, arr):
    new_arr = np.zeros(arr.shape)
    for i in range(len(arr)):
        new_arr[i] = arr[ind[i]]
    return new_arr  

def order_labels(angles_inner, mags, angles_tang):
    # Initialise variables
    y_m = dict()
    y_ai = dict()
    y_at = dict()
    # Load the labels (contact angles, magnitudes, tangential angles)
    for i in range(5):
        y_m[i] = np.load(mags[i])
        y_ai[i] = np.load(angles_inner[i])
        y_at[i] = np.load(angles_tang[i])

    y_m_reord = dict()
    y_ai_reord = dict()
    y_at_reord = dict()
    # Perform reording
    for i in range(5):
        y_ai_reord[i] = np.sort(y_ai[i], axis = -1) 
        ind_matrix = np.argsort(y_ai[i], axis = -1)
        y_m_reord[i] = np.array([reorder(ind_matrix[j,:], y_m[i][j,:]) for j in range(y_m[i].shape[0])])
        y_at_reord[i] = np.array([reorder(ind_matrix[j,:], y_at[i][j,:]) for j in range(y_at[i].shape[0])])

    # Save data
    for i in range(5):
        np.save(angles_inner[i], y_ai_reord[i])
        np.save(angles_tang[i], y_at_reord[i])
        np.save(mags[i], y_m_reord[i])

# %%
# Reorder labels train
angles_inner = []
mags = []
angles_tang = []
for k in range(5):
    i = k + 2
    path = os.path.join(os.getcwd(), 'labels', 'small', '400', 'train', str(i))
    angles_inner.append(os.path.join(path, 'angles_inner.npy'))
    mags.append(os.path.join(path, 'mags.npy'))
    angles_tang.append(os.path.join(path, 'angles_tang.npy'))

order_labels(angles_inner, mags, angles_tang)

# %%
# Reorder labels val
angles_inner = []
mags = []
angles_tang = []
for k in range(5):
    i = k + 2
    path = os.path.join(os.getcwd(), 'labels', 'small', '400', 'val', str(i))
    angles_inner.append(os.path.join(path, 'angles_inner.npy'))
    mags.append(os.path.join(path, 'mags.npy'))
    angles_tang.append(os.path.join(path, 'angles_tang.npy'))

order_labels(angles_inner, mags, angles_tang)

# %% [markdown]
# #### Data preprocessing and augmentation

# %% [markdown]
# Load the data from the directory. The data are the images of particles split into subdirectories based on the number of forces acting on the particle. The labels should be loaded from a separate directory. Each label corresponds to two particles.
#
# The size of all images is adjusted so that all images are 128*128 using nearest neighbor interpolation. Validation split is performed: 20% is set aside for validation. Additionally images are blurred using Gaussian blur with kernel radius = 1.The pixel values are scaled using 1/255 to be in the interval [0,1].

# %%
# Define sorter of image names in order by image number (default is alphanumric)
def sorter(item):
    # Since highest marks first, least error = most marks
    radius = float(item[1 : item.find('_')])
    num_img = int(item[item.find('g') + 1 : item.find('j') - 1])
    return (radius, num_img)

# %%
# Load the train and validation sets

X_train, X_val = {}, {}
y_train, y_val = {}, {}

for k in range(5):
    i = k + 2
    X_path_train = os.path.join(os.getcwd(), 'image_data', 'small', '400', 'train', str(i))
    X_path_val = os.path.join(os.getcwd(), 'image_data', 'small', '400', 'val', str(i))
    X_train[i] = [os.path.join(X_path_train, name) for name in sorted(os.listdir(X_path_train), key = sorter)]
    X_val[i] = [os.path.join(X_path_val, name) for name in sorted(os.listdir(X_path_val), key = sorter)]
    y_train[i] = np.load(os.path.join(os.getcwd(), 'labels', 'small', '400', 'train', str(i), 'angles_inner.npy'))
    y_val[i] = np.load(os.path.join(os.getcwd(), 'labels', 'small', '400', 'val', str(i), 'angles_inner.npy'))

# %%
# Define class for data generation
class DataGenerator(Sequence):
    'Generates data for Keras'
    def __init__(self, list_image_paths = None, labels = None,  
                 batch_size = 32, dim = None, n_channels = 3, rescale = 1, 
                 shuffle=True, save_dir = None, preprocessing_func = None):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_image_paths = list_image_paths
        self.n_channels = n_channels
        self.rescale = rescale
        self.shuffle = shuffle
        self.save_dir = save_dir
        self.preprocessing_func = preprocessing_func
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_image_paths) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indices = self.indices[index * self.batch_size : (index + 1) * self.batch_size]

        # Generate data
        X, y = self.__data_generation(indices)
        
        if self.save_dir is not None:
            for i in range(X.shape[0]):
                path = os.path.join(self.save_dir, 'img' + str(i) + '.jpg')
                plt.imsave(path, np.asarray(X[i, ]), vmin = 0, vmax = 1)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indices = np.arange(len(self.list_image_paths))
        if self.shuffle == True:
            np.random.shuffle(self.indices)

    def __data_generation(self, indices):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        
        # Initialisation
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        list_image_paths_batch = [self.list_image_paths[k] for k in indices]
        
        # Get labels
        y = np.array([self.labels[k, :] for k in indices])
        
        # Generate data
        for i, image_path in enumerate(list_image_paths_batch):
            # Load image and transform
            image = Image.open(os.path.join(image_path))
            if self.dim is not None:
                image = image.resize(self.dim, resample = Image.NEAREST)
            image = np.array(image)[:, :, :self.n_channels]
            image = image * self.rescale
            if self.preprocessing_func is not None:
                image = self.preprocessing_func(image)
            # Store sample
            X[i,] = image

        return X, y

# %%
# Define gaussian blur class
class GaussBlur:
    def __init__(self, radius):
        self.radius = radius
    def blur(self, image):
        return gaussian_filter(image, sigma = self.radius)

# %%
# Apply data generators
gaussblur = GaussBlur(1)
params = {'batch_size': 32, 
          'dim': (128, 128), 
          'n_channels': 3, 
          'rescale': 1 / 255, 
          'shuffle': True, 
          'save_dir': None,
          'preprocessing_func': gaussblur.blur
          }

training_generator = {}
validation_generator = {}

for k in range(5):
    i = k + 2
    training_generator[i] = DataGenerator(X_train[i], y_train[i], **params)
    validation_generator[i] = DataGenerator(X_val[i], y_val[i], **params)

# %% [markdown]
# #### VGG19 Models Training

# %% [markdown]
# Convolutional neural networks is defined and compiled in this step.

# %%
models_path = os.path.join(os.getcwd(), 'models')
models_ai = dict()                         
for k in range(5):
     i = k + 2
     models_ai[i] = load_model(os.path.join(models_path, 'vgg19_angles_inner_'+str(i)+'.h5'))

# %%
for k in range(5):
    i = k + 2
    models_ai[i].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              8389632
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 28,416,066
# Trainable params: 28,416,066
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 28,417,091
# Trainable params: 28,417,091
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 28,418,116
# Trainable params: 28,418,116
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 28,419,141
# Trainable params: 28,419,141
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# vgg19 (Model)                (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 28,420,166
# Trainable params: 28,420,166
# Non-trainable params: 0
# _________________________________________________________________

# %%
for k in range(5):
    i = 2 + k
    models_ai[i].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5, epsilon=1e-7),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = dict()
for k in range(5):
    i = k + 2
    save_dir = os.path.join(os.getcwd(), 'models', 'small', '400')
    model_name = 'vgg19_angles_inner_'+str(i)+'.h5'
    model_path = os.path.join(save_dir, model_name)
    mc[i] = ModelCheckpoint(model_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

epochs = 1000
history = {}

for k in range(5):
    i = k + 2
    print('Model for ', i, ' angles')
    history[i] = models_ai[i].fit(training_generator[i],
                            validation_data = validation_generator[i],
                            epochs = epochs,
                            steps_per_epoch = len(training_generator[i]),
                            validation_steps = len(validation_generator[i]),
                            callbacks=[es, mc[i]]
                           )
# Out:
# Model for  2  angles
# Epoch 1/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1476 - mean_absolute_error: 0.1476
# Epoch 00001: val_loss improved from inf to 1.48898, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_2.h5
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 1.4890 - val_mean_absolute_error: 1.4890
# Epoch 2/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1554 - mean_absolute_error: 0.1554
# Epoch 00002: val_loss improved from 1.48898 to 1.25215, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_2.h5
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 1.2522 - val_mean_absolute_error: 1.2522
# Epoch 3/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 00003: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1419 - mean_absolute_error: 0.1419 - val_loss: 1.5080 - val_mean_absolute_error: 1.5080
# Epoch 4/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1530 - mean_absolute_error: 0.1530
# Epoch 00004: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 1.2989 - val_mean_absolute_error: 1.2989
# Epoch 5/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1374 - mean_absolute_error: 0.1374
# Epoch 00005: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - val_loss: 1.3558 - val_mean_absolute_error: 1.3558
# Epoch 6/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1478 - mean_absolute_error: 0.1478
# Epoch 00006: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 1.4132 - val_mean_absolute_error: 1.4132
# Epoch 7/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1415 - mean_absolute_error: 0.1415
# Epoch 00007: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1415 - mean_absolute_error: 0.1415 - val_loss: 1.4848 - val_mean_absolute_error: 1.4848
# Epoch 8/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 00008: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1521 - mean_absolute_error: 0.1521 - val_loss: 1.4883 - val_mean_absolute_error: 1.4883
# Epoch 9/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 00009: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 1.3499 - val_mean_absolute_error: 1.3499
# Epoch 10/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 00010: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - val_loss: 1.6341 - val_mean_absolute_error: 1.6341
# Epoch 11/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1272 - mean_absolute_error: 0.1272
# Epoch 00011: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1272 - mean_absolute_error: 0.1272 - val_loss: 1.5357 - val_mean_absolute_error: 1.5357
# Epoch 12/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 00012: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1397 - mean_absolute_error: 0.1397 - val_loss: 1.3949 - val_mean_absolute_error: 1.3949
# Epoch 13/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 00013: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1384 - mean_absolute_error: 0.1384 - val_loss: 1.5971 - val_mean_absolute_error: 1.5971
# Epoch 14/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1358 - mean_absolute_error: 0.1358
# Epoch 00014: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1358 - mean_absolute_error: 0.1358 - val_loss: 1.4915 - val_mean_absolute_error: 1.4915
# Epoch 15/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1494 - mean_absolute_error: 0.1494
# Epoch 00015: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 119ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - val_loss: 1.4369 - val_mean_absolute_error: 1.4369
# Epoch 16/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 00016: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - val_loss: 1.3939 - val_mean_absolute_error: 1.3939
# Epoch 17/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 00017: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 119ms/step - loss: 0.1362 - mean_absolute_error: 0.1362 - val_loss: 1.3029 - val_mean_absolute_error: 1.3029
# Epoch 18/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1431 - mean_absolute_error: 0.1431
# Epoch 00018: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1431 - mean_absolute_error: 0.1431 - val_loss: 1.4914 - val_mean_absolute_error: 1.4914
# Epoch 19/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch 00019: val_loss did not improve from 1.25215
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1485 - mean_absolute_error: 0.1485 - val_loss: 1.4463 - val_mean_absolute_error: 1.4463
# Epoch 20/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1441 - mean_absolute_error: 0.1441
# Epoch 00020: val_loss improved from 1.25215 to 1.15896, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_2.h5
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1441 - mean_absolute_error: 0.1441 - val_loss: 1.1590 - val_mean_absolute_error: 1.1590
# Epoch 21/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1519 - mean_absolute_error: 0.1519
# Epoch 00021: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 1.5346 - val_mean_absolute_error: 1.5346
# Epoch 22/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1488 - mean_absolute_error: 0.1488
# Epoch 00022: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 1.5315 - val_mean_absolute_error: 1.5315
# Epoch 23/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1340 - mean_absolute_error: 0.1340
# Epoch 00023: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 1.3917 - val_mean_absolute_error: 1.3917
# Epoch 24/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1431 - mean_absolute_error: 0.1431
# Epoch 00024: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 108ms/step - loss: 0.1431 - mean_absolute_error: 0.1431 - val_loss: 1.4387 - val_mean_absolute_error: 1.4387
# Epoch 25/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1586 - mean_absolute_error: 0.1586
# Epoch 00025: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1586 - mean_absolute_error: 0.1586 - val_loss: 1.2956 - val_mean_absolute_error: 1.2956
# Epoch 26/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1354 - mean_absolute_error: 0.1354
# Epoch 00026: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - val_loss: 1.2976 - val_mean_absolute_error: 1.2976
# Epoch 27/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1373 - mean_absolute_error: 0.1373
# Epoch 00027: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 107ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - val_loss: 1.3380 - val_mean_absolute_error: 1.3380
# Epoch 28/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1453 - mean_absolute_error: 0.1453
# Epoch 00028: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 108ms/step - loss: 0.1453 - mean_absolute_error: 0.1453 - val_loss: 1.3633 - val_mean_absolute_error: 1.3633
# Epoch 29/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1430 - mean_absolute_error: 0.1430
# Epoch 00029: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1430 - mean_absolute_error: 0.1430 - val_loss: 1.3998 - val_mean_absolute_error: 1.3998
# Epoch 30/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1411 - mean_absolute_error: 0.1411
# Epoch 00030: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 106ms/step - loss: 0.1411 - mean_absolute_error: 0.1411 - val_loss: 1.3402 - val_mean_absolute_error: 1.3402
# Epoch 31/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1396 - mean_absolute_error: 0.1396
# Epoch 00031: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 106ms/step - loss: 0.1396 - mean_absolute_error: 0.1396 - val_loss: 1.5360 - val_mean_absolute_error: 1.5360
# Epoch 32/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1489 - mean_absolute_error: 0.1489
# Epoch 00032: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 1.3901 - val_mean_absolute_error: 1.3901
# Epoch 33/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1385 - mean_absolute_error: 0.1385
# Epoch 00033: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1385 - mean_absolute_error: 0.1385 - val_loss: 1.5339 - val_mean_absolute_error: 1.5339
# Epoch 34/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1498 - mean_absolute_error: 0.1498
# Epoch 00034: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 1.4450 - val_mean_absolute_error: 1.4450
# Epoch 35/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1539 - mean_absolute_error: 0.1539
# Epoch 00035: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1539 - mean_absolute_error: 0.1539 - val_loss: 1.5099 - val_mean_absolute_error: 1.5099
# Epoch 36/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1295 - mean_absolute_error: 0.1295
# Epoch 00036: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1295 - mean_absolute_error: 0.1295 - val_loss: 1.3932 - val_mean_absolute_error: 1.3932
# Epoch 37/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1399 - mean_absolute_error: 0.1399
# Epoch 00037: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1399 - mean_absolute_error: 0.1399 - val_loss: 1.3441 - val_mean_absolute_error: 1.3441
# Epoch 38/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 00038: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1376 - mean_absolute_error: 0.1376 - val_loss: 1.3057 - val_mean_absolute_error: 1.3057
# Epoch 39/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1562 - mean_absolute_error: 0.1562
# Epoch 00039: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 108ms/step - loss: 0.1562 - mean_absolute_error: 0.1562 - val_loss: 1.5429 - val_mean_absolute_error: 1.5429
# Epoch 40/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 00040: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1405 - mean_absolute_error: 0.1405 - val_loss: 1.4631 - val_mean_absolute_error: 1.4631
# Epoch 41/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1463 - mean_absolute_error: 0.1463
# Epoch 00041: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - val_loss: 1.4466 - val_mean_absolute_error: 1.4466
# Epoch 42/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 00042: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1416 - mean_absolute_error: 0.1416 - val_loss: 1.3952 - val_mean_absolute_error: 1.3952
# Epoch 43/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 00043: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1341 - mean_absolute_error: 0.1341 - val_loss: 1.3990 - val_mean_absolute_error: 1.3990
# Epoch 44/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1440 - mean_absolute_error: 0.1440
# Epoch 00044: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1440 - mean_absolute_error: 0.1440 - val_loss: 1.3518 - val_mean_absolute_error: 1.3518
# Epoch 45/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1382 - mean_absolute_error: 0.1382
# Epoch 00045: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1382 - mean_absolute_error: 0.1382 - val_loss: 1.4955 - val_mean_absolute_error: 1.4955
# Epoch 46/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1436 - mean_absolute_error: 0.1436
# Epoch 00046: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1436 - mean_absolute_error: 0.1436 - val_loss: 1.3892 - val_mean_absolute_error: 1.3892
# Epoch 47/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1435 - mean_absolute_error: 0.1435
# Epoch 00047: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1435 - mean_absolute_error: 0.1435 - val_loss: 1.4517 - val_mean_absolute_error: 1.4517
# Epoch 48/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 00048: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1451 - mean_absolute_error: 0.1451 - val_loss: 1.5355 - val_mean_absolute_error: 1.5355
# Epoch 49/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1337 - mean_absolute_error: 0.1337
# Epoch 00049: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1337 - mean_absolute_error: 0.1337 - val_loss: 1.4966 - val_mean_absolute_error: 1.4966
# Epoch 50/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1507 - mean_absolute_error: 0.1507
# Epoch 00050: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 1.4506 - val_mean_absolute_error: 1.4506
# Epoch 51/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 00051: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1387 - mean_absolute_error: 0.1387 - val_loss: 1.3982 - val_mean_absolute_error: 1.3982
# Epoch 52/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1431 - mean_absolute_error: 0.1431
# Epoch 00052: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1431 - mean_absolute_error: 0.1431 - val_loss: 1.4454 - val_mean_absolute_error: 1.4454
# Epoch 53/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1408 - mean_absolute_error: 0.1408
# Epoch 00053: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1408 - mean_absolute_error: 0.1408 - val_loss: 1.4867 - val_mean_absolute_error: 1.4867
# Epoch 54/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1390 - mean_absolute_error: 0.1390
# Epoch 00054: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - val_loss: 1.3883 - val_mean_absolute_error: 1.3883
# Epoch 55/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1422 - mean_absolute_error: 0.1422
# Epoch 00055: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1422 - mean_absolute_error: 0.1422 - val_loss: 1.4915 - val_mean_absolute_error: 1.4915
# Epoch 56/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 00056: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1433 - mean_absolute_error: 0.1433 - val_loss: 1.4396 - val_mean_absolute_error: 1.4396
# Epoch 57/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1332 - mean_absolute_error: 0.1332
# Epoch 00057: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1332 - mean_absolute_error: 0.1332 - val_loss: 1.5957 - val_mean_absolute_error: 1.5957
# Epoch 58/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 00058: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - val_loss: 1.3990 - val_mean_absolute_error: 1.3990
# Epoch 59/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1312 - mean_absolute_error: 0.1312
# Epoch 00059: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 1.5845 - val_mean_absolute_error: 1.5845
# Epoch 60/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1548 - mean_absolute_error: 0.1548
# Epoch 00060: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - val_loss: 1.4956 - val_mean_absolute_error: 1.4956
# Epoch 61/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 00061: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1371 - mean_absolute_error: 0.1371 - val_loss: 1.4823 - val_mean_absolute_error: 1.4823
# Epoch 62/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1455 - mean_absolute_error: 0.1455
# Epoch 00062: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1455 - mean_absolute_error: 0.1455 - val_loss: 1.5027 - val_mean_absolute_error: 1.5027
# Epoch 63/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 00063: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1410 - mean_absolute_error: 0.1410 - val_loss: 1.6447 - val_mean_absolute_error: 1.6447
# Epoch 64/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 00064: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1384 - mean_absolute_error: 0.1384 - val_loss: 1.4484 - val_mean_absolute_error: 1.4484
# Epoch 65/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1430 - mean_absolute_error: 0.1430
# Epoch 00065: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1430 - mean_absolute_error: 0.1430 - val_loss: 1.3883 - val_mean_absolute_error: 1.3883
# Epoch 66/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1385 - mean_absolute_error: 0.1385
# Epoch 00066: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1385 - mean_absolute_error: 0.1385 - val_loss: 1.4858 - val_mean_absolute_error: 1.4858
# Epoch 67/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1519 - mean_absolute_error: 0.1519
# Epoch 00067: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 1.3956 - val_mean_absolute_error: 1.3956
# Epoch 68/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1354 - mean_absolute_error: 0.1354
# Epoch 00068: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 119ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - val_loss: 1.3387 - val_mean_absolute_error: 1.3387
# Epoch 69/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1347 - mean_absolute_error: 0.1347
# Epoch 00069: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - val_loss: 1.5848 - val_mean_absolute_error: 1.5848
# Epoch 70/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 00070: val_loss did not improve from 1.15896
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1410 - mean_absolute_error: 0.1410 - val_loss: 1.5373 - val_mean_absolute_error: 1.5373
# Epoch 00070: early stopping
# Model for  3  angles
# Epoch 1/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1901 - mean_absolute_error: 0.1901
# Epoch 00001: val_loss improved from inf to 1.06641, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_3.h5
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1901 - mean_absolute_error: 0.1901 - val_loss: 1.0664 - val_mean_absolute_error: 1.0664
# Epoch 2/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1631 - mean_absolute_error: 0.1631
# Epoch 00002: val_loss did not improve from 1.06641
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1631 - mean_absolute_error: 0.1631 - val_loss: 1.0794 - val_mean_absolute_error: 1.0794
# Epoch 3/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1679 - mean_absolute_error: 0.1679
# Epoch 00003: val_loss did not improve from 1.06641
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 1.1381 - val_mean_absolute_error: 1.1381
# Epoch 4/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 00004: val_loss improved from 1.06641 to 1.04833, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_3.h5
# 10/10 [==============================] - 2s 164ms/step - loss: 0.1598 - mean_absolute_error: 0.1598 - val_loss: 1.0483 - val_mean_absolute_error: 1.0483
# Epoch 5/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1520 - mean_absolute_error: 0.1520
# Epoch 00005: val_loss improved from 1.04833 to 0.98128, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_3.h5
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.9813 - val_mean_absolute_error: 0.9813
# Epoch 6/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1504 - mean_absolute_error: 0.1504
# Epoch 00006: val_loss improved from 0.98128 to 0.91851, saving model to /home/renat_sergazinov/python-git-workspace/PhotoForceReconML/models/small/400/vgg19_angles_inner_3.h5
# 10/10 [==============================] - 2s 152ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.9185 - val_mean_absolute_error: 0.9185
# Epoch 7/1000
#  5/10 [==============>...............] - ETA: 0s - loss: 0.1488 - mean_absolute_error: 0.1488
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-33b28809968b> in <module>
#      14     i = k + 2
#      15     print('Model for ', i, ' angles')
# ---> 16     history[i] = models_ai[i].fit(training_generator[i],
#      17                             validation_data = validation_generator[i],
#      18                             epochs = epochs,
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     387     """
#     388     if self._should_call_train_batch_hooks:
# --> 389       logs = self._process_logs(logs)
#     390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _process_logs(self, logs)
#     263     """Turns tensors into numpy arrays or Python scalars."""
#     264     if logs:
# --> 265       return tf_utils.to_numpy_or_python_type(logs)
#     266     return {}
#     267
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# ~/anaconda3/envs/tf-2-gpu/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize = (15, 15))
for i in range(5):
    fig.add_subplot(3, 2, i+1)
    plt.plot(history[i+2].history['loss'])
    plt.plot(history[i+2].history['val_loss'])
    plt.title('Model loss '+str(i+2))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
